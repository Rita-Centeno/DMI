# %% [markdown]
# # Table of Contents:
# 1. [Library Imports](#li)
# 2. [Data Preparation](#dp)
# 3. [Method Comparison](#mc)
# 4. [Clustering](#cl)
# 5. [UMAP](#u)
# 6. [Final Solutions](#f)

# %% [markdown]
# # 1. Library Imports
# <a id='li'></a>

# %%
### IMPORTS
# !pip install numpy
# !pip install pandas
# !pip install scikit-learn
# !pip install umap-learn
# !pip install scipy


### LIBRARIES
import pandas as pd
import numpy as np
import umap

from sklearn.cluster import KMeans, DBSCAN
from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

from collections import Counter

from scipy.spatial.distance import cdist

from utils1 import knn_imputer
from utils2 import *

### WARNINGS
import warnings
warnings.filterwarnings('ignore')

### AUTORELOAD
# %load_ext autoreload
# %autoreload 2

# Set the path to the data files
# path = 'Data/New_Data/project_data_almano_educ_perc.csv'
#path = 'Data/New_Data/project_data_95_educ_perc.csv'
path = 'Data/New_Data/project_data_99_educ_perc.csv'

# %% [markdown]
# # 2. Data Preparation
# <a id='dp'></a>

# %% [markdown]
# #### Import the data

# %%
data = pd.read_csv(path)

# %% [markdown]
# #### Encode categorical variables

# %%
data['relevance_criteria'] = data['relevance_criteria'].replace({'Priority': 2, 'Caution': 1, 'Unknown': 0})
data['gender'] = data['gender'].replace({'female': 0, 'male': 1})
data['education'] = data['education'].replace({'High School': 0, 'Degree': 1, 'BSc Degree': 2, 'MSc Degree': 3})
data.loc[data['returns'] > 0, 'returns'] = 1

# %% [markdown]
# #### Define metrics to study

# %%
# Metrics to be shown
demographic_metrics_all = ['frequency_items', 'potencial_score', 'longevity_months', 'relevance_criteria', 'recency_in_weeks', 'promotional_percentage', 'returns', 'flaged', 'credit_factor', 'zip_code', 'education', 'gender']
# Metrics considered for clustering
demographic_metrics = ['frequency_items', 'potencial_score', 'longevity_months', 'relevance_criteria', 'recency_in_weeks', 'promotional_percentage', 'returns', 'flaged']

# %%
demographic = data[demographic_metrics_all]
demographic_selection = data[demographic_metrics]

# %% [markdown]
# #### Scale the data

# %%
# Defining the scalers
standard = StandardScaler()
minmax = MinMaxScaler()
robust = RobustScaler()

# %%
# Scaling the data
dem_no_scl = demographic_selection.copy()
dem_st_scl = standard.fit_transform(demographic_selection)
dem_mm_scl = minmax.fit_transform(demographic_selection)
dem_rb_scl = robust.fit_transform(demographic_selection)

# %%
# Creating the scaled dataframes
demographic_no_scl = demographic_selection.copy()
demographic_no_scl[demographic_metrics] = dem_no_scl

demographic_st_scl = demographic_selection.copy()
demographic_st_scl[demographic_metrics] = dem_st_scl

demographic_mm_scl = demographic_selection.copy()
demographic_mm_scl[demographic_metrics] = dem_mm_scl

demographic_rb_scl = demographic_selection.copy()
demographic_rb_scl[demographic_metrics] = dem_rb_scl

# %%
# Creating equal samples of the differently scaled dataframes
sample_original = demographic.sample(frac=0.2, random_state=1)
sample_no_scl = demographic_no_scl.sample(frac=0.2, random_state=1)
sample_st_scl = demographic_st_scl.sample(frac=0.2, random_state=1)
sample_mm_scl = demographic_mm_scl.sample(frac=0.2, random_state=1)
sample_rb_scl = demographic_rb_scl.sample(frac=0.2, random_state=1)

# %% [markdown]
# # 3. Clustering Method Comparison
# <a id='mc'></a>

# %% [markdown]
# Here different clustering methods performance (based on R^2) will be compared to determine weather if it is even worth it to test all of them. This test will be performed for different types of scaled data.
#
# - [No Scaler](#cmc-no)
# - [Standard Scaler](#cmc-st)
# - [MinMax Scaler](#cmc-mm)
# - [Robust Scaler](#cmc-rb)

# %% [markdown]
# First, we will define the base clustering methods to be used in this test. Note that hierarchical clustering will be performed with eucledian distances as this is what is used by k-means, in order to ensure a fair comparison.

# %%
kmeans = KMeans(init='k-means++', n_init=10, random_state=1)
hierarchical = AgglomerativeClustering(metric='euclidean')

# %% [markdown]
# ### No Scale

# %%
dem_no_r2_scores = get_r2_df(sample_no_scl, demographic_metrics, kmeans, hierarchical)
dem_no_r2_scores
# Out:
#      kmeans  complete   average    single      ward
# 2  0.528185  0.500753  0.047871  0.528185  0.528185
# 3  0.637351  0.588127  0.558928  0.528409  0.622241
# 4  0.702856  0.604604  0.559652  0.528635  0.693070
# 5  0.741393  0.616176  0.616420  0.528785  0.727364
# 6  0.766808  0.639001  0.617078  0.528921  0.746569
# 7  0.788074  0.685340  0.617149  0.529028  0.765163
# 8  0.809332  0.701303  0.618338  0.529033  0.783206
# 9  0.826790  0.702343  0.618388  0.530595  0.800240

# %%
plot_r2_scores(dem_no_r2_scores, "Demographic Variables:\nR² plot for various clustering methods\n")

# %% [markdown]
# ### Standard Scale

# %%
dem_st_r2_scores = get_r2_df(sample_st_scl, demographic_metrics, kmeans, hierarchical)
dem_st_r2_scores
# Out:
#      kmeans  complete   average    single      ward
# 2  0.138208  0.139880  0.139880  0.139880  0.139880
# 3  0.245348  0.261587  0.261587  0.146147  0.261587
# 4  0.365834  0.311470  0.267854  0.267854  0.365462
# 5  0.457971  0.410663  0.268097  0.268110  0.445819
# 6  0.517687  0.427187  0.289103  0.269541  0.496031
# 7  0.559282  0.469632  0.392869  0.269630  0.539049
# 8  0.595630  0.475318  0.393061  0.269740  0.568615
# 9  0.622036  0.481584  0.393156  0.270381  0.589806

# %%
plot_r2_scores(dem_st_r2_scores, "Demographic Variables:\nR² plot for various clustering methods\n")

# %% [markdown]
# ### MinMax Scaler

# %%
dem_mm_r2_scores = get_r2_df(sample_mm_scl, demographic_metrics, kmeans, hierarchical)
dem_mm_r2_scores
# Out:
#      kmeans  complete   average    single      ward
# 2  0.287350  0.040103  0.001261  0.025527  0.243536
# 3  0.421417  0.182023  0.041371  0.047529  0.386143
# 4  0.493718  0.262404  0.182748  0.189449  0.478024
# 5  0.559710  0.278665  0.190174  0.189612  0.532338
# 6  0.593857  0.286091  0.190362  0.189818  0.566663
# 7  0.613888  0.535741  0.205436  0.189961  0.600694
# 8  0.636795  0.537747  0.285833  0.190498  0.622031
# 9  0.655148  0.540119  0.288204  0.190587  0.637889

# %%
plot_r2_scores(dem_mm_r2_scores, "Demographic Variables:\nR² plot for various clustering methods\n")

# %% [markdown]
# ### Robust Scaler

# %%
dem_rb_r2_scores = get_r2_df(sample_rb_scl, demographic_metrics, kmeans, hierarchical)
dem_rb_r2_scores
# Out:
#      kmeans  complete   average    single      ward
# 2  0.200756  0.043117  0.000359  0.000359  0.184134
# 3  0.335453  0.144994  0.155846  0.000828  0.311742
# 4  0.409878  0.262763  0.159680  0.001037  0.370936
# 5  0.458551  0.325846  0.160187  0.001203  0.412677
# 6  0.502659  0.326307  0.160363  0.001546  0.447081
# 7  0.533078  0.353143  0.171422  0.001827  0.474484
# 8  0.561749  0.357275  0.173287  0.002228  0.496886
# 9  0.581038  0.370692  0.173785  0.002343  0.517629

# %%
plot_r2_scores(dem_rb_r2_scores, "Demographic Variables:\nR² plot for various clustering methods\n")

# %% [markdown]
# ### Conclusions
# <a id='cmc-c'></a>
#
# With this analysis we can confidently focus on using kmeans and hierarchical clustering with ward linkeage to conduct our analysis, as these were shown to  consistently give better results for all types of scaled data.
#
# It is also possible to see that solutions with 3 to 6 clusters will likely yeild the best results, as it is mostly where the graphs present more significant changes in the slope. Additionally, a comparison among scaler results with these preselected clustering techniques was performed.

# %%
# Prefix the names of the columns
df_no_prefixed = dem_no_r2_scores.add_prefix("no_")
df_st_prefixed = dem_st_r2_scores.add_prefix("st_")
df_mm_prefixed = dem_mm_r2_scores.add_prefix("mm_")
df_rb_prefixed = dem_rb_r2_scores.add_prefix("rb_")

# Concatenate the dataframes
df_combined = pd.concat([df_no_prefixed, df_st_prefixed, df_mm_prefixed, df_rb_prefixed], axis=1)

# Filter ward and kmeans columns
filtered_columns = [col for col in df_combined.columns if 'ward' in col or 'kmeans' in col]

# Create a new dataframe with only the filtered columns
df_filtered = df_combined[filtered_columns]
df_filtered
# Out:
#    no_kmeans   no_ward  st_kmeans   st_ward  mm_kmeans   mm_ward  rb_kmeans  \
# 2   0.528185  0.528185   0.138208  0.139880   0.287350  0.243536   0.200756
# 3   0.637351  0.622241   0.245348  0.261587   0.421417  0.386143   0.335453
# 4   0.702856  0.693070   0.365834  0.365462   0.493718  0.478024   0.409878
# 5   0.741393  0.727364   0.457971  0.445819   0.559710  0.532338   0.458551
# 6   0.766808  0.746569   0.517687  0.496031   0.593857  0.566663   0.502659
# 7   0.788074  0.765163   0.559282  0.539049   0.613888  0.600694   0.533078
# 8   0.809332  0.783206   0.595630  0.568615   0.636795  0.622031   0.561749
# 9   0.826790  0.800240   0.622036  0.589806   0.655148  0.637889   0.581038
#
#     rb_ward
# 2  0.184134
# 3  0.311742
# 4  0.370936
# 5  0.412677
# 6  0.447081
# 7  0.474484
# 8  0.496886
# 9  0.517629

# %%
plot_r2_scores(df_filtered, "Demographic Variables:\nR² plot for various clustering methods\n")

# %% [markdown]
# From the graph it is possible to conclude that **unscaled data** presented the highest performance score, followed by minmax scaler, unscaled data, and standard scaler. The performances for the **standard scaler** and **robust scaler** were the ones that presented worse results, with robust scaler preforming worse for an elevated number of clusters and standard scaler for a lower number of clusters. Nonetheless, similarly to what happened for the preference perspective, all scaling methods were still tested.

# %% [markdown]
# ---

# %% [markdown]
# # 4. Clustering
# <a id='cl'></a>

# %% [markdown]
# In the notebook, the cluster analysis is grouped by data inputs - no scaling, standard scaler, minmax scaler, robust scaler. In each group, several methods of clustering were used and they are presented in this order:
# 1. [KMeans](#km)
# 2. [Ward (Hierarchical)](#wh)
# 3. [DBScan](#dbs)
#
# In the end, it was possible to identify groups that recurrently appeared in the clustering solutions, and based on this, solutions were chosen to be further studied.

# %% [markdown]
# ## 4.1. K-means <a id='km'></a>

# %% [markdown]
# In this section, the k-means algorithm was tested with the data inputs previously mentioned. For each of the data inputs inertia and silhuette plots were done in order to decide which number of cluester were going to be considered for testing. Then, the clusters formed were analysed and clustering solutions compared. The tests for each data input were presented in the following order:
# 1. [No Scaler](#km-no)
# 2. [Standard Scaler](#km-st)
# 3. [MinMax Scaler](#km-mm)
# 4. [Robust Scaler](#km-rb)

# %% [markdown]
# ### No Scaler <a id='km-no'></a>

# %% [markdown]
# #### Plot

# %%
plot_inertia_and_silhouette(sample_no_scl, 2, 10)

# %% [markdown]
# #### Models

# %% [markdown]
# ##### 3 clusters

# %%
kmeans = KMeans(n_clusters = 3, init='k-means++', n_init=20,  random_state = 1).fit(sample_no_scl)
sample_original['no_kmeans3'] = kmeans.predict(sample_no_scl)

# %%
groupby_mean(sample_original, 'no_kmeans3', True)
# Out:
# # observations per cluster: [10379, 5744, 8303]
# <style type="text/css">
# #T_fab96_row0_col0, #T_fab96_row0_col2, #T_fab96_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_fab96_row0_col1 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_fab96_row1_col0, #T_fab96_row9_col0, #T_fab96_row10_col1, #T_fab96_row12_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_fab96_row1_col2 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_fab96_row2_col0 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_fab96_row2_col1 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_fab96_row2_col2 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_fab96_row3_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_fab96_row3_col1, #T_fab96_row8_col0, #T_fab96_row12_col0 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_fab96_row3_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_fab96_row4_col0 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_fab96_row4_col1 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_fab96_row4_col2 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_fab96_row5_col0 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_fab96_row5_col1 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_fab96_row5_col2 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_fab96_row6_col0, #T_fab96_row6_col1, #T_fab96_row6_col2, #T_fab96_row7_col0, #T_fab96_row7_col1, #T_fab96_row7_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_fab96_row8_col1, #T_fab96_row11_col0, #T_fab96_row11_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_fab96_row8_col2 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_fab96_row9_col1 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_fab96_row9_col2 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_fab96_row10_col0 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_fab96_row10_col2, #T_fab96_row12_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_fab96_row11_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_fab96">
#   <thead>
#     <tr>
#       <th class="index_name level0" >no_kmeans3</th>
#       <th id="T_fab96_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_fab96_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_fab96_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fab96_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_fab96_row0_col0" class="data row0 col0" >39.400000</td>
#       <td id="T_fab96_row0_col1" class="data row0 col1" >40.520000</td>
#       <td id="T_fab96_row0_col2" class="data row0 col2" >35.020000</td>
#     </tr>
#     <tr>
#       <th id="T_fab96_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_fab96_row1_col0" class="data row1 col0" >0.730000</td>
#       <td id="T_fab96_row1_col1" class="data row1 col1" >80.200000</td>
#       <td id="T_fab96_row1_col2" class="data row1 col2" >29.740000</td>
#     </tr>
#     <tr>
#       <th id="T_fab96_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_fab96_row2_col0" class="data row2 col0" >12.940000</td>
#       <td id="T_fab96_row2_col1" class="data row2 col1" >16.530000</td>
#       <td id="T_fab96_row2_col2" class="data row2 col2" >16.500000</td>
#     </tr>
#     <tr>
#       <th id="T_fab96_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_fab96_row3_col0" class="data row3 col0" >1.920000</td>
#       <td id="T_fab96_row3_col1" class="data row3 col1" >1.910000</td>
#       <td id="T_fab96_row3_col2" class="data row3 col2" >1.930000</td>
#     </tr>
#     <tr>
#       <th id="T_fab96_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_fab96_row4_col0" class="data row4 col0" >15.640000</td>
#       <td id="T_fab96_row4_col1" class="data row4 col1" >14.780000</td>
#       <td id="T_fab96_row4_col2" class="data row4 col2" >15.140000</td>
#     </tr>
#     <tr>
#       <th id="T_fab96_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_fab96_row5_col0" class="data row5 col0" >11.740000</td>
#       <td id="T_fab96_row5_col1" class="data row5 col1" >12.800000</td>
#       <td id="T_fab96_row5_col2" class="data row5 col2" >10.290000</td>
#     </tr>
#     <tr>
#       <th id="T_fab96_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_fab96_row6_col0" class="data row6 col0" >0.040000</td>
#       <td id="T_fab96_row6_col1" class="data row6 col1" >0.070000</td>
#       <td id="T_fab96_row6_col2" class="data row6 col2" >0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_fab96_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_fab96_row7_col0" class="data row7 col0" >0.010000</td>
#       <td id="T_fab96_row7_col1" class="data row7 col1" >0.020000</td>
#       <td id="T_fab96_row7_col2" class="data row7 col2" >0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_fab96_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_fab96_row8_col0" class="data row8 col0" >1.020000</td>
#       <td id="T_fab96_row8_col1" class="data row8 col1" >0.800000</td>
#       <td id="T_fab96_row8_col2" class="data row8 col2" >0.830000</td>
#     </tr>
#     <tr>
#       <th id="T_fab96_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_fab96_row9_col0" class="data row9 col0" >0.570000</td>
#       <td id="T_fab96_row9_col1" class="data row9 col1" >7.680000</td>
#       <td id="T_fab96_row9_col2" class="data row9 col2" >7.660000</td>
#     </tr>
#     <tr>
#       <th id="T_fab96_level0_row10" class="row_heading level0 row10" >education</th>
#       <td id="T_fab96_row10_col0" class="data row10 col0" >1.250000</td>
#       <td id="T_fab96_row10_col1" class="data row10 col1" >1.000000</td>
#       <td id="T_fab96_row10_col2" class="data row10 col2" >1.070000</td>
#     </tr>
#     <tr>
#       <th id="T_fab96_level0_row11" class="row_heading level0 row11" >gender</th>
#       <td id="T_fab96_row11_col0" class="data row11 col0" >0.380000</td>
#       <td id="T_fab96_row11_col1" class="data row11 col1" >0.360000</td>
#       <td id="T_fab96_row11_col2" class="data row11 col2" >0.380000</td>
#     </tr>
#     <tr>
#       <th id="T_fab96_level0_row12" class="row_heading level0 row12" >constant</th>
#       <td id="T_fab96_row12_col0" class="data row12 col0" >1.000000</td>
#       <td id="T_fab96_row12_col1" class="data row12 col1" >1.000000</td>
#       <td id="T_fab96_row12_col2" class="data row12 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# lowscore | score | general

# %% [markdown]
# ##### 4 clusters

# %%
kmeans = KMeans(n_clusters = 4, init='k-means++', n_init=20,  random_state = 1).fit(sample_no_scl)
sample_original['no_kmeans4'] = kmeans.predict(sample_no_scl)

# %%
groupby_mean(sample_original, 'no_kmeans4', True)
# Out:
# # observations per cluster: [7695, 5531, 9912, 1288]
# <style type="text/css">
# #T_15257_row0_col0, #T_15257_row0_col2, #T_15257_row1_col1, #T_15257_row5_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_15257_row0_col1 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_15257_row0_col3 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_15257_row1_col0 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_15257_row1_col2, #T_15257_row8_col3, #T_15257_row9_col2, #T_15257_row10_col1, #T_15257_row10_col3, #T_15257_row12_col1, #T_15257_row12_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_15257_row1_col3 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_15257_row2_col0 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_15257_row2_col1 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_15257_row2_col2 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_15257_row2_col3 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_15257_row3_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_15257_row3_col1, #T_15257_row8_col2, #T_15257_row12_col2 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_15257_row3_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_15257_row3_col3, #T_15257_row10_col2 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_15257_row4_col0 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_15257_row4_col1 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_15257_row4_col2 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_15257_row4_col3 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_15257_row5_col0 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_15257_row5_col1 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_15257_row5_col2 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_15257_row6_col0, #T_15257_row6_col1, #T_15257_row6_col2, #T_15257_row7_col0, #T_15257_row7_col1, #T_15257_row7_col2, #T_15257_row7_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_15257_row6_col3, #T_15257_row11_col1, #T_15257_row11_col3 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_15257_row8_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_15257_row8_col1, #T_15257_row11_col0, #T_15257_row11_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_15257_row9_col0 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_15257_row9_col1 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_15257_row9_col3 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_15257_row10_col0, #T_15257_row12_col0 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# </style>
# <table id="T_15257">
#   <thead>
#     <tr>
#       <th class="index_name level0" >no_kmeans4</th>
#       <th id="T_15257_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_15257_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_15257_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_15257_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15257_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_15257_row0_col0" class="data row0 col0" >35.090000</td>
#       <td id="T_15257_row0_col1" class="data row0 col1" >40.490000</td>
#       <td id="T_15257_row0_col2" class="data row0 col2" >39.290000</td>
#       <td id="T_15257_row0_col3" class="data row0 col3" >38.110000</td>
#     </tr>
#     <tr>
#       <th id="T_15257_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_15257_row1_col0" class="data row1 col0" >29.730000</td>
#       <td id="T_15257_row1_col1" class="data row1 col1" >80.200000</td>
#       <td id="T_15257_row1_col2" class="data row1 col2" >0.680000</td>
#       <td id="T_15257_row1_col3" class="data row1 col3" >28.000000</td>
#     </tr>
#     <tr>
#       <th id="T_15257_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_15257_row2_col0" class="data row2 col0" >16.480000</td>
#       <td id="T_15257_row2_col1" class="data row2 col1" >16.480000</td>
#       <td id="T_15257_row2_col2" class="data row2 col2" >12.890000</td>
#       <td id="T_15257_row2_col3" class="data row2 col3" >15.950000</td>
#     </tr>
#     <tr>
#       <th id="T_15257_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_15257_row3_col0" class="data row3 col0" >1.930000</td>
#       <td id="T_15257_row3_col1" class="data row3 col1" >1.910000</td>
#       <td id="T_15257_row3_col2" class="data row3 col2" >1.920000</td>
#       <td id="T_15257_row3_col3" class="data row3 col3" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_15257_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_15257_row4_col0" class="data row4 col0" >15.160000</td>
#       <td id="T_15257_row4_col1" class="data row4 col1" >14.800000</td>
#       <td id="T_15257_row4_col2" class="data row4 col2" >15.660000</td>
#       <td id="T_15257_row4_col3" class="data row4 col3" >14.930000</td>
#     </tr>
#     <tr>
#       <th id="T_15257_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_15257_row5_col0" class="data row5 col0" >7.010000</td>
#       <td id="T_15257_row5_col1" class="data row5 col1" >10.100000</td>
#       <td id="T_15257_row5_col2" class="data row5 col2" >9.330000</td>
#       <td id="T_15257_row5_col3" class="data row5 col3" >60.970000</td>
#     </tr>
#     <tr>
#       <th id="T_15257_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_15257_row6_col0" class="data row6 col0" >0.020000</td>
#       <td id="T_15257_row6_col1" class="data row6 col1" >0.050000</td>
#       <td id="T_15257_row6_col2" class="data row6 col2" >0.030000</td>
#       <td id="T_15257_row6_col3" class="data row6 col3" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_15257_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_15257_row7_col0" class="data row7 col0" >0.010000</td>
#       <td id="T_15257_row7_col1" class="data row7 col1" >0.020000</td>
#       <td id="T_15257_row7_col2" class="data row7 col2" >0.010000</td>
#       <td id="T_15257_row7_col3" class="data row7 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_15257_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_15257_row8_col0" class="data row8 col0" >0.820000</td>
#       <td id="T_15257_row8_col1" class="data row8 col1" >0.800000</td>
#       <td id="T_15257_row8_col2" class="data row8 col2" >1.020000</td>
#       <td id="T_15257_row8_col3" class="data row8 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_15257_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_15257_row9_col0" class="data row9 col0" >7.670000</td>
#       <td id="T_15257_row9_col1" class="data row9 col1" >7.680000</td>
#       <td id="T_15257_row9_col2" class="data row9 col2" >0.540000</td>
#       <td id="T_15257_row9_col3" class="data row9 col3" >5.270000</td>
#     </tr>
#     <tr>
#       <th id="T_15257_level0_row10" class="row_heading level0 row10" >education</th>
#       <td id="T_15257_row10_col0" class="data row10 col0" >1.080000</td>
#       <td id="T_15257_row10_col1" class="data row10 col1" >1.010000</td>
#       <td id="T_15257_row10_col2" class="data row10 col2" >1.270000</td>
#       <td id="T_15257_row10_col3" class="data row10 col3" >0.930000</td>
#     </tr>
#     <tr>
#       <th id="T_15257_level0_row11" class="row_heading level0 row11" >gender</th>
#       <td id="T_15257_row11_col0" class="data row11 col0" >0.380000</td>
#       <td id="T_15257_row11_col1" class="data row11 col1" >0.360000</td>
#       <td id="T_15257_row11_col2" class="data row11 col2" >0.380000</td>
#       <td id="T_15257_row11_col3" class="data row11 col3" >0.370000</td>
#     </tr>
#     <tr>
#       <th id="T_15257_level0_row12" class="row_heading level0 row12" >constant</th>
#       <td id="T_15257_row12_col0" class="data row12 col0" >1.000000</td>
#       <td id="T_15257_row12_col1" class="data row12 col1" >1.000000</td>
#       <td id="T_15257_row12_col2" class="data row12 col2" >1.000000</td>
#       <td id="T_1

# %% [markdown]
# general | score | lowscore | promo

# %% [markdown]
# ##### 5 clusters

# %%
kmeans = KMeans(n_clusters = 5, init='k-means++', n_init=20,  random_state = 1).fit(sample_no_scl)
sample_original['no_kmeans5'] = kmeans.predict(sample_no_scl)

# %%
groupby_mean(sample_original, 'no_kmeans5', True)
# Out:
# # observations per cluster: [2736, 5075, 8363, 7531, 721]
# <style type="text/css">
# #T_d1755_row0_col0 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_d1755_row0_col1 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_d1755_row0_col2, #T_d1755_row0_col3, #T_d1755_row1_col1, #T_d1755_row1_col4, #T_d1755_row5_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d1755_row0_col4 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_d1755_row1_col0 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_d1755_row1_col2, #T_d1755_row9_col2, #T_d1755_row10_col1, #T_d1755_row12_col1, #T_d1755_row12_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_d1755_row1_col3 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_d1755_row2_col0 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_d1755_row2_col1 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_d1755_row2_col2 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_d1755_row2_col3 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_d1755_row2_col4 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_d1755_row3_col0, #T_d1755_row3_col3, #T_d1755_row9_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_d1755_row3_col1, #T_d1755_row3_col4, #T_d1755_row10_col0, #T_d1755_row12_col0, #T_d1755_row12_col2 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_d1755_row3_col2, #T_d1755_row8_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_d1755_row4_col0 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_d1755_row4_col1, #T_d1755_row4_col4 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_d1755_row4_col2 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_d1755_row4_col3 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_d1755_row5_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_d1755_row5_col2 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_d1755_row5_col3 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_d1755_row5_col4 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_d1755_row6_col0, #T_d1755_row6_col1, #T_d1755_row6_col2, #T_d1755_row6_col3, #T_d1755_row6_col4, #T_d1755_row7_col0, #T_d1755_row7_col1, #T_d1755_row7_col2, #T_d1755_row7_col3, #T_d1755_row7_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d1755_row8_col1, #T_d1755_row8_col4, #T_d1755_row10_col4, #T_d1755_row11_col0, #T_d1755_row11_col2, #T_d1755_row11_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_d1755_row8_col2, #T_d1755_row8_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_d1755_row9_col1 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_d1755_row9_col3 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_d1755_row9_col4 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_d1755_row10_col2 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_d1755_row10_col3, #T_d1755_row12_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_d1755_row11_col1, #T_d1755_row11_col4 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_d1755">
#   <thead>
#     <tr>
#       <th class="index_name level0" >no_kmeans5</th>
#       <th id="T_d1755_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_d1755_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_d1755_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_d1755_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_d1755_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1755_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_d1755_row0_col0" class="data row0 col0" >38.190000</td>
#       <td id="T_d1755_row0_col1" class="data row0 col1" >40.550000</td>
#       <td id="T_d1755_row0_col2" class="data row0 col2" >39.580000</td>
#       <td id="T_d1755_row0_col3" class="data row0 col3" >34.860000</td>
#       <td id="T_d1755_row0_col4" class="data row0 col4" >39.740000</td>
#     </tr>
#     <tr>
#       <th id="T_d1755_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_d1755_row1_col0" class="data row1 col0" >7.490000</td>
#       <td id="T_d1755_row1_col1" class="data row1 col1" >80.180000</td>
#       <td id="T_d1755_row1_col2" class="data row1 col2" >0.770000</td>
#       <td id="T_d1755_row1_col3" class="data row1 col3" >29.970000</td>
#       <td id="T_d1755_row1_col4" class="data row1 col4" >77.120000</td>
#     </tr>
#     <tr>
#       <th id="T_d1755_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_d1755_row2_col0" class="data row2 col0" >12.540000</td>
#       <td id="T_d1755_row2_col1" class="data row2 col1" >16.420000</td>
#       <td id="T_d1755_row2_col2" class="data row2 col2" >13.340000</td>
#       <td id="T_d1755_row2_col3" class="data row2 col3" >16.540000</td>
#       <td id="T_d1755_row2_col4" class="data row2 col4" >17.320000</td>
#     </tr>
#     <tr>
#       <th id="T_d1755_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_d1755_row3_col0" class="data row3 col0" >2.000000</td>
#       <td id="T_d1755_row3_col1" class="data row3 col1" >1.900000</td>
#       <td id="T_d1755_row3_col2" class="data row3 col2" >1.900000</td>
#       <td id="T_d1755_row3_col3" class="data row3 col3" >1.930000</td>
#       <td id="T_d1755_row3_col4" class="data row3 col4" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d1755_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_d1755_row4_col0" class="data row4 col0" >15.770000</td>
#       <td id="T_d1755_row4_col1" class="data row4 col1" >14.810000</td>
#       <td id="T_d1755_row4_col2" class="data row4 col2" >15.570000</td>
#       <td id="T_d1755_row4_col3" class="data row4 col3" >15.140000</td>
#       <td id="T_d1755_row4_col4" class="data row4 col4" >14.440000</td>
#     </tr>
#     <tr>
#       <th id="T_d1755_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_d1755_row5_col0" class="data row5 col0" >39.360000</td>
#       <td id="T_d1755_row5_col1" class="data row5 col1" >7.020000</td>
#       <td id="T_d1755_row5_col2" class="data row5 col2" >5.280000</td>
#       <td id="T_d1755_row5_col3" class="data row5 col3" >6.760000</td>
#       <td id="T_d1755_row5_col4" class="data row5 col4" >58.820000</td>
#     </tr>
#     <tr>
#       <th id="T_d1755_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_d1755_row6_col0" class="data row6 col0" >0.070000</td>
#       <td id="T_d1755_row6_col1" class="data row6 col1" >0.050000</td>
#       <td id="T_d1755_row6_col2" class="data row6 col2" >0.030000</td>
#       <td id="T_d1755_row6_col3" class="data row6 col3" >0.020000</td>
#       <td id="T_d1755_row6_col4" class="data row6 col4" >0.260000</td>
#     </tr>
#     <tr>
#       <th id="T_d1755_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_d1755_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_d1755_row7_col1" class="data row7 col1" >0.020000</td>
#       <td id="T_d1755_row7_col2" class="data row7 col2" >0.010000</td>
#       <td id="T_d1755_row7_col3" class="data row7 col3" >0.010000</td>
#       <td id="T_d1755_row7_col4" class="data row7 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d1755_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_d1755_row8_col0" class="data row8 col0" >1.710000</td>
#       <td id="T_d1755_row8_col1" class="data row8 col1" >0.790000</td>
#       <td id="T_d1755_row8_col2" class="data row8 col2" >0.800000</td>
#       <td id="T_d1755_row8_col3" class="data row8 col3" >0.810000</td>
#       <td id="T_d1755_row8_col4" class="data row8 col4" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_d1755_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_d1755_row9_col0" class="data row9 col0" >2.260000</td>
#       <td id="T_d1755_row9_col1" class="data row9 col1" >7.680000</td>
#       <td id="T_d1755_row9_col2" class="data row9 col2" >0.620000</td>
#       <td id="T_d1755_row9_col3" class="data row9 col3" >7.680000</td

# %% [markdown]
# promo | score | lowscore | general | promo+returns+score

# %% [markdown]
# #### Comparison

# %%
clusters_comparison(sample_original, 'no_kmeans4', 'no_kmeans3')
# Out:
#                       no_kmeans3 0 Cluster  no_kmeans3 1 Cluster  \
# no_kmeans4 0 Cluster                     5                     0
# no_kmeans4 1 Cluster                     0                  5531
# no_kmeans4 2 Cluster                  9906                     0
# no_kmeans4 3 Cluster                   468                   213
#
#                       no_kmeans3 2 Cluster
# no_kmeans4 0 Cluster                  7690
# no_kmeans4 1 Cluster                     0
# no_kmeans4 2 Cluster                     6
# no_kmeans4 3 Cluster                   607

# %%
clusters_comparison(sample_original, 'no_kmeans5', 'no_kmeans4')
# Out:
#                       no_kmeans4 0 Cluster  no_kmeans4 1 Cluster  \
# no_kmeans5 0 Cluster                   142                     0
# no_kmeans5 1 Cluster                     0                  5075
# no_kmeans5 2 Cluster                    55                     0
# no_kmeans5 3 Cluster                  7498                     0
# no_kmeans5 4 Cluster                     0                   456
#
#                       no_kmeans4 2 Cluster  no_kmeans4 3 Cluster
# no_kmeans5 0 Cluster                  1602                   992
# no_kmeans5 1 Cluster                     0                     0
# no_kmeans5 2 Cluster                  8308                     0
# no_kmeans5 3 Cluster                     2                    31
# no_kmeans5 4 Cluster                     0                   265

# %% [markdown]
# ### Standard Scaler <a id='km-st'></a>

# %% [markdown]
# #### Plot

# %%
plot_inertia_and_silhouette(sample_st_scl, 2, 10)

# %% [markdown]
# #### Models

# %% [markdown]
# ##### 3 clusters

# %%
kmeans = KMeans(n_clusters = 3, init='k-means++', n_init=20,  random_state = 1).fit(sample_st_scl)
sample_original['st_kmeans3'] = kmeans.predict(sample_st_scl)

# %%
groupby_mean(sample_original, 'st_kmeans3', True)
# Out:
# # observations per cluster: [17451, 6766, 209]
# <style type="text/css">
# #T_c552e_row0_col0, #T_c552e_row1_col1, #T_c552e_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c552e_row0_col1 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_c552e_row0_col2 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_c552e_row1_col0 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_c552e_row2_col0 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_c552e_row2_col1 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_c552e_row2_col2 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_c552e_row3_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_c552e_row3_col1, #T_c552e_row3_col2, #T_c552e_row8_col0, #T_c552e_row12_col0 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_c552e_row4_col0 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_c552e_row4_col1 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_c552e_row4_col2 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_c552e_row5_col0 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_c552e_row5_col1 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_c552e_row5_col2, #T_c552e_row6_col0, #T_c552e_row6_col1, #T_c552e_row7_col0, #T_c552e_row7_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c552e_row6_col2, #T_c552e_row8_col1, #T_c552e_row11_col0, #T_c552e_row11_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_c552e_row7_col2, #T_c552e_row12_col2 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_c552e_row8_col2, #T_c552e_row10_col1, #T_c552e_row12_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_c552e_row9_col0 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_c552e_row9_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_c552e_row9_col2 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_c552e_row10_col0 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_c552e_row10_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_c552e_row11_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_c552e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >st_kmeans3</th>
#       <th id="T_c552e_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_c552e_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_c552e_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c552e_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_c552e_row0_col0" class="data row0 col0" >37.110000</td>
#       <td id="T_c552e_row0_col1" class="data row0 col1" >40.800000</td>
#       <td id="T_c552e_row0_col2" class="data row0 col2" >41.760000</td>
#     </tr>
#     <tr>
#       <th id="T_c552e_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_c552e_row1_col0" class="data row1 col0" >12.880000</td>
#       <td id="T_c552e_row1_col1" class="data row1 col1" >71.010000</td>
#       <td id="T_c552e_row1_col2" class="data row1 col2" >47.880000</td>
#     </tr>
#     <tr>
#       <th id="T_c552e_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_c552e_row2_col0" class="data row2 col0" >14.070000</td>
#       <td id="T_c552e_row2_col1" class="data row2 col1" >17.310000</td>
#       <td id="T_c552e_row2_col2" class="data row2 col2" >17.630000</td>
#     </tr>
#     <tr>
#       <th id="T_c552e_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_c552e_row3_col0" class="data row3 col0" >1.930000</td>
#       <td id="T_c552e_row3_col1" class="data row3 col1" >1.930000</td>
#       <td id="T_c552e_row3_col2" class="data row3 col2" >1.230000</td>
#     </tr>
#     <tr>
#       <th id="T_c552e_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_c552e_row4_col0" class="data row4 col0" >15.550000</td>
#       <td id="T_c552e_row4_col1" class="data row4 col1" >14.600000</td>
#       <td id="T_c552e_row4_col2" class="data row4 col2" >13.570000</td>
#     </tr>
#     <tr>
#       <th id="T_c552e_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_c552e_row5_col0" class="data row5 col0" >9.890000</td>
#       <td id="T_c552e_row5_col1" class="data row5 col1" >15.990000</td>
#       <td id="T_c552e_row5_col2" class="data row5 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c552e_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_c552e_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_c552e_row6_col1" class="data row6 col1" >0.130000</td>
#       <td id="T_c552e_row6_col2" class="data row6 col2" >0.390000</td>
#     </tr>
#     <tr>
#       <th id="T_c552e_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_c552e_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_c552e_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_c552e_row7_col2" class="data row7 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c552e_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_c552e_row8_col0" class="data row8 col0" >0.930000</td>
#       <td id="T_c552e_row8_col1" class="data row8 col1" >0.830000</td>
#       <td id="T_c552e_row8_col2" class="data row8 col2" >0.780000</td>
#     </tr>
#     <tr>
#       <th id="T_c552e_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_c552e_row9_col0" class="data row9 col0" >3.560000</td>
#       <td id="T_c552e_row9_col1" class="data row9 col1" >7.400000</td>
#       <td id="T_c552e_row9_col2" class="data row9 col2" >6.540000</td>
#     </tr>
#     <tr>
#       <th id="T_c552e_level0_row10" class="row_heading level0 row10" >education</th>
#       <td id="T_c552e_row10_col0" class="data row10 col0" >1.200000</td>
#       <td id="T_c552e_row10_col1" class="data row10 col1" >0.940000</td>
#       <td id="T_c552e_row10_col2" class="data row10 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c552e_level0_row11" class="row_heading level0 row11" >gender</th>
#       <td id="T_c552e_row11_col0" class="data row11 col0" >0.380000</td>
#       <td id="T_c552e_row11_col1" class="data row11 col1" >0.360000</td>
#       <td id="T_c552e_row11_col2" class="data row11 col2" >0.380000</td>
#     </tr>
#     <tr>
#       <th id="T_c552e_level0_row12" class="row_heading level0 row12" >constant</th>
#       <td id="T_c552e_row12_col0" class="data row12 col0" >1.000000</td>
#       <td id="T_c552e_row12_col1" class="data row12 col1" >1.000000</td>
#       <td id="T_c552e_row12_col2" class="data row12 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# lowscore | score | nopromo+returns

# %% [markdown]
# ##### 4 clusters

# %%
kmeans = KMeans(n_clusters = 4, init='k-means++', n_init=20,  random_state = 1).fit(sample_st_scl)
sample_original['st_kmeans4'] = kmeans.predict(sample_st_scl)

# %%
groupby_mean(sample_original, 'st_kmeans4', True)
# Out:
# # observations per cluster: [937, 22008, 1272, 209]
# <style type="text/css">
# #T_a86b9_row0_col0, #T_a86b9_row0_col1, #T_a86b9_row0_col2, #T_a86b9_row1_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a86b9_row0_col3 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_a86b9_row1_col0 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_a86b9_row1_col1 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_a86b9_row1_col2 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_a86b9_row2_col0 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_a86b9_row2_col1 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_a86b9_row2_col2 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_a86b9_row2_col3 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_a86b9_row3_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_a86b9_row3_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_a86b9_row3_col2, #T_a86b9_row8_col2, #T_a86b9_row8_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_a86b9_row3_col3, #T_a86b9_row6_col0, #T_a86b9_row8_col0, #T_a86b9_row8_col1, #T_a86b9_row10_col0, #T_a86b9_row12_col0, #T_a86b9_row12_col1, #T_a86b9_row12_col2 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_a86b9_row4_col0 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_a86b9_row4_col1 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_a86b9_row4_col2 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_a86b9_row4_col3 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_a86b9_row5_col0 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_a86b9_row5_col1 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_a86b9_row5_col2, #T_a86b9_row5_col3, #T_a86b9_row6_col1, #T_a86b9_row6_col2, #T_a86b9_row7_col0, #T_a86b9_row7_col1, #T_a86b9_row7_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a86b9_row6_col3, #T_a86b9_row11_col0, #T_a86b9_row11_col1, #T_a86b9_row11_col2, #T_a86b9_row11_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_a86b9_row7_col3, #T_a86b9_row12_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_a86b9_row9_col0 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_a86b9_row9_col1 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_a86b9_row9_col2 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_a86b9_row9_col3 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_a86b9_row10_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_a86b9_row10_col2, #T_a86b9_row10_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a86b9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >st_kmeans4</th>
#       <th id="T_a86b9_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a86b9_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_a86b9_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_a86b9_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a86b9_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_a86b9_row0_col0" class="data row0 col0" >39.440000</td>
#       <td id="T_a86b9_row0_col1" class="data row0 col1" >38.050000</td>
#       <td id="T_a86b9_row0_col2" class="data row0 col2" >38.780000</td>
#       <td id="T_a86b9_row0_col3" class="data row0 col3" >41.760000</td>
#     </tr>
#     <tr>
#       <th id="T_a86b9_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_a86b9_row1_col0" class="data row1 col0" >38.250000</td>
#       <td id="T_a86b9_row1_col1" class="data row1 col1" >28.730000</td>
#       <td id="T_a86b9_row1_col2" class="data row1 col2" >29.050000</td>
#       <td id="T_a86b9_row1_col3" class="data row1 col3" >47.880000</td>
#     </tr>
#     <tr>
#       <th id="T_a86b9_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_a86b9_row2_col0" class="data row2 col0" >16.180000</td>
#       <td id="T_a86b9_row2_col1" class="data row2 col1" >14.920000</td>
#       <td id="T_a86b9_row2_col2" class="data row2 col2" >15.020000</td>
#       <td id="T_a86b9_row2_col3" class="data row2 col3" >17.630000</td>
#     </tr>
#     <tr>
#       <th id="T_a86b9_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_a86b9_row3_col0" class="data row3 col0" >1.950000</td>
#       <td id="T_a86b9_row3_col1" class="data row3 col1" >2.000000</td>
#       <td id="T_a86b9_row3_col2" class="data row3 col2" >0.670000</td>
#       <td id="T_a86b9_row3_col3" class="data row3 col3" >1.230000</td>
#     </tr>
#     <tr>
#       <th id="T_a86b9_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_a86b9_row4_col0" class="data row4 col0" >14.720000</td>
#       <td id="T_a86b9_row4_col1" class="data row4 col1" >15.280000</td>
#       <td id="T_a86b9_row4_col2" class="data row4 col2" >15.760000</td>
#       <td id="T_a86b9_row4_col3" class="data row4 col3" >13.570000</td>
#     </tr>
#     <tr>
#       <th id="T_a86b9_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_a86b9_row5_col0" class="data row5 col0" >31.440000</td>
#       <td id="T_a86b9_row5_col1" class="data row5 col1" >11.410000</td>
#       <td id="T_a86b9_row5_col2" class="data row5 col2" >0.150000</td>
#       <td id="T_a86b9_row5_col3" class="data row5 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a86b9_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_a86b9_row6_col0" class="data row6 col0" >1.000000</td>
#       <td id="T_a86b9_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_a86b9_row6_col2" class="data row6 col2" >0.010000</td>
#       <td id="T_a86b9_row6_col3" class="data row6 col3" >0.390000</td>
#     </tr>
#     <tr>
#       <th id="T_a86b9_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_a86b9_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_a86b9_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_a86b9_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_a86b9_row7_col3" class="data row7 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a86b9_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_a86b9_row8_col0" class="data row8 col0" >0.990000</td>
#       <td id="T_a86b9_row8_col1" class="data row8 col1" >0.920000</td>
#       <td id="T_a86b9_row8_col2" class="data row8 col2" >0.630000</td>
#       <td id="T_a86b9_row8_col3" class="data row8 col3" >0.780000</td>
#     </tr>
#     <tr>
#       <th id="T_a86b9_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_a86b9_row9_col0" class="data row9 col0" >5.160000</td>
#       <td id="T_a86b9_row9_col1" class="data row9 col1" >4.630000</td>
#       <td id="T_a86b9_row9_col2" class="data row9 col2" >4.430000</td>
#       <td id="T_a86b9_row9_col3" class="data row9 col3" >6.540000</td>
#     </tr>
#     <tr>
#       <th id="T_a86b9_level0_row10" class="row_heading level0 row10" >education</th>
#       <td id="T_a86b9_row10_col0" class="data row10 col0" >0.930000</td>
#       <td id="T_a86b9_row10_col1" class="data row10 col1" >1.140000</td>
#       <td id="T_a86b9_row10_col2" class="data row10 col2" >nan</td>
#       <td id="T_a86b9_row10_col3" class="data row10 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a86b9_level0_row11" class="row_heading level0 row11" >gender</th>
#       <td id="T_a86b9_row11_col0" class="data row11 col0" >0.370000</td>
#       <td id="T_a86b9_row11_col1" class="data row11 col1" >0.380000</td>
#       <td id="T_a86b9_row11_col2" class="data row11 col2" >0.380000</td>
#       <td id="T_a86b9_row11_col3" class="data row11 col3" >0.380000</td>
#     </tr>
#     <tr>
#       <th id="T_a86b9_level0_row12" class="row_heading level0 row12" >constant</th>
#       <td id="T_a86b9_row12_col0" class="data row12 col0" >1.000000</td>
#       <td id="T_a86b9_row12_col1" class="data row12 col1" >1.000000</td>
#       <td id="T_a86b9_row12_col2" class="data row12 col2" >1.000000</td>
#       <td id="T_a86b9_row12_col3" class="data row12 col3" >1.000000</td>

# %% [markdown]
# promo+returns | general | nopromo | nopromo+score+returns

# %% [markdown]
# ##### 6 clusters

# %%
kmeans = KMeans(n_clusters = 6, init='k-means++', n_init=20,  random_state = 1).fit(sample_st_scl)
sample_original['st_kmeans6'] = kmeans.predict(sample_st_scl)

# %%
groupby_mean(sample_original, 'st_kmeans6', True)
# Out:
# # observations per cluster: [5002, 10051, 209, 937, 6955, 1272]
# <style type="text/css">
# #T_143b9_row0_col0 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_143b9_row0_col1, #T_143b9_row0_col3, #T_143b9_row0_col4, #T_143b9_row0_col5, #T_143b9_row1_col0, #T_143b9_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_143b9_row0_col2 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_143b9_row1_col1 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_143b9_row1_col3 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_143b9_row1_col4 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_143b9_row1_col5 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_143b9_row2_col0 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_143b9_row2_col1 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_143b9_row2_col2 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_143b9_row2_col3 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_143b9_row2_col4 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_143b9_row2_col5 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_143b9_row3_col0, #T_143b9_row3_col2, #T_143b9_row6_col3, #T_143b9_row8_col1, #T_143b9_row8_col3, #T_143b9_row10_col3, #T_143b9_row12_col3, #T_143b9_row12_col4, #T_143b9_row12_col5 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_143b9_row3_col1, #T_143b9_row3_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_143b9_row3_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_143b9_row3_col5, #T_143b9_row8_col2, #T_143b9_row8_col5, #T_143b9_row10_col0, #T_143b9_row10_col4, #T_143b9_row12_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_143b9_row4_col0 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_143b9_row4_col1 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_143b9_row4_col2 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_143b9_row4_col3 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_143b9_row4_col4 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_143b9_row4_col5 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_143b9_row5_col0 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_143b9_row5_col1 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_143b9_row5_col2, #T_143b9_row5_col5, #T_143b9_row6_col0, #T_143b9_row6_col1, #T_143b9_row6_col4, #T_143b9_row6_col5, #T_143b9_row7_col0, #T_143b9_row7_col1, #T_143b9_row7_col3, #T_143b9_row7_col4, #T_143b9_row7_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_143b9_row5_col3 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_143b9_row5_col4 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_143b9_row6_col2, #T_143b9_row8_col0, #T_143b9_row11_col1, #T_143b9_row11_col2, #T_143b9_row11_col3, #T_143b9_row11_col4, #T_143b9_row11_col5 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_143b9_row7_col2, #T_143b9_row8_col4, #T_143b9_row12_col2 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_143b9_row9_col0 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_143b9_row9_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_143b9_row9_col2 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_143b9_row9_col3 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_143b9_row9_col4 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_143b9_row9_col5 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_143b9_row10_col1 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_143b9_row10_col2, #T_143b9_row10_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_143b9_row11_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_143b9_row12_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# </style>
# <table id="T_143b9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >st_kmeans6</th>
#       <th id="T_143b9_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_143b9_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_143b9_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_143b9_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_143b9_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_143b9_level0_col5" class="col_heading level0 col5" >5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_143b9_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_143b9_row0_col0" class="data row0 col0" >40.570000</td>
#       <td id="T_143b9_row0_col1" class="data row0 col1" >36.210000</td>
#       <td id="T_143b9_row0_col2" class="data row0 col2" >41.760000</td>
#       <td id="T_143b9_row0_col3" class="data row0 col3" >39.440000</td>
#       <td id="T_143b9_row0_col4" class="data row0 col4" >38.910000</td>
#       <td id="T_143b9_row0_col5" class="data row0 col5" >38.780000</td>
#     </tr>
#     <tr>
#       <th id="T_143b9_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_143b9_row1_col0" class="data row1 col0" >79.900000</td>
#       <td id="T_143b9_row1_col1" class="data row1 col1" >11.150000</td>
#       <td id="T_143b9_row1_col2" class="data row1 col2" >47.880000</td>
#       <td id="T_143b9_row1_col3" class="data row1 col3" >38.250000</td>
#       <td id="T_143b9_row1_col4" class="data row1 col4" >17.340000</td>
#       <td id="T_143b9_row1_col5" class="data row1 col5" >29.050000</td>
#     </tr>
#     <tr>
#       <th id="T_143b9_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_143b9_row2_col0" class="data row2 col0" >16.490000</td>
#       <td id="T_143b9_row2_col1" class="data row2 col1" >8.540000</td>
#       <td id="T_143b9_row2_col2" class="data row2 col2" >17.630000</td>
#       <td id="T_143b9_row2_col3" class="data row2 col3" >16.180000</td>
#       <td id="T_143b9_row2_col4" class="data row2 col4" >22.990000</td>
#       <td id="T_143b9_row2_col5" class="data row2 col5" >15.020000</td>
#     </tr>
#     <tr>
#       <th id="T_143b9_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_143b9_row3_col0" class="data row3 col0" >2.000000</td>
#       <td id="T_143b9_row3_col1" class="data row3 col1" >2.000000</td>
#       <td id="T_143b9_row3_col2" class="data row3 col2" >1.230000</td>
#       <td id="T_143b9_row3_col3" class="data row3 col3" >1.950000</td>
#       <td id="T_143b9_row3_col4" class="data row3 col4" >2.000000</td>
#       <td id="T_143b9_row3_col5" class="data row3 col5" >0.670000</td>
#     </tr>
#     <tr>
#       <th id="T_143b9_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_143b9_row4_col0" class="data row4 col0" >14.770000</td>
#       <td id="T_143b9_row4_col1" class="data row4 col1" >15.570000</td>
#       <td id="T_143b9_row4_col2" class="data row4 col2" >13.570000</td>
#       <td id="T_143b9_row4_col3" class="data row4 col3" >14.720000</td>
#       <td id="T_143b9_row4_col4" class="data row4 col4" >15.240000</td>
#       <td id="T_143b9_row4_col5" class="data row4 col5" >15.760000</td>
#     </tr>
#     <tr>
#       <th id="T_143b9_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_143b9_row5_col0" class="data row5 col0" >12.240000</td>
#       <td id="T_143b9_row5_col1" class="data row5 col1" >12.830000</td>
#       <td id="T_143b9_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_143b9_row5_col3" class="data row5 col3" >31.440000</td>
#       <td id="T_143b9_row5_col4" class="data row5 col4" >8.760000</td>
#       <td id="T_143b9_row5_col5" class="data row5 col5" >0.150000</td>
#     </tr>
#     <tr>
#       <th id="T_143b9_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_143b9_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_143b9_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_143b9_row6_col2" class="data row6 col2" >0.390000</td>
#       <td id="T_143b9_row6_col3" class="data row6 col3" >1.000000</td>
#       <td id="T_143b9_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_143b9_row6_col5" class="data row6 col5" >0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_143b9_level0_row7" cla

# %% [markdown]
# score | lowscore | nopromo1 | promo+returns | antiques | nopromo2

# %% [markdown]
# #### Comparison

# %%
clusters_comparison(sample_original, 'st_kmeans4', 'st_kmeans3')
# Out:
#                       st_kmeans3 0 Cluster  st_kmeans3 1 Cluster  \
# st_kmeans4 0 Cluster                    86                   851
# st_kmeans4 1 Cluster                 16417                  5591
# st_kmeans4 2 Cluster                   948                   324
# st_kmeans4 3 Cluster                     0                     0
#
#                       st_kmeans3 2 Cluster
# st_kmeans4 0 Cluster                     0
# st_kmeans4 1 Cluster                     0
# st_kmeans4 2 Cluster                     0
# st_kmeans4 3 Cluster                   209

# %%
clusters_comparison(sample_original, 'st_kmeans6', 'st_kmeans4')
# Out:
#                       st_kmeans4 0 Cluster  st_kmeans4 1 Cluster  \
# st_kmeans6 0 Cluster                     0                  5002
# st_kmeans6 1 Cluster                     0                 10051
# st_kmeans6 2 Cluster                     0                     0
# st_kmeans6 3 Cluster                   937                     0
# st_kmeans6 4 Cluster                     0                  6955
# st_kmeans6 5 Cluster                     0                     0
#
#                       st_kmeans4 2 Cluster  st_kmeans4 3 Cluster
# st_kmeans6 0 Cluster                     0                     0
# st_kmeans6 1 Cluster                     0                     0
# st_kmeans6 2 Cluster                     0                   209
# st_kmeans6 3 Cluster                     0                     0
# st_kmeans6 4 Cluster                     0                     0
# st_kmeans6 5 Cluster                  1272                     0

# %% [markdown]
# ### MinMax Scaler <a id='km-mm'></a>

# %% [markdown]
# #### Plot

# %%
plot_inertia_and_silhouette(sample_mm_scl, 2, 10)

# %% [markdown]
# #### Models

# %% [markdown]
# ##### 3 clusters

# %%
kmeans = KMeans(n_clusters = 3, init='k-means++', n_init=20,  random_state = 1).fit(sample_mm_scl)
sample_original['mm_kmeans3'] = kmeans.predict(sample_mm_scl)

# %%
groupby_mean(sample_original, 'mm_kmeans3', True)
# Out:
# # observations per cluster: [18066, 5335, 1025]
# <style type="text/css">
# #T_6770a_row0_col0, #T_6770a_row0_col2, #T_6770a_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_6770a_row0_col1 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_6770a_row1_col0, #T_6770a_row4_col2 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_6770a_row1_col2 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_6770a_row2_col0 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_6770a_row2_col1 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_6770a_row2_col2, #T_6770a_row4_col0 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_6770a_row3_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_6770a_row3_col1, #T_6770a_row8_col0, #T_6770a_row12_col0 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_6770a_row3_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_6770a_row4_col1 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_6770a_row5_col0 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_6770a_row5_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_6770a_row5_col2 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_6770a_row6_col0, #T_6770a_row6_col1, #T_6770a_row7_col0, #T_6770a_row7_col1, #T_6770a_row7_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_6770a_row6_col2, #T_6770a_row8_col2, #T_6770a_row10_col2, #T_6770a_row12_col2 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_6770a_row8_col1, #T_6770a_row11_col0 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_6770a_row9_col0 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_6770a_row9_col1 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_6770a_row9_col2 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_6770a_row10_col0 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_6770a_row10_col1, #T_6770a_row12_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_6770a_row11_col1, #T_6770a_row11_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_6770a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mm_kmeans3</th>
#       <th id="T_6770a_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_6770a_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_6770a_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6770a_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_6770a_row0_col0" class="data row0 col0" >37.400000</td>
#       <td id="T_6770a_row0_col1" class="data row0 col1" >40.530000</td>
#       <td id="T_6770a_row0_col2" class="data row0 col2" >39.690000</td>
#     </tr>
#     <tr>
#       <th id="T_6770a_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_6770a_row1_col0" class="data row1 col0" >13.670000</td>
#       <td id="T_6770a_row1_col1" class="data row1 col1" >80.220000</td>
#       <td id="T_6770a_row1_col2" class="data row1 col2" >39.260000</td>
#     </tr>
#     <tr>
#       <th id="T_6770a_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_6770a_row2_col0" class="data row2 col0" >14.480000</td>
#       <td id="T_6770a_row2_col1" class="data row2 col1" >16.480000</td>
#       <td id="T_6770a_row2_col2" class="data row2 col2" >16.380000</td>
#     </tr>
#     <tr>
#       <th id="T_6770a_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_6770a_row3_col0" class="data row3 col0" >1.930000</td>
#       <td id="T_6770a_row3_col1" class="data row3 col1" >1.920000</td>
#       <td id="T_6770a_row3_col2" class="data row3 col2" >1.880000</td>
#     </tr>
#     <tr>
#       <th id="T_6770a_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_6770a_row4_col0" class="data row4 col0" >15.440000</td>
#       <td id="T_6770a_row4_col1" class="data row4 col1" >14.840000</td>
#       <td id="T_6770a_row4_col2" class="data row4 col2" >14.570000</td>
#     </tr>
#     <tr>
#       <th id="T_6770a_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_6770a_row5_col0" class="data row5 col0" >10.550000</td>
#       <td id="T_6770a_row5_col1" class="data row5 col1" >11.390000</td>
#       <td id="T_6770a_row5_col2" class="data row5 col2" >28.740000</td>
#     </tr>
#     <tr>
#       <th id="T_6770a_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_6770a_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_6770a_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_6770a_row6_col2" class="data row6 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6770a_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_6770a_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_6770a_row7_col1" class="data row7 col1" >0.010000</td>
#       <td id="T_6770a_row7_col2" class="data row7 col2" >0.080000</td>
#     </tr>
#     <tr>
#       <th id="T_6770a_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_6770a_row8_col0" class="data row8 col0" >0.930000</td>
#       <td id="T_6770a_row8_col1" class="data row8 col1" >0.800000</td>
#       <td id="T_6770a_row8_col2" class="data row8 col2" >0.970000</td>
#     </tr>
#     <tr>
#       <th id="T_6770a_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_6770a_row9_col0" class="data row9 col0" >3.720000</td>
#       <td id="T_6770a_row9_col1" class="data row9 col1" >7.670000</td>
#       <td id="T_6770a_row9_col2" class="data row9 col2" >5.300000</td>
#     </tr>
#     <tr>
#       <th id="T_6770a_level0_row10" class="row_heading level0 row10" >education</th>
#       <td id="T_6770a_row10_col0" class="data row10 col0" >1.180000</td>
#       <td id="T_6770a_row10_col1" class="data row10 col1" >1.010000</td>
#       <td id="T_6770a_row10_col2" class="data row10 col2" >0.930000</td>
#     </tr>
#     <tr>
#       <th id="T_6770a_level0_row11" class="row_heading level0 row11" >gender</th>
#       <td id="T_6770a_row11_col0" class="data row11 col0" >0.380000</td>
#       <td id="T_6770a_row11_col1" class="data row11 col1" >0.360000</td>
#       <td id="T_6770a_row11_col2" class="data row11 col2" >0.370000</td>
#     </tr>
#     <tr>
#       <th id="T_6770a_level0_row12" class="row_heading level0 row12" >constant</th>
#       <td id="T_6770a_row12_col0" class="data row12 col0" >1.000000</td>
#       <td id="T_6770a_row12_col1" class="data row12 col1" >1.000000</td>
#       <td id="T_6770a_row12_col2" class="data row12 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# general | score | promo+returns

# %% [markdown]
# ##### 4 clusters

# %%
kmeans = KMeans(n_clusters = 4, init='k-means++', n_init=20,  random_state = 1).fit(sample_mm_scl)
sample_original['mm_kmeans4'] = kmeans.predict(sample_mm_scl)

# %%
groupby_mean(sample_original, 'mm_kmeans4', True)
# Out:
# # observations per cluster: [10347, 5335, 7719, 1025]
# <style type="text/css">
# #T_d3a35_row0_col0, #T_d3a35_row0_col2, #T_d3a35_row0_col3, #T_d3a35_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d3a35_row0_col1 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_d3a35_row1_col0 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_d3a35_row1_col2 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_d3a35_row1_col3 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_d3a35_row2_col0 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_d3a35_row2_col1 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_d3a35_row2_col2 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_d3a35_row2_col3 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_d3a35_row3_col0, #T_d3a35_row3_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_d3a35_row3_col1, #T_d3a35_row8_col0, #T_d3a35_row12_col0, #T_d3a35_row12_col2 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_d3a35_row3_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_d3a35_row4_col0 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_d3a35_row4_col1 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_d3a35_row4_col2 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_d3a35_row4_col3 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_d3a35_row5_col0 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_d3a35_row5_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_d3a35_row5_col2 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_d3a35_row5_col3 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_d3a35_row6_col0, #T_d3a35_row6_col1, #T_d3a35_row6_col2, #T_d3a35_row7_col0, #T_d3a35_row7_col1, #T_d3a35_row7_col2, #T_d3a35_row7_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d3a35_row6_col3, #T_d3a35_row8_col2, #T_d3a35_row8_col3, #T_d3a35_row10_col3, #T_d3a35_row12_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_d3a35_row8_col1, #T_d3a35_row11_col0, #T_d3a35_row11_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_d3a35_row9_col0 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_d3a35_row9_col1 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_d3a35_row9_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_d3a35_row9_col3 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_d3a35_row10_col0 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_d3a35_row10_col1, #T_d3a35_row10_col2, #T_d3a35_row12_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_d3a35_row11_col1, #T_d3a35_row11_col3 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_d3a35">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mm_kmeans4</th>
#       <th id="T_d3a35_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_d3a35_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_d3a35_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_d3a35_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3a35_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_d3a35_row0_col0" class="data row0 col0" >37.590000</td>
#       <td id="T_d3a35_row0_col1" class="data row0 col1" >40.530000</td>
#       <td id="T_d3a35_row0_col2" class="data row0 col2" >37.130000</td>
#       <td id="T_d3a35_row0_col3" class="data row0 col3" >39.690000</td>
#     </tr>
#     <tr>
#       <th id="T_d3a35_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_d3a35_row1_col0" class="data row1 col0" >8.770000</td>
#       <td id="T_d3a35_row1_col1" class="data row1 col1" >80.220000</td>
#       <td id="T_d3a35_row1_col2" class="data row1 col2" >20.230000</td>
#       <td id="T_d3a35_row1_col3" class="data row1 col3" >39.260000</td>
#     </tr>
#     <tr>
#       <th id="T_d3a35_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_d3a35_row2_col0" class="data row2 col0" >8.530000</td>
#       <td id="T_d3a35_row2_col1" class="data row2 col1" >16.480000</td>
#       <td id="T_d3a35_row2_col2" class="data row2 col2" >22.450000</td>
#       <td id="T_d3a35_row2_col3" class="data row2 col3" >16.380000</td>
#     </tr>
#     <tr>
#       <th id="T_d3a35_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_d3a35_row3_col0" class="data row3 col0" >1.940000</td>
#       <td id="T_d3a35_row3_col1" class="data row3 col1" >1.920000</td>
#       <td id="T_d3a35_row3_col2" class="data row3 col2" >1.910000</td>
#       <td id="T_d3a35_row3_col3" class="data row3 col3" >1.880000</td>
#     </tr>
#     <tr>
#       <th id="T_d3a35_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_d3a35_row4_col0" class="data row4 col0" >15.650000</td>
#       <td id="T_d3a35_row4_col1" class="data row4 col1" >14.840000</td>
#       <td id="T_d3a35_row4_col2" class="data row4 col2" >15.160000</td>
#       <td id="T_d3a35_row4_col3" class="data row4 col3" >14.570000</td>
#     </tr>
#     <tr>
#       <th id="T_d3a35_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_d3a35_row5_col0" class="data row5 col0" >11.800000</td>
#       <td id="T_d3a35_row5_col1" class="data row5 col1" >11.390000</td>
#       <td id="T_d3a35_row5_col2" class="data row5 col2" >8.870000</td>
#       <td id="T_d3a35_row5_col3" class="data row5 col3" >28.740000</td>
#     </tr>
#     <tr>
#       <th id="T_d3a35_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_d3a35_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_d3a35_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_d3a35_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_d3a35_row6_col3" class="data row6 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d3a35_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_d3a35_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_d3a35_row7_col1" class="data row7 col1" >0.010000</td>
#       <td id="T_d3a35_row7_col2" class="data row7 col2" >0.010000</td>
#       <td id="T_d3a35_row7_col3" class="data row7 col3" >0.080000</td>
#     </tr>
#     <tr>
#       <th id="T_d3a35_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_d3a35_row8_col0" class="data row8 col0" >0.980000</td>
#       <td id="T_d3a35_row8_col1" class="data row8 col1" >0.800000</td>
#       <td id="T_d3a35_row8_col2" class="data row8 col2" >0.860000</td>
#       <td id="T_d3a35_row8_col3" class="data row8 col3" >0.970000</td>
#     </tr>
#     <tr>
#       <th id="T_d3a35_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_d3a35_row9_col0" class="data row9 col0" >2.490000</td>
#       <td id="T_d3a35_row9_col1" class="data row9 col1" >7.670000</td>
#       <td id="T_d3a35_row9_col2" class="data row9 col2" >5.380000</td>
#       <td id="T_d3a35_row9_col3" class="data row9 col3" >5.300000</td>
#     </tr>
#     <tr>
#       <th id="T_d3a35_level0_row10" class="row_heading level0 row10" >education</th>
#       <td id="T_d3a35_row10_col0" class="data row10 col0" >1.550000</td>
#       <td id="T_d3a35_row10_col1" class="data row10 col1" >1.010000</td>
#       <td id="T_d3a35_row10_col2" class="data row10 col2" >0.670000</td>
#       <td id="T_d3a35_row10_col3" class="data row10 col3" >0.930000</td>
#     </tr>
#     <tr>
#       <th id="T_d3a35_level0_row11" class="row_heading level0 row11" >gender</th>
#       <td id="T_d3a35_row11_col0" class="data row11 col0" >0.390000</td>
#       <td id="T_d3a35_row11_col1" class="data row11 col1" >0.360000</td>
#       <td id="T_d3a35_row11_col2" class="data row11 col2" >0.370000</td>
#       <td id="T_d3a35_row11_col3" class="data row11 col3" >0.370000</td>
#     </tr>
#     <tr>
#       <th id="T_d3a35_level0_row12" class="row_heading level0 row12" >constant</th>
#       <td id="T_d3a35_row12_col0" class="data row12 col0" >1.000000</td>
#       <td id="T_d3a35_row12_col1" class="data row12 col1" >1.000000</td>
#       <td id="T_d3a35_row12_col2" class=

# %% [markdown]
# lowscore | score | antiques+lowpromo | promo+returns

# %% [markdown]
# ##### 5 clusters

# %%
kmeans = KMeans(n_clusters = 5, init='k-means++', n_init=20,  random_state = 1).fit(sample_mm_scl)
sample_original['mm_kmeans5'] = kmeans.predict(sample_mm_scl)

# %%
groupby_mean(sample_original, 'mm_kmeans5', True)
# Out:
# # observations per cluster: [7244, 1025, 5243, 1105, 9809]
# <style type="text/css">
# #T_6c9d8_row0_col0, #T_6c9d8_row0_col1, #T_6c9d8_row0_col3, #T_6c9d8_row0_col4, #T_6c9d8_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_6c9d8_row0_col2 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_6c9d8_row1_col0 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_6c9d8_row1_col1 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_6c9d8_row1_col3 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_6c9d8_row1_col4 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_6c9d8_row2_col0 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_6c9d8_row2_col1 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_6c9d8_row2_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_6c9d8_row2_col3 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_6c9d8_row2_col4 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_6c9d8_row3_col0, #T_6c9d8_row3_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_6c9d8_row3_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_6c9d8_row3_col2, #T_6c9d8_row8_col0, #T_6c9d8_row8_col4, #T_6c9d8_row12_col0, #T_6c9d8_row12_col3, #T_6c9d8_row12_col4 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_6c9d8_row3_col3, #T_6c9d8_row8_col3, #T_6c9d8_row10_col0, #T_6c9d8_row10_col2, #T_6c9d8_row12_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_6c9d8_row4_col0 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_6c9d8_row4_col1 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_6c9d8_row4_col2 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_6c9d8_row4_col3 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_6c9d8_row4_col4 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_6c9d8_row5_col0 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_6c9d8_row5_col1 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_6c9d8_row5_col2 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_6c9d8_row5_col3, #T_6c9d8_row6_col0, #T_6c9d8_row6_col2, #T_6c9d8_row6_col3, #T_6c9d8_row6_col4, #T_6c9d8_row7_col0, #T_6c9d8_row7_col1, #T_6c9d8_row7_col2, #T_6c9d8_row7_col3, #T_6c9d8_row7_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_6c9d8_row5_col4 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_6c9d8_row6_col1, #T_6c9d8_row8_col1, #T_6c9d8_row10_col1, #T_6c9d8_row12_col1 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_6c9d8_row8_col2, #T_6c9d8_row11_col0, #T_6c9d8_row11_col3, #T_6c9d8_row11_col4 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_6c9d8_row9_col0 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_6c9d8_row9_col1 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_6c9d8_row9_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_6c9d8_row9_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_6c9d8_row9_col4 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_6c9d8_row10_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_6c9d8_row10_col4 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_6c9d8_row11_col1, #T_6c9d8_row11_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_6c9d8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mm_kmeans5</th>
#       <th id="T_6c9d8_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_6c9d8_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_6c9d8_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_6c9d8_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_6c9d8_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c9d8_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_6c9d8_row0_col0" class="data row0 col0" >37.070000</td>
#       <td id="T_6c9d8_row0_col1" class="data row0 col1" >39.690000</td>
#       <td id="T_6c9d8_row0_col2" class="data row0 col2" >40.480000</td>
#       <td id="T_6c9d8_row0_col3" class="data row0 col3" >38.900000</td>
#       <td id="T_6c9d8_row0_col4" class="data row0 col4" >37.520000</td>
#     </tr>
#     <tr>
#       <th id="T_6c9d8_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_6c9d8_row1_col0" class="data row1 col0" >20.440000</td>
#       <td id="T_6c9d8_row1_col1" class="data row1 col1" >39.260000</td>
#       <td id="T_6c9d8_row1_col2" class="data row1 col2" >80.210000</td>
#       <td id="T_6c9d8_row1_col3" class="data row1 col3" >18.400000</td>
#       <td id="T_6c9d8_row1_col4" class="data row1 col4" >8.760000</td>
#     </tr>
#     <tr>
#       <th id="T_6c9d8_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_6c9d8_row2_col0" class="data row2 col0" >22.490000</td>
#       <td id="T_6c9d8_row2_col1" class="data row2 col1" >16.380000</td>
#       <td id="T_6c9d8_row2_col2" class="data row2 col2" >16.480000</td>
#       <td id="T_6c9d8_row2_col3" class="data row2 col3" >14.940000</td>
#       <td id="T_6c9d8_row2_col4" class="data row2 col4" >8.520000</td>
#     </tr>
#     <tr>
#       <th id="T_6c9d8_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_6c9d8_row3_col0" class="data row3 col0" >2.000000</td>
#       <td id="T_6c9d8_row3_col1" class="data row3 col1" >1.880000</td>
#       <td id="T_6c9d8_row3_col2" class="data row3 col2" >1.950000</td>
#       <td id="T_6c9d8_row3_col3" class="data row3 col3" >0.630000</td>
#       <td id="T_6c9d8_row3_col4" class="data row3 col4" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6c9d8_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_6c9d8_row4_col0" class="data row4 col0" >15.150000</td>
#       <td id="T_6c9d8_row4_col1" class="data row4 col1" >14.570000</td>
#       <td id="T_6c9d8_row4_col2" class="data row4 col2" >14.830000</td>
#       <td id="T_6c9d8_row4_col3" class="data row4 col3" >15.680000</td>
#       <td id="T_6c9d8_row4_col4" class="data row4 col4" >15.620000</td>
#     </tr>
#     <tr>
#       <th id="T_6c9d8_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_6c9d8_row5_col0" class="data row5 col0" >9.480000</td>
#       <td id="T_6c9d8_row5_col1" class="data row5 col1" >28.740000</td>
#       <td id="T_6c9d8_row5_col2" class="data row5 col2" >11.590000</td>
#       <td id="T_6c9d8_row5_col3" class="data row5 col3" >0.030000</td>
#       <td id="T_6c9d8_row5_col4" class="data row5 col4" >12.420000</td>
#     </tr>
#     <tr>
#       <th id="T_6c9d8_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_6c9d8_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_6c9d8_row6_col1" class="data row6 col1" >1.000000</td>
#       <td id="T_6c9d8_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_6c9d8_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_6c9d8_row6_col4" class="data row6 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6c9d8_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_6c9d8_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_6c9d8_row7_col1" class="data row7 col1" >0.080000</td>
#       <td id="T_6c9d8_row7_col2" class="data row7 col2" >0.010000</td>
#       <td id="T_6c9d8_row7_col3" class="data row7 col3" >0.050000</td>
#       <td id="T_6c9d8_row7_col4" class="data row7 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6c9d8_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_6c9d8_row8_col0" class="data row8 col0" >0.880000</td>
#       <td id="T_6c9d8_row8_col1" class="data row8 col1" >0.970000</td>
#       <td id="T_6c9d8_row8_col2" class="data row8 col2" >0.810000</td>
#       <td id="T_6c9d8_row8_col3" class="data row8 col3" >0.610000</td>
#       <td id="T_6c9d8_row8_col4" class="data row8 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6c9d8_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_6c9d8_row9_col0" class="data row9 col0" >5.440000</td>
#       <td id="T_6c9d8_row9_col1" class="data row9 col1" >5.3

# %% [markdown]
# antiques | promo+returns | score | nopromo | lowscore+new

# %% [markdown]
# ##### 6 clusters

# %%
kmeans = KMeans(n_clusters = 6, init='k-means++', n_init=20,  random_state = 1).fit(sample_mm_scl)
sample_original['mm_kmeans6'] = kmeans.predict(sample_mm_scl)

# %%
groupby_mean(sample_original, 'mm_kmeans6', True)
# Out:
# # observations per cluster: [1104, 5359, 5243, 5611, 6084, 1025]
# <style type="text/css">
# #T_15f3f_row0_col0, #T_15f3f_row0_col1, #T_15f3f_row0_col3, #T_15f3f_row0_col4, #T_15f3f_row0_col5, #T_15f3f_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_15f3f_row0_col2 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_15f3f_row1_col0 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_15f3f_row1_col1 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_15f3f_row1_col3, #T_15f3f_row2_col0 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_15f3f_row1_col4, #T_15f3f_row2_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_15f3f_row1_col5 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_15f3f_row2_col1 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_15f3f_row2_col3 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_15f3f_row2_col4, #T_15f3f_row5_col1 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_15f3f_row2_col5 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_15f3f_row3_col0, #T_15f3f_row8_col0, #T_15f3f_row10_col1, #T_15f3f_row10_col2, #T_15f3f_row12_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_15f3f_row3_col1, #T_15f3f_row3_col3, #T_15f3f_row3_col4, #T_15f3f_row9_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_15f3f_row3_col2, #T_15f3f_row8_col1, #T_15f3f_row8_col3, #T_15f3f_row12_col0, #T_15f3f_row12_col1, #T_15f3f_row12_col4 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_15f3f_row3_col5 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_15f3f_row4_col0 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_15f3f_row4_col1 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_15f3f_row4_col2 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_15f3f_row4_col3 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_15f3f_row4_col4 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_15f3f_row4_col5 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_15f3f_row5_col0, #T_15f3f_row6_col0, #T_15f3f_row6_col1, #T_15f3f_row6_col2, #T_15f3f_row6_col3, #T_15f3f_row6_col4, #T_15f3f_row7_col0, #T_15f3f_row7_col1, #T_15f3f_row7_col2, #T_15f3f_row7_col3, #T_15f3f_row7_col4, #T_15f3f_row7_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_15f3f_row5_col2, #T_15f3f_row9_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_15f3f_row5_col3 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_15f3f_row5_col4 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_15f3f_row5_col5 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_15f3f_row6_col5, #T_15f3f_row8_col5, #T_15f3f_row10_col5, #T_15f3f_row12_col5 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_15f3f_row8_col2, #T_15f3f_row11_col0, #T_15f3f_row11_col1, #T_15f3f_row11_col3, #T_15f3f_row11_col4 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_15f3f_row8_col4, #T_15f3f_row12_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_15f3f_row9_col0 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_15f3f_row9_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_15f3f_row9_col3 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_15f3f_row9_col5 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_15f3f_row10_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_15f3f_row10_col3, #T_15f3f_row10_col4 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_15f3f_row11_col2, #T_15f3f_row11_col5 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_15f3f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mm_kmeans6</th>
#       <th id="T_15f3f_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_15f3f_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_15f3f_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_15f3f_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_15f3f_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_15f3f_level0_col5" class="col_heading level0 col5" >5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15f3f_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_15f3f_row0_col0" class="data row0 col0" >38.910000</td>
#       <td id="T_15f3f_row0_col1" class="data row0 col1" >37.640000</td>
#       <td id="T_15f3f_row0_col2" class="data row0 col2" >40.480000</td>
#       <td id="T_15f3f_row0_col3" class="data row0 col3" >36.520000</td>
#       <td id="T_15f3f_row0_col4" class="data row0 col4" >37.810000</td>
#       <td id="T_15f3f_row0_col5" class="data row0 col5" >39.690000</td>
#     </tr>
#     <tr>
#       <th id="T_15f3f_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_15f3f_row1_col0" class="data row1 col0" >18.420000</td>
#       <td id="T_15f3f_row1_col1" class="data row1 col1" >20.190000</td>
#       <td id="T_15f3f_row1_col2" class="data row1 col2" >80.210000</td>
#       <td id="T_15f3f_row1_col3" class="data row1 col3" >14.040000</td>
#       <td id="T_15f3f_row1_col4" class="data row1 col4" >7.740000</td>
#       <td id="T_15f3f_row1_col5" class="data row1 col5" >39.260000</td>
#     </tr>
#     <tr>
#       <th id="T_15f3f_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_15f3f_row2_col0" class="data row2 col0" >14.940000</td>
#       <td id="T_15f3f_row2_col1" class="data row2 col1" >24.520000</td>
#       <td id="T_15f3f_row2_col2" class="data row2 col2" >16.480000</td>
#       <td id="T_15f3f_row2_col3" class="data row2 col3" >10.520000</td>
#       <td id="T_15f3f_row2_col4" class="data row2 col4" >9.220000</td>
#       <td id="T_15f3f_row2_col5" class="data row2 col5" >16.380000</td>
#     </tr>
#     <tr>
#       <th id="T_15f3f_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_15f3f_row3_col0" class="data row3 col0" >0.630000</td>
#       <td id="T_15f3f_row3_col1" class="data row3 col1" >2.000000</td>
#       <td id="T_15f3f_row3_col2" class="data row3 col2" >1.950000</td>
#       <td id="T_15f3f_row3_col3" class="data row3 col3" >2.000000</td>
#       <td id="T_15f3f_row3_col4" class="data row3 col4" >2.000000</td>
#       <td id="T_15f3f_row3_col5" class="data row3 col5" >1.880000</td>
#     </tr>
#     <tr>
#       <th id="T_15f3f_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_15f3f_row4_col0" class="data row4 col0" >15.690000</td>
#       <td id="T_15f3f_row4_col1" class="data row4 col1" >15.760000</td>
#       <td id="T_15f3f_row4_col2" class="data row4 col2" >14.830000</td>
#       <td id="T_15f3f_row4_col3" class="data row4 col3" >11.920000</td>
#       <td id="T_15f3f_row4_col4" class="data row4 col4" >18.360000</td>
#       <td id="T_15f3f_row4_col5" class="data row4 col5" >14.570000</td>
#     </tr>
#     <tr>
#       <th id="T_15f3f_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_15f3f_row5_col0" class="data row5 col0" >0.030000</td>
#       <td id="T_15f3f_row5_col1" class="data row5 col1" >9.250000</td>
#       <td id="T_15f3f_row5_col2" class="data row5 col2" >11.590000</td>
#       <td id="T_15f3f_row5_col3" class="data row5 col3" >11.110000</td>
#       <td id="T_15f3f_row5_col4" class="data row5 col4" >12.910000</td>
#       <td id="T_15f3f_row5_col5" class="data row5 col5" >28.740000</td>
#     </tr>
#     <tr>
#       <th id="T_15f3f_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_15f3f_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_15f3f_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_15f3f_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_15f3f_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_15f3f_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_15f3f_row6_col5" class="data row6 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_15f3f_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_15f3f_row7_col0" class="data row7 col0" >0.050000</td>
#       <td id="T_15f3f_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_

# %% [markdown]
# nopromo | antiques | score | lowscore | lowscore+new | promo+returns

# %% [markdown]
# #### Comparison

# %%
clusters_comparison(sample_original, 'mm_kmeans4', 'mm_kmeans3')
# Out:
#                       mm_kmeans3 0 Cluster  mm_kmeans3 1 Cluster  \
# mm_kmeans4 0 Cluster                 10347                     0
# mm_kmeans4 1 Cluster                     0                  5335
# mm_kmeans4 2 Cluster                  7719                     0
# mm_kmeans4 3 Cluster                     0                     0
#
#                       mm_kmeans3 2 Cluster
# mm_kmeans4 0 Cluster                     0
# mm_kmeans4 1 Cluster                     0
# mm_kmeans4 2 Cluster                     0
# mm_kmeans4 3 Cluster                  1025

# %%
clusters_comparison(sample_original, 'mm_kmeans5', 'mm_kmeans4')
# Out:
#                       mm_kmeans4 0 Cluster  mm_kmeans4 1 Cluster  \
# mm_kmeans5 0 Cluster                    33                     0
# mm_kmeans5 1 Cluster                     0                     0
# mm_kmeans5 2 Cluster                     0                  5243
# mm_kmeans5 3 Cluster                   509                    92
# mm_kmeans5 4 Cluster                  9805                     0
#
#                       mm_kmeans4 2 Cluster  mm_kmeans4 3 Cluster
# mm_kmeans5 0 Cluster                  7211                     0
# mm_kmeans5 1 Cluster                     0                  1025
# mm_kmeans5 2 Cluster                     0                     0
# mm_kmeans5 3 Cluster                   504                     0
# mm_kmeans5 4 Cluster                     4                     0

# %%
clusters_comparison(sample_original, 'mm_kmeans6', 'mm_kmeans5')
# Out:
#                       mm_kmeans5 0 Cluster  mm_kmeans5 1 Cluster  \
# mm_kmeans6 0 Cluster                     0                     0
# mm_kmeans6 1 Cluster                  5357                     0
# mm_kmeans6 2 Cluster                     0                     0
# mm_kmeans6 3 Cluster                  1377                     0
# mm_kmeans6 4 Cluster                   510                     0
# mm_kmeans6 5 Cluster                     0                  1025
#
#                       mm_kmeans5 2 Cluster  mm_kmeans5 3 Cluster  \
# mm_kmeans6 0 Cluster                     0                  1104
# mm_kmeans6 1 Cluster                     0                     0
# mm_kmeans6 2 Cluster                  5243                     0
# mm_kmeans6 3 Cluster                     0                     1
# mm_kmeans6 4 Cluster                     0                     0
# mm_kmeans6 5 Cluster                     0                     0
#
#                       mm_kmeans5 4 Cluster
# mm_kmeans6 0 Cluster                     0
# mm_kmeans6 1 Cluster                     2
# mm_kmeans6 2 Cluster                     0
# mm_kmeans6 3 Cluster                  4233
# mm_kmeans6 4 Cluster                  5574
# mm_kmeans6 5 Cluster                     0

# %% [markdown]
# ### Robust Scaler <a id='km-rb'></a>

# %% [markdown]
# #### Plot

# %%
plot_inertia_and_silhouette(sample_rb_scl, 2, 10)

# %% [markdown]
# #### Models

# %% [markdown]
# ##### 3 clusters

# %%
kmeans = KMeans(n_clusters = 3, init='k-means++', n_init=20,  random_state = 1).fit(sample_rb_scl)
sample_original['rb_kmeans3'] = kmeans.predict(sample_rb_scl)

# %%
groupby_mean(sample_original, 'rb_kmeans3', True)
# Out:
# # observations per cluster: [5098, 3236, 16092]
# <style type="text/css">
# #T_5cbe0_row0_col0 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_5cbe0_row0_col1 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_5cbe0_row0_col2, #T_5cbe0_row1_col0, #T_5cbe0_row5_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_5cbe0_row1_col1 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_5cbe0_row1_col2 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_5cbe0_row2_col0 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_5cbe0_row2_col1 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_5cbe0_row2_col2 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_5cbe0_row3_col0, #T_5cbe0_row12_col2 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_5cbe0_row3_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_5cbe0_row3_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_5cbe0_row4_col0 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_5cbe0_row4_col1 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_5cbe0_row4_col2 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_5cbe0_row5_col0, #T_5cbe0_row9_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_5cbe0_row5_col2 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_5cbe0_row6_col0, #T_5cbe0_row6_col1, #T_5cbe0_row6_col2, #T_5cbe0_row7_col0, #T_5cbe0_row7_col1, #T_5cbe0_row7_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_5cbe0_row8_col0, #T_5cbe0_row11_col1, #T_5cbe0_row11_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_5cbe0_row8_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_5cbe0_row8_col2, #T_5cbe0_row10_col1, #T_5cbe0_row12_col1 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_5cbe0_row9_col0 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_5cbe0_row9_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_5cbe0_row10_col0, #T_5cbe0_row12_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_5cbe0_row10_col2 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_5cbe0_row11_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_5cbe0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >rb_kmeans3</th>
#       <th id="T_5cbe0_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_5cbe0_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_5cbe0_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5cbe0_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_5cbe0_row0_col0" class="data row0 col0" >40.690000</td>
#       <td id="T_5cbe0_row0_col1" class="data row0 col1" >38.310000</td>
#       <td id="T_5cbe0_row0_col2" class="data row0 col2" >37.350000</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe0_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_5cbe0_row1_col0" class="data row1 col0" >79.980000</td>
#       <td id="T_5cbe0_row1_col1" class="data row1 col1" >25.180000</td>
#       <td id="T_5cbe0_row1_col2" class="data row1 col2" >14.040000</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe0_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_5cbe0_row2_col0" class="data row2 col0" >16.510000</td>
#       <td id="T_5cbe0_row2_col1" class="data row2 col1" >13.870000</td>
#       <td id="T_5cbe0_row2_col2" class="data row2 col2" >14.740000</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe0_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_5cbe0_row3_col0" class="data row3 col0" >1.900000</td>
#       <td id="T_5cbe0_row3_col1" class="data row3 col1" >2.000000</td>
#       <td id="T_5cbe0_row3_col2" class="data row3 col2" >1.910000</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe0_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_5cbe0_row4_col0" class="data row4 col0" >14.790000</td>
#       <td id="T_5cbe0_row4_col1" class="data row4 col1" >15.360000</td>
#       <td id="T_5cbe0_row4_col2" class="data row4 col2" >15.400000</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe0_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_5cbe0_row5_col0" class="data row5 col0" >7.000000</td>
#       <td id="T_5cbe0_row5_col1" class="data row5 col1" >45.110000</td>
#       <td id="T_5cbe0_row5_col2" class="data row5 col2" >6.160000</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe0_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_5cbe0_row6_col0" class="data row6 col0" >0.050000</td>
#       <td id="T_5cbe0_row6_col1" class="data row6 col1" >0.120000</td>
#       <td id="T_5cbe0_row6_col2" class="data row6 col2" >0.020000</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe0_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_5cbe0_row7_col0" class="data row7 col0" >0.020000</td>
#       <td id="T_5cbe0_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_5cbe0_row7_col2" class="data row7 col2" >0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe0_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_5cbe0_row8_col0" class="data row8 col0" >0.790000</td>
#       <td id="T_5cbe0_row8_col1" class="data row8 col1" >1.400000</td>
#       <td id="T_5cbe0_row8_col2" class="data row8 col2" >0.840000</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe0_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_5cbe0_row9_col0" class="data row9 col0" >7.680000</td>
#       <td id="T_5cbe0_row9_col1" class="data row9 col1" >3.910000</td>
#       <td id="T_5cbe0_row9_col2" class="data row9 col2" >3.840000</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe0_level0_row10" class="row_heading level0 row10" >education</th>
#       <td id="T_5cbe0_row10_col0" class="data row10 col0" >1.010000</td>
#       <td id="T_5cbe0_row10_col1" class="data row10 col1" >1.000000</td>
#       <td id="T_5cbe0_row10_col2" class="data row10 col2" >1.200000</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe0_level0_row11" class="row_heading level0 row11" >gender</th>
#       <td id="T_5cbe0_row11_col0" class="data row11 col0" >0.360000</td>
#       <td id="T_5cbe0_row11_col1" class="data row11 col1" >0.380000</td>
#       <td id="T_5cbe0_row11_col2" class="data row11 col2" >0.380000</td>
#     </tr>
#     <tr>
#       <th id="T_5cbe0_level0_row12" class="row_heading level0 row12" >constant</th>
#       <td id="T_5cbe0_row12_col0" class="data row12 col0" >1.000000</td>
#       <td id="T_5cbe0_row12_col1" class="data row12 col1" >1.000000</td>
#       <td id="T_5cbe0_row12_col2" class="data row12 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# score | promo+(returns) | lowscore?

# %% [markdown]
# ##### 4 clusters

# %%
kmeans = KMeans(n_clusters = 4, init='k-means++', n_init=20,  random_state = 1).fit(sample_rb_scl)
sample_original['rb_kmeans4'] = kmeans.predict(sample_rb_scl)

# %%
groupby_mean(sample_original, 'rb_kmeans4', True)
# Out:
# # observations per cluster: [8142, 8206, 2992, 5086]
# <style type="text/css">
# #T_eeef5_row0_col0, #T_eeef5_row0_col1, #T_eeef5_row1_col3, #T_eeef5_row5_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_eeef5_row0_col2 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_eeef5_row0_col3 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_eeef5_row1_col0 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_eeef5_row1_col1, #T_eeef5_row2_col1 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_eeef5_row1_col2 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_eeef5_row2_col0 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_eeef5_row2_col2 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_eeef5_row2_col3 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_eeef5_row3_col0, #T_eeef5_row3_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_eeef5_row3_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_eeef5_row3_col3, #T_eeef5_row8_col0, #T_eeef5_row12_col0, #T_eeef5_row12_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_eeef5_row4_col0 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_eeef5_row4_col1 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_eeef5_row4_col2 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_eeef5_row4_col3 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_eeef5_row5_col0 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_eeef5_row5_col1 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_eeef5_row5_col3, #T_eeef5_row9_col2 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_eeef5_row6_col0, #T_eeef5_row6_col1, #T_eeef5_row6_col2, #T_eeef5_row6_col3, #T_eeef5_row7_col0, #T_eeef5_row7_col1, #T_eeef5_row7_col2, #T_eeef5_row7_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_eeef5_row8_col1, #T_eeef5_row10_col2, #T_eeef5_row12_col2 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_eeef5_row8_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_eeef5_row8_col3, #T_eeef5_row11_col0, #T_eeef5_row11_col1, #T_eeef5_row11_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_eeef5_row9_col0 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_eeef5_row9_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_eeef5_row9_col3 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_eeef5_row10_col0, #T_eeef5_row10_col1 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_eeef5_row10_col3, #T_eeef5_row12_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_eeef5_row11_col3 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_eeef5">
#   <thead>
#     <tr>
#       <th class="index_name level0" >rb_kmeans4</th>
#       <th id="T_eeef5_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_eeef5_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_eeef5_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_eeef5_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eeef5_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_eeef5_row0_col0" class="data row0 col0" >37.680000</td>
#       <td id="T_eeef5_row0_col1" class="data row0 col1" >37.060000</td>
#       <td id="T_eeef5_row0_col2" class="data row0 col2" >38.350000</td>
#       <td id="T_eeef5_row0_col3" class="data row0 col3" >40.670000</td>
#     </tr>
#     <tr>
#       <th id="T_eeef5_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_eeef5_row1_col0" class="data row1 col0" >13.000000</td>
#       <td id="T_eeef5_row1_col1" class="data row1 col1" >14.790000</td>
#       <td id="T_eeef5_row1_col2" class="data row1 col2" >27.000000</td>
#       <td id="T_eeef5_row1_col3" class="data row1 col3" >80.050000</td>
#     </tr>
#     <tr>
#       <th id="T_eeef5_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_eeef5_row2_col0" class="data row2 col0" >14.610000</td>
#       <td id="T_eeef5_row2_col1" class="data row2 col1" >14.800000</td>
#       <td id="T_eeef5_row2_col2" class="data row2 col2" >14.050000</td>
#       <td id="T_eeef5_row2_col3" class="data row2 col3" >16.480000</td>
#     </tr>
#     <tr>
#       <th id="T_eeef5_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_eeef5_row3_col0" class="data row3 col0" >1.920000</td>
#       <td id="T_eeef5_row3_col1" class="data row3 col1" >1.920000</td>
#       <td id="T_eeef5_row3_col2" class="data row3 col2" >2.000000</td>
#       <td id="T_eeef5_row3_col3" class="data row3 col3" >1.900000</td>
#     </tr>
#     <tr>
#       <th id="T_eeef5_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_eeef5_row4_col0" class="data row4 col0" >18.600000</td>
#       <td id="T_eeef5_row4_col1" class="data row4 col1" >12.330000</td>
#       <td id="T_eeef5_row4_col2" class="data row4 col2" >15.030000</td>
#       <td id="T_eeef5_row4_col3" class="data row4 col3" >14.810000</td>
#     </tr>
#     <tr>
#       <th id="T_eeef5_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_eeef5_row5_col0" class="data row5 col0" >6.790000</td>
#       <td id="T_eeef5_row5_col1" class="data row5 col1" >6.250000</td>
#       <td id="T_eeef5_row5_col2" class="data row5 col2" >46.380000</td>
#       <td id="T_eeef5_row5_col3" class="data row5 col3" >6.970000</td>
#     </tr>
#     <tr>
#       <th id="T_eeef5_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_eeef5_row6_col0" class="data row6 col0" >0.020000</td>
#       <td id="T_eeef5_row6_col1" class="data row6 col1" >0.030000</td>
#       <td id="T_eeef5_row6_col2" class="data row6 col2" >0.130000</td>
#       <td id="T_eeef5_row6_col3" class="data row6 col3" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_eeef5_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_eeef5_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_eeef5_row7_col1" class="data row7 col1" >0.010000</td>
#       <td id="T_eeef5_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_eeef5_row7_col3" class="data row7 col3" >0.020000</td>
#     </tr>
#     <tr>
#       <th id="T_eeef5_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_eeef5_row8_col0" class="data row8 col0" >0.910000</td>
#       <td id="T_eeef5_row8_col1" class="data row8 col1" >0.800000</td>
#       <td id="T_eeef5_row8_col2" class="data row8 col2" >1.380000</td>
#       <td id="T_eeef5_row8_col3" class="data row8 col3" >0.790000</td>
#     </tr>
#     <tr>
#       <th id="T_eeef5_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_eeef5_row9_col0" class="data row9 col0" >3.490000</td>
#       <td id="T_eeef5_row9_col1" class="data row9 col1" >4.120000</td>
#       <td id="T_eeef5_row9_col2" class="data row9 col2" >4.140000</td>
#       <td id="T_eeef5_row9_col3" class="data row9 col3" >7.680000</td>
#     </tr>
#     <tr>
#       <th id="T_eeef5_level0_row10" class="row_heading level0 row10" >education</th>
#       <td id="T_eeef5_row10_col0" class="data row10 col0" >1.210000</td>
#       <td id="T_eeef5_row10_col1" class="data row10 col1" >1.190000</td>
#       <td id="T_eeef5_row10_col2" class="data row10 col2" >1.000000</td>
#       <td id="T_eeef5_row10_col3" class="data row10 col3" >1.010000</td>
#     </tr>
#     <tr>
#       <th id="T_eeef5_level0_row11" class="row_heading level0 row11" >gender</th>
#       <td id="T_eeef5_row11_col0" class="data row11 col0" >0.380000</td>
#       <td id="T_eeef5_row11_col1" class="data row11 col1" >0.380000</td>
#       <td id="T_eeef5_row11_col2" class="data row11 col2" >0.380000</td>
#       <td id="T_eeef5_row11_col3" class="data row11 col3" >0.360000</td>
#     </tr>
#     <tr>
#       <th id="T_eeef5_level0_row12" class="row_heading level0 row12" >constant</th>
#       <td id="T_eeef5_row12_col0" class="data row12 col0" >1.000000</td>
#       <td id="T_eeef5_row12_col1" class="data row12 col1" >1.000000</td>
#       <td id="T_eeef5_row12_col2" class="data row12 col2" >1.000000</td>
#       <td id="T_e

# %% [markdown]
# recent+lowscore | general | promo+(returns) | score

# %% [markdown]
# ### Comparison

# %%
clusters_comparison(sample_original, 'rb_kmeans4', 'rb_kmeans3')
# Out:
#                       rb_kmeans3 0 Cluster  rb_kmeans3 1 Cluster  \
# rb_kmeans4 0 Cluster                     1                   215
# rb_kmeans4 1 Cluster                    20                    32
# rb_kmeans4 2 Cluster                     5                  2987
# rb_kmeans4 3 Cluster                  5072                     2
#
#                       rb_kmeans3 2 Cluster
# rb_kmeans4 0 Cluster                  7926
# rb_kmeans4 1 Cluster                  8154
# rb_kmeans4 2 Cluster                     0
# rb_kmeans4 3 Cluster                    12

# %% [markdown]
# ## 4.2. Hierarchical (Ward) <a id='wh'></a>

# %% [markdown]
# In this section, the hierarchical algorithm with a ward linkeage method was tested with the data inputs previously mentioned. For each of the data inputs dendrograms were plotted in order to decide which number of cluester were going to be considered for testing. Then, the clusters formed were analysed and clustering solutions compared. The tests for each data input were presented in the following order:
# 1. [No Scaler](#h-no)
# 2. [Standard Scaler](#h-st)
# 3. [MinMax Scaler](#h-mm)
# 4. [Robust Scaler](#h-rb)
#
# In the end of this section there is also a result comparison between clustering techniques as well as scaling options.
#
# 5. [Inter Clustering Comparison](#icc)

# %% [markdown]
# ### No Scaler <a id='h-no'></a>

# %% [markdown]
# #### Plot

# %%
plot_dendrogram(sample_no_scl, 'ward')

# %% [markdown]
# #### Models

# %% [markdown]
# ##### 2 clusters

# %%
sample_original['no_ward2'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 2
    ).fit_predict(sample_no_scl)

# %%
groupby_mean(sample_original, 'no_ward2', True, 12, 1)
# Out:
# # observations per cluster: [18682, 5744]
# <style type="text/css">
# #T_71d60_row0_col0, #T_71d60_row1_col0, #T_71d60_row2_col0, #T_71d60_row3_col1, #T_71d60_row4_col1, #T_71d60_row5_col0, #T_71d60_row6_col0, #T_71d60_row7_col0, #T_71d60_row8_col1, #T_71d60_row9_col0, #T_71d60_row10_col1, #T_71d60_row11_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_71d60_row0_col1, #T_71d60_row1_col1, #T_71d60_row2_col1, #T_71d60_row3_col0, #T_71d60_row4_col0, #T_71d60_row5_col1, #T_71d60_row6_col1, #T_71d60_row7_col1, #T_71d60_row8_col0, #T_71d60_row9_col1, #T_71d60_row10_col0, #T_71d60_row11_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_71d60">
#   <thead>
#     <tr>
#       <th class="index_name level0" >no_ward2</th>
#       <th id="T_71d60_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_71d60_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71d60_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_71d60_row0_col0" class="data row0 col0" >37.460000</td>
#       <td id="T_71d60_row0_col1" class="data row0 col1" >40.520000</td>
#     </tr>
#     <tr>
#       <th id="T_71d60_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_71d60_row1_col0" class="data row1 col0" >13.620000</td>
#       <td id="T_71d60_row1_col1" class="data row1 col1" >80.200000</td>
#     </tr>
#     <tr>
#       <th id="T_71d60_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_71d60_row2_col0" class="data row2 col0" >14.520000</td>
#       <td id="T_71d60_row2_col1" class="data row2 col1" >16.530000</td>
#     </tr>
#     <tr>
#       <th id="T_71d60_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_71d60_row3_col0" class="data row3 col0" >1.930000</td>
#       <td id="T_71d60_row3_col1" class="data row3 col1" >1.910000</td>
#     </tr>
#     <tr>
#       <th id="T_71d60_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_71d60_row4_col0" class="data row4 col0" >15.420000</td>
#       <td id="T_71d60_row4_col1" class="data row4 col1" >14.780000</td>
#     </tr>
#     <tr>
#       <th id="T_71d60_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_71d60_row5_col0" class="data row5 col0" >11.100000</td>
#       <td id="T_71d60_row5_col1" class="data row5 col1" >12.800000</td>
#     </tr>
#     <tr>
#       <th id="T_71d60_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_71d60_row6_col0" class="data row6 col0" >0.030000</td>
#       <td id="T_71d60_row6_col1" class="data row6 col1" >0.070000</td>
#     </tr>
#     <tr>
#       <th id="T_71d60_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_71d60_row7_col0" class="data row7 col0" >0.010000</td>
#       <td id="T_71d60_row7_col1" class="data row7 col1" >0.020000</td>
#     </tr>
#     <tr>
#       <th id="T_71d60_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_71d60_row8_col0" class="data row8 col0" >0.940000</td>
#       <td id="T_71d60_row8_col1" class="data row8 col1" >0.800000</td>
#     </tr>
#     <tr>
#       <th id="T_71d60_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_71d60_row9_col0" class="data row9 col0" >3.720000</td>
#       <td id="T_71d60_row9_col1" class="data row9 col1" >7.680000</td>
#     </tr>
#     <tr>
#       <th id="T_71d60_level0_row10" class="row_heading level0 row10" >education</th>
#       <td id="T_71d60_row10_col0" class="data row10 col0" >1.170000</td>
#       <td id="T_71d60_row10_col1" class="data row10 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_71d60_level0_row11" class="row_heading level0 row11" >gender</th>
#       <td id="T_71d60_row11_col0" class="data row11 col0" >0.380000</td>
#       <td id="T_71d60_row11_col1" class="data row11 col1" >0.360000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# general | score

# %% [markdown]
# ##### 3 clusters

# %%
sample_original['no_ward3'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 3
    ).fit_predict(sample_no_scl)

# %%
groupby_mean(sample_original, 'no_ward3', False, 12, 0)
# Out:
# no_ward3                       0        1        2      data
# frequency_items            39.23    40.52    34.64     38.18
# potencial_score             3.53    80.20    29.64     29.28
# longevity_months           13.35    16.53    16.39     14.99
# relevance_criteria          1.93     1.91     1.92      1.92
# recency_in_weeks           15.58    14.78    15.17     15.27
# promotional_percentage     14.41    12.80     5.83     11.49
# returns                     0.04     0.07     0.02      0.04
# flaged                      0.00     0.02     0.01      0.01
# credit_factor               1.02     0.80     0.80      0.90
# zip_code                    1.23     7.68     7.68      4.65
# education                   1.22     1.00     1.09      1.14
# gender                      0.38     0.36     0.38      0.38
# Counts                  11461.00  5744.00  7221.00  24426.00

# %% [markdown]
# lowscore+(new) | score | lowpromo

# %% [markdown]
# ##### 4 clusters

# %%
sample_original['no_ward4'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 4
    ).fit_predict(sample_no_scl)

# %%
groupby_mean(sample_original, 'no_ward4', True, 12)
# Out:
# # observations per cluster: [5744, 3264, 7221, 8197]
# <style type="text/css">
# #T_1d215_row0_col0 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_1d215_row0_col1, #T_1d215_row0_col2, #T_1d215_row0_col3, #T_1d215_row1_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1d215_row1_col1 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_1d215_row1_col2 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_1d215_row1_col3, #T_1d215_row9_col3, #T_1d215_row10_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_1d215_row2_col0 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_1d215_row2_col1 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_1d215_row2_col2 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_1d215_row2_col3 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_1d215_row3_col0, #T_1d215_row10_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_1d215_row3_col1, #T_1d215_row3_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_1d215_row3_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_1d215_row4_col0 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_1d215_row4_col1 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_1d215_row4_col2 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_1d215_row4_col3 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_1d215_row5_col0 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_1d215_row5_col1 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_1d215_row5_col2 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_1d215_row5_col3 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_1d215_row6_col0, #T_1d215_row6_col1, #T_1d215_row6_col2, #T_1d215_row6_col3, #T_1d215_row7_col0, #T_1d215_row7_col1, #T_1d215_row7_col2, #T_1d215_row7_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_1d215_row8_col0, #T_1d215_row11_col1, #T_1d215_row11_col2, #T_1d215_row11_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_1d215_row8_col1 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_1d215_row8_col2, #T_1d215_row8_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_1d215_row9_col0 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_1d215_row9_col1 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_1d215_row9_col2 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_1d215_row10_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_1d215_row10_col3 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_1d215_row11_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_1d215">
#   <thead>
#     <tr>
#       <th class="index_name level0" >no_ward4</th>
#       <th id="T_1d215_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_1d215_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_1d215_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_1d215_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d215_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_1d215_row0_col0" class="data row0 col0" >40.520000</td>
#       <td id="T_1d215_row0_col1" class="data row0 col1" >38.700000</td>
#       <td id="T_1d215_row0_col2" class="data row0 col2" >34.640000</td>
#       <td id="T_1d215_row0_col3" class="data row0 col3" >39.440000</td>
#     </tr>
#     <tr>
#       <th id="T_1d215_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_1d215_row1_col0" class="data row1 col0" >80.200000</td>
#       <td id="T_1d215_row1_col1" class="data row1 col1" >11.130000</td>
#       <td id="T_1d215_row1_col2" class="data row1 col2" >29.640000</td>
#       <td id="T_1d215_row1_col3" class="data row1 col3" >0.510000</td>
#     </tr>
#     <tr>
#       <th id="T_1d215_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_1d215_row2_col0" class="data row2 col0" >16.530000</td>
#       <td id="T_1d215_row2_col1" class="data row2 col1" >13.850000</td>
#       <td id="T_1d215_row2_col2" class="data row2 col2" >16.390000</td>
#       <td id="T_1d215_row2_col3" class="data row2 col3" >13.150000</td>
#     </tr>
#     <tr>
#       <th id="T_1d215_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_1d215_row3_col0" class="data row3 col0" >1.910000</td>
#       <td id="T_1d215_row3_col1" class="data row3 col1" >2.000000</td>
#       <td id="T_1d215_row3_col2" class="data row3 col2" >1.920000</td>
#       <td id="T_1d215_row3_col3" class="data row3 col3" >1.900000</td>
#     </tr>
#     <tr>
#       <th id="T_1d215_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_1d215_row4_col0" class="data row4 col0" >14.780000</td>
#       <td id="T_1d215_row4_col1" class="data row4 col1" >15.620000</td>
#       <td id="T_1d215_row4_col2" class="data row4 col2" >15.170000</td>
#       <td id="T_1d215_row4_col3" class="data row4 col3" >15.560000</td>
#     </tr>
#     <tr>
#       <th id="T_1d215_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_1d215_row5_col0" class="data row5 col0" >12.800000</td>
#       <td id="T_1d215_row5_col1" class="data row5 col1" >37.130000</td>
#       <td id="T_1d215_row5_col2" class="data row5 col2" >5.830000</td>
#       <td id="T_1d215_row5_col3" class="data row5 col3" >5.370000</td>
#     </tr>
#     <tr>
#       <th id="T_1d215_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_1d215_row6_col0" class="data row6 col0" >0.070000</td>
#       <td id="T_1d215_row6_col1" class="data row6 col1" >0.070000</td>
#       <td id="T_1d215_row6_col2" class="data row6 col2" >0.020000</td>
#       <td id="T_1d215_row6_col3" class="data row6 col3" >0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_1d215_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_1d215_row7_col0" class="data row7 col0" >0.020000</td>
#       <td id="T_1d215_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_1d215_row7_col2" class="data row7 col2" >0.010000</td>
#       <td id="T_1d215_row7_col3" class="data row7 col3" >0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_1d215_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_1d215_row8_col0" class="data row8 col0" >0.800000</td>
#       <td id="T_1d215_row8_col1" class="data row8 col1" >1.460000</td>
#       <td id="T_1d215_row8_col2" class="data row8 col2" >0.800000</td>
#       <td id="T_1d215_row8_col3" class="data row8 col3" >0.840000</td>
#     </tr>
#     <tr>
#       <th id="T_1d215_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_1d215_row9_col0" class="data row9 col0" >7.680000</td>
#       <td id="T_1d215_row9_col1" class="data row9 col1" >3.060000</td>
#       <td id="T_1d215_row9_col2" class="data row9 col2" >7.680000</td>
#       <td id="T_1d215_row9_col3" class="data row9 col3" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_1d215_level0_row10" class="row_heading level0 row10" >education</th>
#       <td id="T_1d215_row10_col0" class="data row10 col0" >1.000000</td>
#       <td id="T_1d215_row10_col1" class="data row10 col1" >1.000000</td>
#       <td id="T_1d215_row10_col2" class="data row10 col2" >1.090000</td>
#       <td id="T_1d215_row10_col3" class="data row10 col3" >1.320000</td>
#     </tr>
#     <tr>
#       <th id="T_1d215_level0_row11" class="row_heading level0 row11" >gender</th>
#       <td id="T_1d215_row11_col0" class="data row11 col0" >0.360000</td>
#       <td id="T_1d215_row11_col1" class="data row11 col1" >0.380000</td>
#       <td id="T_1d215_row11_col2" class="data row11 col2" >0.380000</td>
#       <td id="T_1d215_row11_col3" class="data row11 col3" >0.380000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# score | promo | general | lowscore

# %% [markdown]
# ##### 5 clusters

# %%
sample_original['no_ward5'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 5
    ).fit_predict(sample_no_scl)

# %%
groupby_mean(sample_original, 'no_ward5', True, 12)
# Out:
# # observations per cluster: [4679, 3264, 7221, 8197, 1065]
# <style type="text/css">
# #T_bfe52_row0_col0 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_bfe52_row0_col1, #T_bfe52_row0_col2, #T_bfe52_row0_col3, #T_bfe52_row1_col0, #T_bfe52_row1_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_bfe52_row0_col4 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_bfe52_row1_col1 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_bfe52_row1_col2 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_bfe52_row1_col3, #T_bfe52_row9_col3, #T_bfe52_row10_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_bfe52_row2_col0 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_bfe52_row2_col1 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_bfe52_row2_col2 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_bfe52_row2_col3 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_bfe52_row2_col4 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_bfe52_row3_col0, #T_bfe52_row8_col2, #T_bfe52_row8_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_bfe52_row3_col1, #T_bfe52_row3_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_bfe52_row3_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_bfe52_row3_col4, #T_bfe52_row10_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_bfe52_row4_col0 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_bfe52_row4_col1 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_bfe52_row4_col2 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_bfe52_row4_col3 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_bfe52_row4_col4 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_bfe52_row5_col0 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_bfe52_row5_col1 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_bfe52_row5_col2 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_bfe52_row5_col3 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_bfe52_row5_col4 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_bfe52_row6_col0, #T_bfe52_row6_col1, #T_bfe52_row6_col2, #T_bfe52_row6_col3, #T_bfe52_row6_col4, #T_bfe52_row7_col0, #T_bfe52_row7_col1, #T_bfe52_row7_col2, #T_bfe52_row7_col3, #T_bfe52_row7_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_bfe52_row8_col0, #T_bfe52_row8_col4, #T_bfe52_row10_col4, #T_bfe52_row11_col1, #T_bfe52_row11_col2, #T_bfe52_row11_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_bfe52_row8_col1 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_bfe52_row9_col0, #T_bfe52_row9_col4 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_bfe52_row9_col1 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_bfe52_row9_col2 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_bfe52_row10_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_bfe52_row10_col3 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_bfe52_row11_col0, #T_bfe52_row11_col4 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_bfe52">
#   <thead>
#     <tr>
#       <th class="index_name level0" >no_ward5</th>
#       <th id="T_bfe52_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_bfe52_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_bfe52_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_bfe52_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_bfe52_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bfe52_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_bfe52_row0_col0" class="data row0 col0" >41.260000</td>
#       <td id="T_bfe52_row0_col1" class="data row0 col1" >38.700000</td>
#       <td id="T_bfe52_row0_col2" class="data row0 col2" >34.640000</td>
#       <td id="T_bfe52_row0_col3" class="data row0 col3" >39.440000</td>
#       <td id="T_bfe52_row0_col4" class="data row0 col4" >37.260000</td>
#     </tr>
#     <tr>
#       <th id="T_bfe52_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_bfe52_row1_col0" class="data row1 col0" >80.140000</td>
#       <td id="T_bfe52_row1_col1" class="data row1 col1" >11.130000</td>
#       <td id="T_bfe52_row1_col2" class="data row1 col2" >29.640000</td>
#       <td id="T_bfe52_row1_col3" class="data row1 col3" >0.510000</td>
#       <td id="T_bfe52_row1_col4" class="data row1 col4" >80.450000</td>
#     </tr>
#     <tr>
#       <th id="T_bfe52_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_bfe52_row2_col0" class="data row2 col0" >16.430000</td>
#       <td id="T_bfe52_row2_col1" class="data row2 col1" >13.850000</td>
#       <td id="T_bfe52_row2_col2" class="data row2 col2" >16.390000</td>
#       <td id="T_bfe52_row2_col3" class="data row2 col3" >13.150000</td>
#       <td id="T_bfe52_row2_col4" class="data row2 col4" >16.950000</td>
#     </tr>
#     <tr>
#       <th id="T_bfe52_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_bfe52_row3_col0" class="data row3 col0" >1.890000</td>
#       <td id="T_bfe52_row3_col1" class="data row3 col1" >2.000000</td>
#       <td id="T_bfe52_row3_col2" class="data row3 col2" >1.920000</td>
#       <td id="T_bfe52_row3_col3" class="data row3 col3" >1.900000</td>
#       <td id="T_bfe52_row3_col4" class="data row3 col4" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfe52_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_bfe52_row4_col0" class="data row4 col0" >14.790000</td>
#       <td id="T_bfe52_row4_col1" class="data row4 col1" >15.620000</td>
#       <td id="T_bfe52_row4_col2" class="data row4 col2" >15.170000</td>
#       <td id="T_bfe52_row4_col3" class="data row4 col3" >15.560000</td>
#       <td id="T_bfe52_row4_col4" class="data row4 col4" >14.740000</td>
#     </tr>
#     <tr>
#       <th id="T_bfe52_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_bfe52_row5_col0" class="data row5 col0" >5.740000</td>
#       <td id="T_bfe52_row5_col1" class="data row5 col1" >37.130000</td>
#       <td id="T_bfe52_row5_col2" class="data row5 col2" >5.830000</td>
#       <td id="T_bfe52_row5_col3" class="data row5 col3" >5.370000</td>
#       <td id="T_bfe52_row5_col4" class="data row5 col4" >43.780000</td>
#     </tr>
#     <tr>
#       <th id="T_bfe52_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_bfe52_row6_col0" class="data row6 col0" >0.050000</td>
#       <td id="T_bfe52_row6_col1" class="data row6 col1" >0.070000</td>
#       <td id="T_bfe52_row6_col2" class="data row6 col2" >0.020000</td>
#       <td id="T_bfe52_row6_col3" class="data row6 col3" >0.030000</td>
#       <td id="T_bfe52_row6_col4" class="data row6 col4" >0.160000</td>
#     </tr>
#     <tr>
#       <th id="T_bfe52_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_bfe52_row7_col0" class="data row7 col0" >0.020000</td>
#       <td id="T_bfe52_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_bfe52_row7_col2" class="data row7 col2" >0.010000</td>
#       <td id="T_bfe52_row7_col3" class="data row7 col3" >0.010000</td>
#       <td id="T_bfe52_row7_col4" class="data row7 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bfe52_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_bfe52_row8_col0" class="data row8 col0" >0.780000</td>
#       <td id="T_bfe52_row8_col1" class="data row8 col1" >1.460000</td>
#       <td id="T_bfe52_row8_col2" class="data row8 col2" >0.800000</td>
#       <td id="T_bfe52_row8_col3" class="data row8 col3" >0.840000</td>
#       <td id="T_bfe52_row8_col4" class="data row8 col4" >0.930000</td>
#     </tr>
#     <tr>
#       <th id="T_bfe52_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_bfe52_row9_col0" class="data row9 col0" >7.690000</td>
#       <td id="T_bfe52_row9_col1" class="data row9 col1" >3.060000</td>
#       <td id="T_bfe52_row9_col2" class="data row9 col2" >7.680000</td>
#       <td id="T_bfe52_row9_col3" class="data row9 col3" >0.500000</td>

# %% [markdown]
# score | promo+(lowscore) | general | lowscore | score+promo

# %% [markdown]
# #### Comparison

# %%
clusters_comparison(sample_original, 'no_ward3', 'no_ward2')
# Out:
#                     no_ward2 0 Cluster  no_ward2 1 Cluster
# no_ward3 0 Cluster               11461                   0
# no_ward3 1 Cluster                   0                5744
# no_ward3 2 Cluster                7221                   0

# %%
clusters_comparison(sample_original, 'no_ward4', 'no_ward3')
# Out:
#                     no_ward3 0 Cluster  no_ward3 1 Cluster  no_ward3 2 Cluster
# no_ward4 0 Cluster                   0                5744                   0
# no_ward4 1 Cluster                3264                   0                   0
# no_ward4 2 Cluster                   0                   0                7221
# no_ward4 3 Cluster                8197                   0                   0

# %%
clusters_comparison(sample_original, 'no_ward5', 'no_ward4')
# Out:
#                     no_ward4 0 Cluster  no_ward4 1 Cluster  \
# no_ward5 0 Cluster                4679                   0
# no_ward5 1 Cluster                   0                3264
# no_ward5 2 Cluster                   0                   0
# no_ward5 3 Cluster                   0                   0
# no_ward5 4 Cluster                1065                   0
#
#                     no_ward4 2 Cluster  no_ward4 3 Cluster
# no_ward5 0 Cluster                   0                   0
# no_ward5 1 Cluster                   0                   0
# no_ward5 2 Cluster                7221                   0
# no_ward5 3 Cluster                   0                8197
# no_ward5 4 Cluster                   0                   0

# %% [markdown]
# ### Standard Scaler <a id='h-st'></a>

# %% [markdown]
# #### Plot

# %%
plot_dendrogram(sample_st_scl, 'ward')

# %% [markdown]
# #### Models

# %% [markdown]
# ##### 5 clusters

# %%
sample_original['st_ward5'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 5
    ).fit_predict(sample_st_scl)

# %%
groupby_mean(sample_original, 'st_ward5', True)
# Out:
# # observations per cluster: [17573, 4436, 944, 209, 1264]
# <style type="text/css">
# #T_1468f_row0_col0, #T_1468f_row0_col2, #T_1468f_row0_col4, #T_1468f_row1_col1, #T_1468f_row1_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1468f_row0_col1 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_1468f_row0_col3 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_1468f_row1_col0 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_1468f_row1_col2 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_1468f_row1_col4 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_1468f_row2_col0, #T_1468f_row2_col4 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_1468f_row2_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_1468f_row2_col2, #T_1468f_row4_col4 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_1468f_row2_col3 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_1468f_row3_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_1468f_row3_col1, #T_1468f_row3_col3, #T_1468f_row6_col2, #T_1468f_row8_col0, #T_1468f_row8_col2, #T_1468f_row10_col2, #T_1468f_row12_col0, #T_1468f_row12_col2, #T_1468f_row12_col4 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_1468f_row3_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_1468f_row3_col4, #T_1468f_row8_col3, #T_1468f_row8_col4, #T_1468f_row10_col1, #T_1468f_row12_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_1468f_row4_col0 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_1468f_row4_col1 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_1468f_row4_col2 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_1468f_row4_col3 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_1468f_row5_col0 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_1468f_row5_col1, #T_1468f_row9_col0 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_1468f_row5_col2 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_1468f_row5_col3, #T_1468f_row5_col4, #T_1468f_row6_col0, #T_1468f_row6_col1, #T_1468f_row6_col4, #T_1468f_row7_col0, #T_1468f_row7_col1, #T_1468f_row7_col2, #T_1468f_row7_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_1468f_row6_col3, #T_1468f_row8_col1, #T_1468f_row11_col0, #T_1468f_row11_col2, #T_1468f_row11_col3, #T_1468f_row11_col4 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_1468f_row7_col3, #T_1468f_row12_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_1468f_row9_col1 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_1468f_row9_col2 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_1468f_row9_col3 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_1468f_row9_col4 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_1468f_row10_col0 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_1468f_row10_col3, #T_1468f_row10_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_1468f_row11_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_1468f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >st_ward5</th>
#       <th id="T_1468f_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_1468f_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_1468f_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_1468f_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_1468f_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1468f_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_1468f_row0_col0" class="data row0 col0" >37.420000</td>
#       <td id="T_1468f_row0_col1" class="data row0 col1" >40.540000</td>
#       <td id="T_1468f_row0_col2" class="data row0 col2" >39.460000</td>
#       <td id="T_1468f_row0_col3" class="data row0 col3" >41.760000</td>
#       <td id="T_1468f_row0_col4" class="data row0 col4" >38.760000</td>
#     </tr>
#     <tr>
#       <th id="T_1468f_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_1468f_row1_col0" class="data row1 col0" >15.760000</td>
#       <td id="T_1468f_row1_col1" class="data row1 col1" >80.150000</td>
#       <td id="T_1468f_row1_col2" class="data row1 col2" >38.310000</td>
#       <td id="T_1468f_row1_col3" class="data row1 col3" >47.880000</td>
#       <td id="T_1468f_row1_col4" class="data row1 col4" >28.910000</td>
#     </tr>
#     <tr>
#       <th id="T_1468f_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_1468f_row2_col0" class="data row2 col0" >14.480000</td>
#       <td id="T_1468f_row2_col1" class="data row2 col1" >16.630000</td>
#       <td id="T_1468f_row2_col2" class="data row2 col2" >16.160000</td>
#       <td id="T_1468f_row2_col3" class="data row2 col3" >17.630000</td>
#       <td id="T_1468f_row2_col4" class="data row2 col4" >15.030000</td>
#     </tr>
#     <tr>
#       <th id="T_1468f_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_1468f_row3_col0" class="data row3 col0" >2.000000</td>
#       <td id="T_1468f_row3_col1" class="data row3 col1" >2.000000</td>
#       <td id="T_1468f_row3_col2" class="data row3 col2" >1.940000</td>
#       <td id="T_1468f_row3_col3" class="data row3 col3" >1.230000</td>
#       <td id="T_1468f_row3_col4" class="data row3 col4" >0.670000</td>
#     </tr>
#     <tr>
#       <th id="T_1468f_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_1468f_row4_col0" class="data row4 col0" >15.390000</td>
#       <td id="T_1468f_row4_col1" class="data row4 col1" >14.840000</td>
#       <td id="T_1468f_row4_col2" class="data row4 col2" >14.700000</td>
#       <td id="T_1468f_row4_col3" class="data row4 col3" >13.570000</td>
#       <td id="T_1468f_row4_col4" class="data row4 col4" >15.770000</td>
#     </tr>
#     <tr>
#       <th id="T_1468f_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_1468f_row5_col0" class="data row5 col0" >12.270000</td>
#       <td id="T_1468f_row5_col1" class="data row5 col1" >8.020000</td>
#       <td id="T_1468f_row5_col2" class="data row5 col2" >31.210000</td>
#       <td id="T_1468f_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_1468f_row5_col4" class="data row5 col4" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_1468f_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_1468f_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_1468f_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_1468f_row6_col2" class="data row6 col2" >1.000000</td>
#       <td id="T_1468f_row6_col3" class="data row6 col3" >0.390000</td>
#       <td id="T_1468f_row6_col4" class="data row6 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1468f_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_1468f_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_1468f_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_1468f_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_1468f_row7_col3" class="data row7 col3" >1.000000</td>
#       <td id="T_1468f_row7_col4" class="data row7 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1468f_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_1468f_row8_col0" class="data row8 col0" >0.950000</td>
#       <td id="T_1468f_row8_col1" class="data row8 col1" >0.800000</td>
#       <td id="T_1468f_row8_col2" class="data row8 col2" >0.980000</td>
#       <td id="T_1468f_row8_col3" class="data row8 col3" >0.780000</td>
#       <td id="T_1468f_row8_col4" class="data row8 col4" >0.630000</td>
#     </tr>
#     <tr>
#       <th id="T_1468f_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_1468f_row9_col0" class="data row9 col0" >3.860000</td>
#       <td id="T_1468f_row9_col1" class="data row9 col1" >7.660000</td>
#       <td id="T_1468f_row9_col2" class="data row9 col2" >5.150000</td>
#       <td id="T_1468f_row9_col3" class="data row9 col3" >6.540000</td>
#       <td id="T_1468f_row9_col4" class="data row

# %% [markdown]
# general | score | promo+return | flag+nopromo | flag+nopromo

# %% [markdown]
# ##### 8 clusters

# %%
sample_original['st_ward8'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 8
    ).fit_predict(sample_st_scl)

# %%
groupby_mean(sample_original, 'st_ward8', True, 12)
# Out:
# # observations per cluster: [944, 4436, 4888, 4898, 1264, 3318, 4469, 209]
# <style type="text/css">
# #T_02aee_row0_col0, #T_02aee_row0_col2, #T_02aee_row0_col3, #T_02aee_row0_col4, #T_02aee_row0_col5, #T_02aee_row0_col6, #T_02aee_row1_col1, #T_02aee_row1_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_02aee_row0_col1 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_02aee_row0_col7 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_02aee_row1_col0 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_02aee_row1_col2 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_02aee_row1_col3, #T_02aee_row2_col7 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_02aee_row1_col4 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_02aee_row1_col5 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_02aee_row1_col6 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_02aee_row2_col0, #T_02aee_row4_col2, #T_02aee_row4_col4 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_02aee_row2_col1, #T_02aee_row5_col3 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_02aee_row2_col2 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_02aee_row2_col3 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_02aee_row2_col4 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_02aee_row2_col5 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_02aee_row2_col6 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_02aee_row3_col0, #T_02aee_row3_col2, #T_02aee_row10_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_02aee_row3_col1, #T_02aee_row3_col7, #T_02aee_row6_col0, #T_02aee_row8_col0, #T_02aee_row8_col3, #T_02aee_row8_col6, #T_02aee_row10_col0 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_02aee_row3_col3 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_02aee_row3_col4, #T_02aee_row8_col2, #T_02aee_row8_col4, #T_02aee_row8_col7, #T_02aee_row10_col1, #T_02aee_row10_col6, #T_02aee_row11_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_02aee_row3_col5, #T_02aee_row3_col6 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_02aee_row4_col0 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_02aee_row4_col1 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_02aee_row4_col3 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_02aee_row4_col5 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_02aee_row4_col6 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_02aee_row4_col7 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_02aee_row5_col0 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_02aee_row5_col1, #T_02aee_row9_col3, #T_02aee_row9_col5 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_02aee_row5_col2, #T_02aee_row9_col6 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_02aee_row5_col4, #T_02aee_row5_col7, #T_02aee_row6_col1, #T_02aee_row6_col2, #T_02aee_row6_col3, #T_02aee_row6_col4, #T_02aee_row6_col5, #T_02aee_row6_col6, #T_02aee_row7_col0, #T_02aee_row7_col1, #T_02aee_row7_col2, #T_02aee_row7_col3, #T_02aee_row7_col4, #T_02aee_row7_col5, #T_02aee_row7_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_02aee_row5_col5 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_02aee_row5_col6 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_02aee_row6_col7, #T_02aee_row8_col1, #T_02aee_row11_col0, #T_02aee_row11_col2, #T_02aee_row11_col4, #T_02aee_row11_col5, #T_02aee_row11_col6, #T_02aee_row11_col7 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_02aee_row7_col7 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_02aee_row8_col5, #T_02aee_row10_col2 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_02aee_row9_col0 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_02aee_row9_col1 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_02aee_row9_col2 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_02aee_row9_col4 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_02aee_row9_col7 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_02aee_row10_col4, #T_02aee_row10_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_02aee_row10_col5 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_02aee_row11_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_02aee">
#   <thead>
#     <tr>
#       <th class="index_name level0" >st_ward8</th>
#       <th id="T_02aee_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_02aee_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_02aee_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_02aee_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_02aee_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_02aee_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_02aee_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_02aee_level0_col7" class="col_heading level0 col7" >7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02aee_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_02aee_row0_col0" class="data row0 col0" >39.460000</td>
#       <td id="T_02aee_row0_col1" class="data row0 col1" >40.540000</td>
#       <td id="T_02aee_row0_col2" class="data row0 col2" >43.010000</td>
#       <td id="T_02aee_row0_col3" class="data row0 col3" >32.660000</td>
#       <td id="T_02aee_row0_col4" class="data row0 col4" >38.760000</td>
#       <td id="T_02aee_row0_col5" class="data row0 col5" >37.590000</td>
#       <td id="T_02aee_row0_col6" class="data row0 col6" >36.420000</td>
#       <td id="T_02aee_row0_col7" class="data row0 col7" >41.760000</td>
#     </tr>
#     <tr>
#       <th id="T_02aee_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_02aee_row1_col0" class="data row1 col0" >38.310000</td>
#       <td id="T_02aee_row1_col1" class="data row1 col1" >80.150000</td>
#       <td id="T_02aee_row1_col2" class="data row1 col2" >10.740000</td>
#       <td id="T_02aee_row1_col3" class="data row1 col3" >12.070000</td>
#       <td id="T_02aee_row1_col4" class="data row1 col4" >28.910000</td>
#       <td id="T_02aee_row1_col5" class="data row1 col5" >22.340000</td>
#       <td id="T_02aee_row1_col6" class="data row1 col6" >20.400000</td>
#       <td id="T_02aee_row1_col7" class="data row1 col7" >47.880000</td>
#     </tr>
#     <tr>
#       <th id="T_02aee_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_02aee_row2_col0" class="data row2 col0" >16.160000</td>
#       <td id="T_02aee_row2_col1" class="data row2 col1" >16.630000</td>
#       <td id="T_02aee_row2_col2" class="data row2 col2" >9.390000</td>
#       <td id="T_02aee_row2_col3" class="data row2 col3" >11.450000</td>
#       <td id="T_02aee_row2_col4" class="data row2 col4" >15.030000</td>
#       <td id="T_02aee_row2_col5" class="data row2 col5" >12.970000</td>
#       <td id="T_02aee_row2_col6" class="data row2 col6" >24.510000</td>
#       <td id="T_02aee_row2_col7" class="data row2 col7" >17.630000</td>
#     </tr>
#     <tr>
#       <th id="T_02aee_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_02aee_row3_col0" class="data row3 col0" >1.940000</td>
#       <td id="T_02aee_row3_col1" class="data row3 col1" >2.000000</td>
#       <td id="T_02aee_row3_col2" class="data row3 col2" >2.000000</td>
#       <td id="T_02aee_row3_col3" class="data row3 col3" >2.000000</td>
#       <td id="T_02aee_row3_col4" class="data row3 col4" >0.670000</td>
#       <td id="T_02aee_row3_col5" class="data row3 col5" >2.000000</td>
#       <td id="T_02aee_row3_col6" class="data row3 col6" >2.000000</td>
#       <td id="T_02aee_row3_col7" class="data row3 col7" >1.230000</td>
#     </tr>
#     <tr>
#       <th id="T_02aee_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_02aee_row4_col0" class="data row4 col0" >14.700000</td>
#       <td id="T_02aee_row4_col1" class="data row4 col1" >14.840000</td>
#       <td id="T_02aee_row4_col2" class="data row4 col2" >17.580000</td>
#       <td id="T_02aee_row4_col3" class="data row4 col3" >12.610

# %% [markdown]
# promo+returns | score | lowscore | ? | nopromo | promo | antiques | nopromo+flag

# %% [markdown]
# ### MinMax Scaler <a id='h-mm'></a>

# %% [markdown]
# #### Plot

# %%
plot_dendrogram(sample_mm_scl, 'ward')

# %% [markdown]
# #### Models

# %% [markdown]
# ##### 2 clusters

# %%
sample_original['mm_ward2'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 2
    ).fit_predict(sample_mm_scl)

# %%
groupby_mean(sample_original, 'mm_ward2', True, 12)
# Out:
# # observations per cluster: [5917, 18509]
# <style type="text/css">
# #T_c5564_row0_col0 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_c5564_row0_col1, #T_c5564_row1_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c5564_row1_col1 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_c5564_row2_col0 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_c5564_row2_col1 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_c5564_row3_col0, #T_c5564_row8_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_c5564_row3_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_c5564_row4_col0 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_c5564_row4_col1 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_c5564_row5_col0 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_c5564_row5_col1 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_c5564_row6_col0, #T_c5564_row6_col1, #T_c5564_row7_col0, #T_c5564_row7_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c5564_row8_col0, #T_c5564_row11_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_c5564_row9_col0, #T_c5564_row9_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_c5564_row10_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_c5564_row10_col1 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_c5564_row11_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_c5564">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mm_ward2</th>
#       <th id="T_c5564_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_c5564_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5564_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_c5564_row0_col0" class="data row0 col0" >40.330000</td>
#       <td id="T_c5564_row0_col1" class="data row0 col1" >37.490000</td>
#     </tr>
#     <tr>
#       <th id="T_c5564_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_c5564_row1_col0" class="data row1 col0" >73.480000</td>
#       <td id="T_c5564_row1_col1" class="data row1 col1" >15.150000</td>
#     </tr>
#     <tr>
#       <th id="T_c5564_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_c5564_row2_col0" class="data row2 col0" >16.450000</td>
#       <td id="T_c5564_row2_col1" class="data row2 col1" >14.530000</td>
#     </tr>
#     <tr>
#       <th id="T_c5564_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_c5564_row3_col0" class="data row3 col0" >1.990000</td>
#       <td id="T_c5564_row3_col1" class="data row3 col1" >1.900000</td>
#     </tr>
#     <tr>
#       <th id="T_c5564_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_c5564_row4_col0" class="data row4 col0" >14.780000</td>
#       <td id="T_c5564_row4_col1" class="data row4 col1" >15.430000</td>
#     </tr>
#     <tr>
#       <th id="T_c5564_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_c5564_row5_col0" class="data row5 col0" >15.230000</td>
#       <td id="T_c5564_row5_col1" class="data row5 col1" >10.300000</td>
#     </tr>
#     <tr>
#       <th id="T_c5564_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_c5564_row6_col0" class="data row6 col0" >0.160000</td>
#       <td id="T_c5564_row6_col1" class="data row6 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c5564_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_c5564_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_c5564_row7_col1" class="data row7 col1" >0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_c5564_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_c5564_row8_col0" class="data row8 col0" >0.840000</td>
#       <td id="T_c5564_row8_col1" class="data row8 col1" >0.920000</td>
#     </tr>
#     <tr>
#       <th id="T_c5564_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_c5564_row9_col0" class="data row9 col0" >7.260000</td>
#       <td id="T_c5564_row9_col1" class="data row9 col1" >3.820000</td>
#     </tr>
#     <tr>
#       <th id="T_c5564_level0_row10" class="row_heading level0 row10" >education</th>
#       <td id="T_c5564_row10_col0" class="data row10 col0" >1.000000</td>
#       <td id="T_c5564_row10_col1" class="data row10 col1" >1.180000</td>
#     </tr>
#     <tr>
#       <th id="T_c5564_level0_row11" class="row_heading level0 row11" >gender</th>
#       <td id="T_c5564_row11_col0" class="data row11 col0" >0.360000</td>
#       <td id="T_c5564_row11_col1" class="data row11 col1" >0.380000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# score | general

# %% [markdown]
# ##### 3 clusters

# %%
sample_original['mm_ward3'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 3
    ).fit_predict(sample_mm_scl)

# %%
groupby_mean(sample_original, 'mm_ward3', True, 12)
# Out:
# # observations per cluster: [18509, 944, 4973]
# <style type="text/css">
# #T_ad262_row0_col0, #T_ad262_row0_col1, #T_ad262_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ad262_row0_col2 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_ad262_row1_col0 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_ad262_row1_col1 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_ad262_row2_col0 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_ad262_row2_col1 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_ad262_row2_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_ad262_row3_col0, #T_ad262_row3_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_ad262_row3_col2, #T_ad262_row6_col1, #T_ad262_row8_col0, #T_ad262_row8_col1, #T_ad262_row10_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_ad262_row4_col0 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_ad262_row4_col1 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_ad262_row4_col2 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_ad262_row5_col0 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_ad262_row5_col1 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_ad262_row5_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_ad262_row6_col0, #T_ad262_row6_col2, #T_ad262_row7_col0, #T_ad262_row7_col1, #T_ad262_row7_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ad262_row8_col2, #T_ad262_row11_col0, #T_ad262_row11_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_ad262_row9_col0 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_ad262_row9_col1 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_ad262_row9_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_ad262_row10_col0 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_ad262_row10_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_ad262_row11_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_ad262">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mm_ward3</th>
#       <th id="T_ad262_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_ad262_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_ad262_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad262_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_ad262_row0_col0" class="data row0 col0" >37.490000</td>
#       <td id="T_ad262_row0_col1" class="data row0 col1" >39.460000</td>
#       <td id="T_ad262_row0_col2" class="data row0 col2" >40.490000</td>
#     </tr>
#     <tr>
#       <th id="T_ad262_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_ad262_row1_col0" class="data row1 col0" >15.150000</td>
#       <td id="T_ad262_row1_col1" class="data row1 col1" >38.310000</td>
#       <td id="T_ad262_row1_col2" class="data row1 col2" >80.160000</td>
#     </tr>
#     <tr>
#       <th id="T_ad262_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_ad262_row2_col0" class="data row2 col0" >14.530000</td>
#       <td id="T_ad262_row2_col1" class="data row2 col1" >16.160000</td>
#       <td id="T_ad262_row2_col2" class="data row2 col2" >16.510000</td>
#     </tr>
#     <tr>
#       <th id="T_ad262_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_ad262_row3_col0" class="data row3 col0" >1.900000</td>
#       <td id="T_ad262_row3_col1" class="data row3 col1" >1.940000</td>
#       <td id="T_ad262_row3_col2" class="data row3 col2" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ad262_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_ad262_row4_col0" class="data row4 col0" >15.430000</td>
#       <td id="T_ad262_row4_col1" class="data row4 col1" >14.700000</td>
#       <td id="T_ad262_row4_col2" class="data row4 col2" >14.800000</td>
#     </tr>
#     <tr>
#       <th id="T_ad262_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_ad262_row5_col0" class="data row5 col0" >10.300000</td>
#       <td id="T_ad262_row5_col1" class="data row5 col1" >31.210000</td>
#       <td id="T_ad262_row5_col2" class="data row5 col2" >12.200000</td>
#     </tr>
#     <tr>
#       <th id="T_ad262_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_ad262_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_ad262_row6_col1" class="data row6 col1" >1.000000</td>
#       <td id="T_ad262_row6_col2" class="data row6 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ad262_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_ad262_row7_col0" class="data row7 col0" >0.010000</td>
#       <td id="T_ad262_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_ad262_row7_col2" class="data row7 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ad262_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_ad262_row8_col0" class="data row8 col0" >0.920000</td>
#       <td id="T_ad262_row8_col1" class="data row8 col1" >0.980000</td>
#       <td id="T_ad262_row8_col2" class="data row8 col2" >0.810000</td>
#     </tr>
#     <tr>
#       <th id="T_ad262_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_ad262_row9_col0" class="data row9 col0" >3.820000</td>
#       <td id="T_ad262_row9_col1" class="data row9 col1" >5.150000</td>
#       <td id="T_ad262_row9_col2" class="data row9 col2" >7.660000</td>
#     </tr>
#     <tr>
#       <th id="T_ad262_level0_row10" class="row_heading level0 row10" >education</th>
#       <td id="T_ad262_row10_col0" class="data row10 col0" >1.180000</td>
#       <td id="T_ad262_row10_col1" class="data row10 col1" >0.930000</td>
#       <td id="T_ad262_row10_col2" class="data row10 col2" >1.010000</td>
#     </tr>
#     <tr>
#       <th id="T_ad262_level0_row11" class="row_heading level0 row11" >gender</th>
#       <td id="T_ad262_row11_col0" class="data row11 col0" >0.380000</td>
#       <td id="T_ad262_row11_col1" class="data row11 col1" >0.380000</td>
#       <td id="T_ad262_row11_col2" class="data row11 col2" >0.360000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# general | promo+returns | score

# %% [markdown]
# ##### 4 clusters

# %%
sample_original['mm_ward4'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 4
    ).fit_predict(sample_mm_scl)

# %%
groupby_mean(sample_original, 'mm_ward4', True, 12)
# Out:
# # observations per cluster: [17036, 1473, 4973, 944]
# <style type="text/css">
# #T_e6cb9_row0_col0, #T_e6cb9_row0_col1, #T_e6cb9_row0_col3, #T_e6cb9_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e6cb9_row0_col2 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_e6cb9_row1_col0 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_e6cb9_row1_col1 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_e6cb9_row1_col3 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_e6cb9_row2_col0 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_e6cb9_row2_col1, #T_e6cb9_row4_col1 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_e6cb9_row2_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_e6cb9_row2_col3 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_e6cb9_row3_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_e6cb9_row3_col1, #T_e6cb9_row8_col1, #T_e6cb9_row10_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_e6cb9_row3_col2, #T_e6cb9_row6_col3, #T_e6cb9_row8_col0, #T_e6cb9_row8_col3, #T_e6cb9_row10_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_e6cb9_row3_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_e6cb9_row4_col0 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_e6cb9_row4_col2 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_e6cb9_row4_col3 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_e6cb9_row5_col0 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_e6cb9_row5_col1, #T_e6cb9_row6_col0, #T_e6cb9_row6_col1, #T_e6cb9_row6_col2, #T_e6cb9_row7_col0, #T_e6cb9_row7_col1, #T_e6cb9_row7_col2, #T_e6cb9_row7_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e6cb9_row5_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_e6cb9_row5_col3 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_e6cb9_row8_col2, #T_e6cb9_row11_col0, #T_e6cb9_row11_col1, #T_e6cb9_row11_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_e6cb9_row9_col0 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_e6cb9_row9_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_e6cb9_row9_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_e6cb9_row9_col3 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_e6cb9_row10_col0 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_e6cb9_row10_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_e6cb9_row11_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_e6cb9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mm_ward4</th>
#       <th id="T_e6cb9_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e6cb9_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_e6cb9_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_e6cb9_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6cb9_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_e6cb9_row0_col0" class="data row0 col0" >37.340000</td>
#       <td id="T_e6cb9_row0_col1" class="data row0 col1" >39.180000</td>
#       <td id="T_e6cb9_row0_col2" class="data row0 col2" >40.490000</td>
#       <td id="T_e6cb9_row0_col3" class="data row0 col3" >39.460000</td>
#     </tr>
#     <tr>
#       <th id="T_e6cb9_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_e6cb9_row1_col0" class="data row1 col0" >13.720000</td>
#       <td id="T_e6cb9_row1_col1" class="data row1 col1" >31.600000</td>
#       <td id="T_e6cb9_row1_col2" class="data row1 col2" >80.160000</td>
#       <td id="T_e6cb9_row1_col3" class="data row1 col3" >38.310000</td>
#     </tr>
#     <tr>
#       <th id="T_e6cb9_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_e6cb9_row2_col0" class="data row2 col0" >14.450000</td>
#       <td id="T_e6cb9_row2_col1" class="data row2 col1" >15.400000</td>
#       <td id="T_e6cb9_row2_col2" class="data row2 col2" >16.510000</td>
#       <td id="T_e6cb9_row2_col3" class="data row2 col3" >16.160000</td>
#     </tr>
#     <tr>
#       <th id="T_e6cb9_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_e6cb9_row3_col0" class="data row3 col0" >2.000000</td>
#       <td id="T_e6cb9_row3_col1" class="data row3 col1" >0.750000</td>
#       <td id="T_e6cb9_row3_col2" class="data row3 col2" >2.000000</td>
#       <td id="T_e6cb9_row3_col3" class="data row3 col3" >1.940000</td>
#     </tr>
#     <tr>
#       <th id="T_e6cb9_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_e6cb9_row4_col0" class="data row4 col0" >15.420000</td>
#       <td id="T_e6cb9_row4_col1" class="data row4 col1" >15.460000</td>
#       <td id="T_e6cb9_row4_col2" class="data row4 col2" >14.800000</td>
#       <td id="T_e6cb9_row4_col3" class="data row4 col3" >14.700000</td>
#     </tr>
#     <tr>
#       <th id="T_e6cb9_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_e6cb9_row5_col0" class="data row5 col0" >11.180000</td>
#       <td id="T_e6cb9_row5_col1" class="data row5 col1" >0.090000</td>
#       <td id="T_e6cb9_row5_col2" class="data row5 col2" >12.200000</td>
#       <td id="T_e6cb9_row5_col3" class="data row5 col3" >31.210000</td>
#     </tr>
#     <tr>
#       <th id="T_e6cb9_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_e6cb9_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_e6cb9_row6_col1" class="data row6 col1" >0.050000</td>
#       <td id="T_e6cb9_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_e6cb9_row6_col3" class="data row6 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e6cb9_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_e6cb9_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_e6cb9_row7_col1" class="data row7 col1" >0.140000</td>
#       <td id="T_e6cb9_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_e6cb9_row7_col3" class="data row7 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e6cb9_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_e6cb9_row8_col0" class="data row8 col0" >0.950000</td>
#       <td id="T_e6cb9_row8_col1" class="data row8 col1" >0.650000</td>
#       <td id="T_e6cb9_row8_col2" class="data row8 col2" >0.810000</td>
#       <td id="T_e6cb9_row8_col3" class="data row8 col3" >0.980000</td>
#     </tr>
#     <tr>
#       <th id="T_e6cb9_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_e6cb9_row9_col0" class="data row9 col0" >3.740000</td>
#       <td id="T_e6cb9_row9_col1" class="data row9 col1" >4.730000</td>
#       <td id="T_e6cb9_row9_col2" class="data row9 col2" >7.660000</td>
#       <td id="T_e6cb9_row9_col3" class="data row9 col3" >5.150000</td>
#     </tr>
#     <tr>
#       <th id="T_e6cb9_level0_row10" class="row_heading level0 row10" >education</th>
#       <td id="T_e6cb9_row10_col0" class="data row10 col0" >1.180000</td>
#       <td id="T_e6cb9_row10_col1" class="data row10 col1" >nan</td>
#       <td id="T_e6cb9_row10_col2" class="data row10 col2" >1.010000</td>
#       <td id="T_e6cb9_row10_col3" class="data row10 col3" >0.930000</td>
#     </tr>
#     <tr>
#       <th id="T_e6cb9_level0_row11" class="row_heading level0 row11" >gender</th>
#       <td id="T_e6cb9_row11_col0" class="data row11 col0" >0.380000</td>
#       <td id="T_e6cb9_row11_col1" class="data row11 col1" >0.380000</td>
#       <td id="T_e6cb9_row11_col2" class="data row11 col2" >0.360000</td>
#       <td id="T_e6cb9_row11_col3" class="data row11 col3" >0.380000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# lowscore | nopromo | score | promo+returns

# %% [markdown]
# ##### 5 clusters

# %%
sample_original['mm_ward5'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 5
    ).fit_predict(sample_mm_scl)

# %%
groupby_mean(sample_original, 'mm_ward5', True, 12)
# Out:
# # observations per cluster: [9301, 1473, 4973, 944, 7735]
# <style type="text/css">
# #T_4d491_row0_col0, #T_4d491_row0_col1, #T_4d491_row0_col3, #T_4d491_row0_col4, #T_4d491_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_4d491_row0_col2 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_4d491_row1_col0 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_4d491_row1_col1 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_4d491_row1_col3 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_4d491_row1_col4, #T_4d491_row3_col1, #T_4d491_row8_col1, #T_4d491_row10_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_4d491_row2_col0 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_4d491_row2_col1, #T_4d491_row4_col1 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_4d491_row2_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_4d491_row2_col3, #T_4d491_row4_col4 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_4d491_row2_col4 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_4d491_row3_col0, #T_4d491_row3_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_4d491_row3_col2, #T_4d491_row6_col3, #T_4d491_row8_col0, #T_4d491_row8_col3, #T_4d491_row10_col0, #T_4d491_row10_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_4d491_row3_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_4d491_row4_col0 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_4d491_row4_col2 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_4d491_row4_col3 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_4d491_row5_col0 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_4d491_row5_col1, #T_4d491_row6_col0, #T_4d491_row6_col1, #T_4d491_row6_col2, #T_4d491_row6_col4, #T_4d491_row7_col0, #T_4d491_row7_col1, #T_4d491_row7_col2, #T_4d491_row7_col3, #T_4d491_row7_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_4d491_row5_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_4d491_row5_col3 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_4d491_row5_col4 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_4d491_row8_col2, #T_4d491_row9_col4, #T_4d491_row11_col0, #T_4d491_row11_col1, #T_4d491_row11_col3, #T_4d491_row11_col4 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_4d491_row8_col4 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_4d491_row9_col0 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_4d491_row9_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_4d491_row9_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_4d491_row9_col3 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_4d491_row10_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_4d491_row10_col4 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_4d491_row11_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_4d491">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mm_ward5</th>
#       <th id="T_4d491_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_4d491_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_4d491_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_4d491_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_4d491_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d491_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_4d491_row0_col0" class="data row0 col0" >35.920000</td>
#       <td id="T_4d491_row0_col1" class="data row0 col1" >39.180000</td>
#       <td id="T_4d491_row0_col2" class="data row0 col2" >40.490000</td>
#       <td id="T_4d491_row0_col3" class="data row0 col3" >39.460000</td>
#       <td id="T_4d491_row0_col4" class="data row0 col4" >39.050000</td>
#     </tr>
#     <tr>
#       <th id="T_4d491_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_4d491_row1_col0" class="data row1 col0" >24.720000</td>
#       <td id="T_4d491_row1_col1" class="data row1 col1" >31.600000</td>
#       <td id="T_4d491_row1_col2" class="data row1 col2" >80.160000</td>
#       <td id="T_4d491_row1_col3" class="data row1 col3" >38.310000</td>
#       <td id="T_4d491_row1_col4" class="data row1 col4" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_4d491_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_4d491_row2_col0" class="data row2 col0" >17.810000</td>
#       <td id="T_4d491_row2_col1" class="data row2 col1" >15.400000</td>
#       <td id="T_4d491_row2_col2" class="data row2 col2" >16.510000</td>
#       <td id="T_4d491_row2_col3" class="data row2 col3" >16.160000</td>
#       <td id="T_4d491_row2_col4" class="data row2 col4" >10.420000</td>
#     </tr>
#     <tr>
#       <th id="T_4d491_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_4d491_row3_col0" class="data row3 col0" >2.000000</td>
#       <td id="T_4d491_row3_col1" class="data row3 col1" >0.750000</td>
#       <td id="T_4d491_row3_col2" class="data row3 col2" >2.000000</td>
#       <td id="T_4d491_row3_col3" class="data row3 col3" >1.940000</td>
#       <td id="T_4d491_row3_col4" class="data row3 col4" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4d491_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_4d491_row4_col0" class="data row4 col0" >15.050000</td>
#       <td id="T_4d491_row4_col1" class="data row4 col1" >15.460000</td>
#       <td id="T_4d491_row4_col2" class="data row4 col2" >14.800000</td>
#       <td id="T_4d491_row4_col3" class="data row4 col3" >14.700000</td>
#       <td id="T_4d491_row4_col4" class="data row4 col4" >15.870000</td>
#     </tr>
#     <tr>
#       <th id="T_4d491_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_4d491_row5_col0" class="data row5 col0" >11.490000</td>
#       <td id="T_4d491_row5_col1" class="data row5 col1" >0.090000</td>
#       <td id="T_4d491_row5_col2" class="data row5 col2" >12.200000</td>
#       <td id="T_4d491_row5_col3" class="data row5 col3" >31.210000</td>
#       <td id="T_4d491_row5_col4" class="data row5 col4" >10.810000</td>
#     </tr>
#     <tr>
#       <th id="T_4d491_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_4d491_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_4d491_row6_col1" class="data row6 col1" >0.050000</td>
#       <td id="T_4d491_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_4d491_row6_col3" class="data row6 col3" >1.000000</td>
#       <td id="T_4d491_row6_col4" class="data row6 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4d491_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_4d491_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_4d491_row7_col1" class="data row7 col1" >0.140000</td>
#       <td id="T_4d491_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_4d491_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_4d491_row7_col4" class="data row7 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4d491_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_4d491_row8_col0" class="data row8 col0" >0.850000</td>
#       <td id="T_4d491_row8_col1" class="data row8 col1" >0.650000</td>
#       <td id="T_4d491_row8_col2" class="data row8 col2" >0.810000</td>
#       <td id="T_4d491_row8_col3" class="data row8 col3" >0.980000</td>
#       <td id="T_4d491_row8_col4" class="data row8 col4" >1.070000</td>
#     </tr>
#     <tr>
#       <th id="T_4d491_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_4d491_row9_col0" class="data row9 col0" >6.550000</td>
#       <td id="T_4d491_row9_col1" class="data row9 col1" >4.730000</td>
#       <td id="T_4d491_row9_col2" class="data row9 col2" >7.660000</td>
#       <td id="T_4d491_row9_col3" class="data row9 col3" >5.150000</td>
#       <td id="T_4d491_row9_col4" class="data row9 col4" >0.360000</td>
#     </tr>
#     <tr>
#       <th id="T_4d491_level0_row10" class="row_heading level0

# %% [markdown]
# general | nopromo | score | promo+returns | lowscore+new

# %% [markdown]
# #### Comparison

# %%
clusters_comparison(sample_original, 'mm_ward3', 'mm_ward2')
# Out:
#                     mm_ward2 0 Cluster  mm_ward2 1 Cluster
# mm_ward3 0 Cluster                   0               18509
# mm_ward3 1 Cluster                 944                   0
# mm_ward3 2 Cluster                4973                   0

# %%
clusters_comparison(sample_original, 'mm_ward4', 'mm_ward3')
# Out:
#                     mm_ward3 0 Cluster  mm_ward3 1 Cluster  mm_ward3 2 Cluster
# mm_ward4 0 Cluster               17036                   0                   0
# mm_ward4 1 Cluster                1473                   0                   0
# mm_ward4 2 Cluster                   0                   0                4973
# mm_ward4 3 Cluster                   0                 944                   0

# %%
clusters_comparison(sample_original, 'mm_ward5', 'mm_ward4')
# Out:
#                     mm_ward4 0 Cluster  mm_ward4 1 Cluster  \
# mm_ward5 0 Cluster                9301                   0
# mm_ward5 1 Cluster                   0                1473
# mm_ward5 2 Cluster                   0                   0
# mm_ward5 3 Cluster                   0                   0
# mm_ward5 4 Cluster                7735                   0
#
#                     mm_ward4 2 Cluster  mm_ward4 3 Cluster
# mm_ward5 0 Cluster                   0                   0
# mm_ward5 1 Cluster                   0                   0
# mm_ward5 2 Cluster                4973                   0
# mm_ward5 3 Cluster                   0                 944
# mm_ward5 4 Cluster                   0                   0

# %% [markdown]
# ### Robust Scaler <a id='h-rb'></a>

# %% [markdown]
# #### Plot

# %%
plot_dendrogram(sample_rb_scl, 'ward')

# %% [markdown]
# #### Models

# %% [markdown]
# ##### 3 clusters

# %%
sample_original['rb_ward3'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 3
    ).fit_predict(sample_rb_scl)

# %%
groupby_mean(sample_original, 'rb_ward3', True, 12)
# Out:
# # observations per cluster: [5035, 14721, 4670]
# <style type="text/css">
# #T_019f3_row0_col0, #T_019f3_row0_col1, #T_019f3_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_019f3_row0_col2 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_019f3_row1_col0 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_019f3_row1_col1 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_019f3_row2_col0 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_019f3_row2_col1 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_019f3_row2_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_019f3_row3_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_019f3_row3_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_019f3_row3_col2, #T_019f3_row8_col1 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_019f3_row4_col0 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_019f3_row4_col1 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_019f3_row4_col2 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_019f3_row5_col0 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_019f3_row5_col1 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_019f3_row5_col2 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_019f3_row6_col0, #T_019f3_row6_col1, #T_019f3_row6_col2, #T_019f3_row7_col0, #T_019f3_row7_col1, #T_019f3_row7_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_019f3_row8_col0 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_019f3_row8_col2, #T_019f3_row11_col0, #T_019f3_row11_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_019f3_row9_col0 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_019f3_row9_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_019f3_row9_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_019f3_row10_col0 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_019f3_row10_col1 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_019f3_row10_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_019f3_row11_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_019f3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >rb_ward3</th>
#       <th id="T_019f3_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_019f3_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_019f3_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_019f3_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_019f3_row0_col0" class="data row0 col0" >36.980000</td>
#       <td id="T_019f3_row0_col1" class="data row0 col1" >37.490000</td>
#       <td id="T_019f3_row0_col2" class="data row0 col2" >41.630000</td>
#     </tr>
#     <tr>
#       <th id="T_019f3_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_019f3_row1_col0" class="data row1 col0" >26.300000</td>
#       <td id="T_019f3_row1_col1" class="data row1 col1" >14.150000</td>
#       <td id="T_019f3_row1_col2" class="data row1 col2" >80.180000</td>
#     </tr>
#     <tr>
#       <th id="T_019f3_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_019f3_row2_col0" class="data row2 col0" >14.160000</td>
#       <td id="T_019f3_row2_col1" class="data row2 col1" >14.770000</td>
#       <td id="T_019f3_row2_col2" class="data row2 col2" >16.600000</td>
#     </tr>
#     <tr>
#       <th id="T_019f3_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_019f3_row3_col0" class="data row3 col0" >2.000000</td>
#       <td id="T_019f3_row3_col1" class="data row3 col1" >1.910000</td>
#       <td id="T_019f3_row3_col2" class="data row3 col2" >1.890000</td>
#     </tr>
#     <tr>
#       <th id="T_019f3_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_019f3_row4_col0" class="data row4 col0" >15.620000</td>
#       <td id="T_019f3_row4_col1" class="data row4 col1" >15.320000</td>
#       <td id="T_019f3_row4_col2" class="data row4 col2" >14.720000</td>
#     </tr>
#     <tr>
#       <th id="T_019f3_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_019f3_row5_col0" class="data row5 col0" >36.340000</td>
#       <td id="T_019f3_row5_col1" class="data row5 col1" >4.820000</td>
#       <td id="T_019f3_row5_col2" class="data row5 col2" >5.750000</td>
#     </tr>
#     <tr>
#       <th id="T_019f3_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_019f3_row6_col0" class="data row6 col0" >0.090000</td>
#       <td id="T_019f3_row6_col1" class="data row6 col1" >0.020000</td>
#       <td id="T_019f3_row6_col2" class="data row6 col2" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_019f3_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_019f3_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_019f3_row7_col1" class="data row7 col1" >0.010000</td>
#       <td id="T_019f3_row7_col2" class="data row7 col2" >0.020000</td>
#     </tr>
#     <tr>
#       <th id="T_019f3_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_019f3_row8_col0" class="data row8 col0" >1.330000</td>
#       <td id="T_019f3_row8_col1" class="data row8 col1" >0.800000</td>
#       <td id="T_019f3_row8_col2" class="data row8 col2" >0.780000</td>
#     </tr>
#     <tr>
#       <th id="T_019f3_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_019f3_row9_col0" class="data row9 col0" >4.130000</td>
#       <td id="T_019f3_row9_col1" class="data row9 col1" >3.870000</td>
#       <td id="T_019f3_row9_col2" class="data row9 col2" >7.690000</td>
#     </tr>
#     <tr>
#       <th id="T_019f3_level0_row10" class="row_heading level0 row10" >education</th>
#       <td id="T_019f3_row10_col0" class="data row10 col0" >1.040000</td>
#       <td id="T_019f3_row10_col1" class="data row10 col1" >1.210000</td>
#       <td id="T_019f3_row10_col2" class="data row10 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_019f3_level0_row11" class="row_heading level0 row11" >gender</th>
#       <td id="T_019f3_row11_col0" class="data row11 col0" >0.370000</td>
#       <td id="T_019f3_row11_col1" class="data row11 col1" >0.380000</td>
#       <td id="T_019f3_row11_col2" class="data row11 col2" >0.370000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# promo | general | score

# %% [markdown]
# ##### 4 clusters

# %%
sample_original['rb_ward4'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 4
    ).fit_predict(sample_rb_scl)

# %%
groupby_mean(sample_original, 'rb_ward4', True, 12)
# Out:
# # observations per cluster: [14721, 4463, 4670, 572]
# <style type="text/css">
# #T_e1478_row0_col0, #T_e1478_row0_col1, #T_e1478_row1_col2, #T_e1478_row5_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e1478_row0_col2 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_e1478_row0_col3 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_e1478_row1_col0, #T_e1478_row2_col1 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_e1478_row1_col1 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_e1478_row1_col3 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_e1478_row2_col0 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_e1478_row2_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_e1478_row2_col3 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_e1478_row3_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_e1478_row3_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_e1478_row3_col2, #T_e1478_row8_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_e1478_row3_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_e1478_row4_col0 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_e1478_row4_col1 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_e1478_row4_col2 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_e1478_row4_col3 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_e1478_row5_col0 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_e1478_row5_col1 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_e1478_row5_col2 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_e1478_row6_col0, #T_e1478_row6_col1, #T_e1478_row6_col2, #T_e1478_row7_col0, #T_e1478_row7_col1, #T_e1478_row7_col2, #T_e1478_row7_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e1478_row6_col3, #T_e1478_row11_col2, #T_e1478_row11_col3 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_e1478_row8_col1 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_e1478_row8_col2, #T_e1478_row8_col3, #T_e1478_row11_col0, #T_e1478_row11_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_e1478_row9_col0 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_e1478_row9_col1 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_e1478_row9_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_e1478_row9_col3 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_e1478_row10_col0 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_e1478_row10_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_e1478_row10_col2, #T_e1478_row10_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# </style>
# <table id="T_e1478">
#   <thead>
#     <tr>
#       <th class="index_name level0" >rb_ward4</th>
#       <th id="T_e1478_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e1478_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_e1478_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_e1478_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1478_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_e1478_row0_col0" class="data row0 col0" >37.490000</td>
#       <td id="T_e1478_row0_col1" class="data row0 col1" >36.760000</td>
#       <td id="T_e1478_row0_col2" class="data row0 col2" >41.630000</td>
#       <td id="T_e1478_row0_col3" class="data row0 col3" >38.620000</td>
#     </tr>
#     <tr>
#       <th id="T_e1478_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_e1478_row1_col0" class="data row1 col0" >14.150000</td>
#       <td id="T_e1478_row1_col1" class="data row1 col1" >24.490000</td>
#       <td id="T_e1478_row1_col2" class="data row1 col2" >80.180000</td>
#       <td id="T_e1478_row1_col3" class="data row1 col3" >40.420000</td>
#     </tr>
#     <tr>
#       <th id="T_e1478_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_e1478_row2_col0" class="data row2 col0" >14.770000</td>
#       <td id="T_e1478_row2_col1" class="data row2 col1" >13.840000</td>
#       <td id="T_e1478_row2_col2" class="data row2 col2" >16.600000</td>
#       <td id="T_e1478_row2_col3" class="data row2 col3" >16.710000</td>
#     </tr>
#     <tr>
#       <th id="T_e1478_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_e1478_row3_col0" class="data row3 col0" >1.910000</td>
#       <td id="T_e1478_row3_col1" class="data row3 col1" >2.000000</td>
#       <td id="T_e1478_row3_col2" class="data row3 col2" >1.890000</td>
#       <td id="T_e1478_row3_col3" class="data row3 col3" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1478_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_e1478_row4_col0" class="data row4 col0" >15.320000</td>
#       <td id="T_e1478_row4_col1" class="data row4 col1" >15.740000</td>
#       <td id="T_e1478_row4_col2" class="data row4 col2" >14.720000</td>
#       <td id="T_e1478_row4_col3" class="data row4 col3" >14.650000</td>
#     </tr>
#     <tr>
#       <th id="T_e1478_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_e1478_row5_col0" class="data row5 col0" >4.820000</td>
#       <td id="T_e1478_row5_col1" class="data row5 col1" >30.780000</td>
#       <td id="T_e1478_row5_col2" class="data row5 col2" >5.750000</td>
#       <td id="T_e1478_row5_col3" class="data row5 col3" >79.720000</td>
#     </tr>
#     <tr>
#       <th id="T_e1478_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_e1478_row6_col0" class="data row6 col0" >0.020000</td>
#       <td id="T_e1478_row6_col1" class="data row6 col1" >0.040000</td>
#       <td id="T_e1478_row6_col2" class="data row6 col2" >0.050000</td>
#       <td id="T_e1478_row6_col3" class="data row6 col3" >0.450000</td>
#     </tr>
#     <tr>
#       <th id="T_e1478_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_e1478_row7_col0" class="data row7 col0" >0.010000</td>
#       <td id="T_e1478_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_e1478_row7_col2" class="data row7 col2" >0.020000</td>
#       <td id="T_e1478_row7_col3" class="data row7 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e1478_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_e1478_row8_col0" class="data row8 col0" >0.800000</td>
#       <td id="T_e1478_row8_col1" class="data row8 col1" >1.390000</td>
#       <td id="T_e1478_row8_col2" class="data row8 col2" >0.780000</td>
#       <td id="T_e1478_row8_col3" class="data row8 col3" >0.920000</td>
#     </tr>
#     <tr>
#       <th id="T_e1478_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_e1478_row9_col0" class="data row9 col0" >3.870000</td>
#       <td id="T_e1478_row9_col1" class="data row9 col1" >3.950000</td>
#       <td id="T_e1478_row9_col2" class="data row9 col2" >7.690000</td>
#       <td id="T_e1478_row9_col3" class="data row9 col3" >5.510000</td>
#     </tr>
#     <tr>
#       <th id="T_e1478_level0_row10" class="row_heading level0 row10" >education</th>
#       <td id="T_e1478_row10_col0" class="data row10 col0" >1.210000</td>
#       <td id="T_e1478_row10_col1" class="data row10 col1" >1.050000</td>
#       <td id="T_e1478_row10_col2" class="data row10 col2" >1.000000</td>
#       <td id="T_e1478_row10_col3" class="data row10 col3" >0.970000</td>
#     </tr>
#     <tr>
#       <th id="T_e1478_level0_row11" class="row_heading level0 row11" >gender</th>
#       <td id="T_e1478_row11_col0" class="data row11 col0" >0.380000</td>
#       <td id="T_e1478_row11_col1" class="data row11 col1" >0.370000</td>
#       <td id="T_e1478_row11_col2" class="data row11 col2" >0.370000</td>
#       <td id="T_e1478_row11_col3" class="data row11 col3" >0.380000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# general | promo1 | score | promo2

# %% [markdown]
# ##### 5 clusters

# %%
sample_original['rb_ward5'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 5
    ).fit_predict(sample_rb_scl)

# %%
groupby_mean(sample_original, 'rb_ward5', True, 12)
# Out:
# # observations per cluster: [10280, 4463, 4670, 572, 4441]
# <style type="text/css">
# #T_ce830_row0_col0, #T_ce830_row0_col1, #T_ce830_row0_col4, #T_ce830_row1_col2, #T_ce830_row5_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ce830_row0_col2 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_ce830_row0_col3 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_ce830_row1_col0 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_ce830_row1_col1 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_ce830_row1_col3 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_ce830_row1_col4 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_ce830_row2_col0 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_ce830_row2_col1, #T_ce830_row4_col0 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_ce830_row2_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_ce830_row2_col3 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_ce830_row2_col4 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_ce830_row3_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_ce830_row3_col1, #T_ce830_row3_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_ce830_row3_col2, #T_ce830_row8_col0, #T_ce830_row8_col4 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_ce830_row3_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_ce830_row4_col1 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_ce830_row4_col2 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_ce830_row4_col3 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_ce830_row4_col4 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_ce830_row5_col0 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_ce830_row5_col1 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_ce830_row5_col2 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_ce830_row5_col4 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_ce830_row6_col0, #T_ce830_row6_col1, #T_ce830_row6_col2, #T_ce830_row6_col4, #T_ce830_row7_col0, #T_ce830_row7_col1, #T_ce830_row7_col2, #T_ce830_row7_col3, #T_ce830_row7_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ce830_row6_col3, #T_ce830_row11_col2, #T_ce830_row11_col3 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_ce830_row8_col1, #T_ce830_row10_col4 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_ce830_row8_col2, #T_ce830_row8_col3, #T_ce830_row11_col0, #T_ce830_row11_col1, #T_ce830_row11_col4 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_ce830_row9_col0 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_ce830_row9_col1 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_ce830_row9_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_ce830_row9_col3 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_ce830_row9_col4 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_ce830_row10_col0, #T_ce830_row10_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_ce830_row10_col2, #T_ce830_row10_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# </style>
# <table id="T_ce830">
#   <thead>
#     <tr>
#       <th class="index_name level0" >rb_ward5</th>
#       <th id="T_ce830_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_ce830_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_ce830_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_ce830_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_ce830_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce830_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_ce830_row0_col0" class="data row0 col0" >37.050000</td>
#       <td id="T_ce830_row0_col1" class="data row0 col1" >36.760000</td>
#       <td id="T_ce830_row0_col2" class="data row0 col2" >41.630000</td>
#       <td id="T_ce830_row0_col3" class="data row0 col3" >38.620000</td>
#       <td id="T_ce830_row0_col4" class="data row0 col4" >38.510000</td>
#     </tr>
#     <tr>
#       <th id="T_ce830_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_ce830_row1_col0" class="data row1 col0" >15.170000</td>
#       <td id="T_ce830_row1_col1" class="data row1 col1" >24.490000</td>
#       <td id="T_ce830_row1_col2" class="data row1 col2" >80.180000</td>
#       <td id="T_ce830_row1_col3" class="data row1 col3" >40.420000</td>
#       <td id="T_ce830_row1_col4" class="data row1 col4" >11.790000</td>
#     </tr>
#     <tr>
#       <th id="T_ce830_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_ce830_row2_col0" class="data row2 col0" >16.670000</td>
#       <td id="T_ce830_row2_col1" class="data row2 col1" >13.840000</td>
#       <td id="T_ce830_row2_col2" class="data row2 col2" >16.600000</td>
#       <td id="T_ce830_row2_col3" class="data row2 col3" >16.710000</td>
#       <td id="T_ce830_row2_col4" class="data row2 col4" >10.370000</td>
#     </tr>
#     <tr>
#       <th id="T_ce830_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_ce830_row3_col0" class="data row3 col0" >1.870000</td>
#       <td id="T_ce830_row3_col1" class="data row3 col1" >2.000000</td>
#       <td id="T_ce830_row3_col2" class="data row3 col2" >1.890000</td>
#       <td id="T_ce830_row3_col3" class="data row3 col3" >2.000000</td>
#       <td id="T_ce830_row3_col4" class="data row3 col4" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ce830_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_ce830_row4_col0" class="data row4 col0" >13.930000</td>
#       <td id="T_ce830_row4_col1" class="data row4 col1" >15.740000</td>
#       <td id="T_ce830_row4_col2" class="data row4 col2" >14.720000</td>
#       <td id="T_ce830_row4_col3" class="data row4 col3" >14.650000</td>
#       <td id="T_ce830_row4_col4" class="data row4 col4" >18.560000</td>
#     </tr>
#     <tr>
#       <th id="T_ce830_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_ce830_row5_col0" class="data row5 col0" >4.410000</td>
#       <td id="T_ce830_row5_col1" class="data row5 col1" >30.780000</td>
#       <td id="T_ce830_row5_col2" class="data row5 col2" >5.750000</td>
#       <td id="T_ce830_row5_col3" class="data row5 col3" >79.720000</td>
#       <td id="T_ce830_row5_col4" class="data row5 col4" >5.770000</td>
#     </tr>
#     <tr>
#       <th id="T_ce830_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_ce830_row6_col0" class="data row6 col0" >0.020000</td>
#       <td id="T_ce830_row6_col1" class="data row6 col1" >0.040000</td>
#       <td id="T_ce830_row6_col2" class="data row6 col2" >0.050000</td>
#       <td id="T_ce830_row6_col3" class="data row6 col3" >0.450000</td>
#       <td id="T_ce830_row6_col4" class="data row6 col4" >0.020000</td>
#     </tr>
#     <tr>
#       <th id="T_ce830_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_ce830_row7_col0" class="data row7 col0" >0.010000</td>
#       <td id="T_ce830_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_ce830_row7_col2" class="data row7 col2" >0.020000</td>
#       <td id="T_ce830_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_ce830_row7_col4" class="data row7 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ce830_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_ce830_row8_col0" class="data row8 col0" >0.800000</td>
#       <td id="T_ce830_row8_col1" class="data row8 col1" >1.390000</td>
#       <td id="T_ce830_row8_col2" class="data row8 col2" >0.780000</td>
#       <td id="T_ce830_row8_col3" class="data row8 col3" >0.920000</td>
#       <td id="T_ce830_row8_col4" class="data row8 col4" >0.800000</td>
#     </tr>
#     <tr>
#       <th id="T_ce830_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_ce830_row9_col0" class="data row9 col0" >4.190000</td>
#       <td id="T_ce830_row9_col1" class="data row9 col1" >3.950000</td>
#       <td id="T_ce830_row9_col2" class="data row9 col2" >7.690000</td>
#       <td id="T_ce830_ro

# %% [markdown]
# general | promo1 | score | promo2 | lowscore?+new

# %% [markdown]
# #### Comparison

# %%
clusters_comparison(sample_original, 'rb_ward4', 'rb_ward3')
# Out:
#                     rb_ward3 0 Cluster  rb_ward3 1 Cluster  rb_ward3 2 Cluster
# rb_ward4 0 Cluster                   0               14721                   0
# rb_ward4 1 Cluster                4463                   0                   0
# rb_ward4 2 Cluster                   0                   0                4670
# rb_ward4 3 Cluster                 572                   0                   0

# %%
clusters_comparison(sample_original, 'rb_ward5', 'rb_ward4')
# Out:
#                     rb_ward4 0 Cluster  rb_ward4 1 Cluster  \
# rb_ward5 0 Cluster               10280                   0
# rb_ward5 1 Cluster                   0                4463
# rb_ward5 2 Cluster                   0                   0
# rb_ward5 3 Cluster                   0                   0
# rb_ward5 4 Cluster                4441                   0
#
#                     rb_ward4 2 Cluster  rb_ward4 3 Cluster
# rb_ward5 0 Cluster                   0                   0
# rb_ward5 1 Cluster                   0                   0
# rb_ward5 2 Cluster                4670                   0
# rb_ward5 3 Cluster                   0                 572
# rb_ward5 4 Cluster                   0                   0

# %% [markdown]
# ### Inter clustering Comparison <a id='icc'></a>

# %% [markdown]
# #### Scaler Comparison
# In this section it is possible understand that **minmax scaler** is the one that presented more **consistent results**, in the sense that independently of the clustering method used (hierarchical with ward or kmeans), the clustering solutions it presented were very similar and the observations belonging to the clusters formed also had less variation.

# %% [markdown]
# ##### No Scaler

# %%
clusters_comparison(sample_original, 'no_kmeans3', 'no_ward3')
# Out:
#                       no_ward3 0 Cluster  no_ward3 1 Cluster  \
# no_kmeans3 0 Cluster               10304                   0
# no_kmeans3 1 Cluster                   0                5744
# no_kmeans3 2 Cluster                1157                   0
#
#                       no_ward3 2 Cluster
# no_kmeans3 0 Cluster                  75
# no_kmeans3 1 Cluster                   0
# no_kmeans3 2 Cluster                7146

# %%
clusters_comparison(sample_original, 'no_kmeans4', 'no_ward4')
# Out:
#                       no_ward4 0 Cluster  no_ward4 1 Cluster  \
# no_kmeans4 0 Cluster                   0                 553
# no_kmeans4 1 Cluster                5531                   0
# no_kmeans4 2 Cluster                   0                1643
# no_kmeans4 3 Cluster                 213                1068
#
#                       no_ward4 2 Cluster  no_ward4 3 Cluster
# no_kmeans4 0 Cluster                7142                   0
# no_kmeans4 1 Cluster                   0                   0
# no_kmeans4 2 Cluster                  72                8197
# no_kmeans4 3 Cluster                   7                   0

# %%
clusters_comparison(sample_original, 'no_kmeans5', 'no_ward5')
# Out:
#                       no_ward5 0 Cluster  no_ward5 1 Cluster  \
# no_kmeans5 0 Cluster                   0                2530
# no_kmeans5 1 Cluster                4629                   0
# no_kmeans5 2 Cluster                   0                 200
# no_kmeans5 3 Cluster                   0                 482
# no_kmeans5 4 Cluster                  50                  52
#
#                       no_ward5 2 Cluster  no_ward5 3 Cluster  \
# no_kmeans5 0 Cluster                  47                 159
# no_kmeans5 1 Cluster                   0                   0
# no_kmeans5 2 Cluster                 125                8038
# no_kmeans5 3 Cluster                7049                   0
# no_kmeans5 4 Cluster                   0                   0
#
#                       no_ward5 4 Cluster
# no_kmeans5 0 Cluster                   0
# no_kmeans5 1 Cluster                 446
# no_kmeans5 2 Cluster                   0
# no_kmeans5 3 Cluster                   0
# no_kmeans5 4 Cluster                 619

# %% [markdown]
# ##### Standard Scaler

# %% [markdown]
# No options were tested with the same number of clusters

# %% [markdown]
# ##### MinMax Scaler

# %%
clusters_comparison(sample_original, 'mm_kmeans3', 'mm_ward3')
# Out:
#                       mm_ward3 0 Cluster  mm_ward3 1 Cluster  \
# mm_kmeans3 0 Cluster               18066                   0
# mm_kmeans3 1 Cluster                 362                   0
# mm_kmeans3 2 Cluster                  81                 944
#
#                       mm_ward3 2 Cluster
# mm_kmeans3 0 Cluster                   0
# mm_kmeans3 1 Cluster                4973
# mm_kmeans3 2 Cluster                   0

# %%
clusters_comparison(sample_original, 'mm_kmeans4', 'mm_ward4')
# Out:
#                       mm_ward4 0 Cluster  mm_ward4 1 Cluster  \
# mm_kmeans4 0 Cluster                9832                 515
# mm_kmeans4 1 Cluster                   0                 362
# mm_kmeans4 2 Cluster                7204                 515
# mm_kmeans4 3 Cluster                   0                  81
#
#                       mm_ward4 2 Cluster  mm_ward4 3 Cluster
# mm_kmeans4 0 Cluster                   0                   0
# mm_kmeans4 1 Cluster                4973                   0
# mm_kmeans4 2 Cluster                   0                   0
# mm_kmeans4 3 Cluster                   0                 944

# %%
clusters_comparison(sample_original, 'mm_kmeans5', 'mm_ward5')
# Out:
#                       mm_ward5 0 Cluster  mm_ward5 1 Cluster  \
# mm_kmeans5 0 Cluster                6250                  11
# mm_kmeans5 1 Cluster                   0                  81
# mm_kmeans5 2 Cluster                   0                 270
# mm_kmeans5 3 Cluster                   0                1105
# mm_kmeans5 4 Cluster                3051                   6
#
#                       mm_ward5 2 Cluster  mm_ward5 3 Cluster  \
# mm_kmeans5 0 Cluster                   0                   0
# mm_kmeans5 1 Cluster                   0                 944
# mm_kmeans5 2 Cluster                4973                   0
# mm_kmeans5 3 Cluster                   0                   0
# mm_kmeans5 4 Cluster                   0                   0
#
#                       mm_ward5 4 Cluster
# mm_kmeans5 0 Cluster                 983
# mm_kmeans5 1 Cluster                   0
# mm_kmeans5 2 Cluster                   0
# mm_kmeans5 3 Cluster                   0
# mm_kmeans5 4 Cluster                6752

# %% [markdown]
# ##### Robust Scaler

# %%
clusters_comparison(sample_original, 'rb_kmeans3', 'rb_ward3')
# Out:
#                       rb_ward3 0 Cluster  rb_ward3 1 Cluster  \
# rb_kmeans3 0 Cluster                 447                  28
# rb_kmeans3 1 Cluster                3180                   9
# rb_kmeans3 2 Cluster                1408               14684
#
#                       rb_ward3 2 Cluster
# rb_kmeans3 0 Cluster                4623
# rb_kmeans3 1 Cluster                  47
# rb_kmeans3 2 Cluster                   0

# %%
clusters_comparison(sample_original, 'rb_kmeans4', 'rb_ward4')
# Out:
#                       rb_ward4 0 Cluster  rb_ward4 1 Cluster  \
# rb_kmeans4 0 Cluster                7104                1038
# rb_kmeans4 1 Cluster                7590                 616
# rb_kmeans4 2 Cluster                   8                2365
# rb_kmeans4 3 Cluster                  19                 444
#
#                       rb_ward4 2 Cluster  rb_ward4 3 Cluster
# rb_kmeans4 0 Cluster                   0                   0
# rb_kmeans4 1 Cluster                   0                   0
# rb_kmeans4 2 Cluster                  47                 572
# rb_kmeans4 3 Cluster                4623                   0

# %% [markdown]
# ## 4.3. DBScan <a id='dbs'></a>

# %% [markdown]
# In this section **DBScan** will be run using the algorithm that preformed best until now (**minmax**). Firstly, a Kdist graph was plotted (to help find the right eps value) and, then, **parameters were adjusted**, and clustering solutions created. These solutions were once again compared.

# %% [markdown]
# ### MinMax Scaler <a id='dbs-mm'></a>

# %% [markdown]
# #### Plot

# %%
plot_kdist_graph(sample_mm_scl, demographic_metrics)

# %% [markdown]
# #### Models

# %% [markdown]
# ##### 3 clusters

# %%
dbscan = DBSCAN(eps=0.22, min_samples=90, n_jobs=4)
dbscan_labels = dbscan.fit_predict(sample_mm_scl)
dbscan_n_clusters = len(np.unique(dbscan_labels))
sample_original['mm_dbs3'] = dbscan_labels

print("Number of estimated clusters  : %d" % dbscan_n_clusters)
print("Counter of cluster labels     :", Counter(dbscan_labels))
print("Percentage of noise rows      :", round(100*Counter(dbscan_labels)[-1]/sample_mm_scl.shape[0],2))
# Out:
# Number of estimated clusters  : 4
# Counter of cluster labels     : Counter({np.int64(0): 16864, np.int64(1): 4835, np.int64(-1): 2237, np.int64(2): 490})
# Percentage of noise rows      : 9.16

# %%
groupby_mean(sample_original, 'mm_dbs3', True)
# Out:
# # observations per cluster: [2237, 16864, 4835, 490]
# <style type="text/css">
# #T_4d809_row0_col0 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_4d809_row0_col1, #T_4d809_row0_col3, #T_4d809_row1_col0, #T_4d809_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_4d809_row0_col2 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_4d809_row1_col1 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_4d809_row1_col3 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_4d809_row2_col0 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_4d809_row2_col1 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_4d809_row2_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_4d809_row2_col3 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_4d809_row3_col0 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_4d809_row3_col1, #T_4d809_row9_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_4d809_row3_col2, #T_4d809_row3_col3, #T_4d809_row8_col1, #T_4d809_row12_col1, #T_4d809_row12_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_4d809_row4_col0 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_4d809_row4_col1 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_4d809_row4_col2 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_4d809_row4_col3 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_4d809_row5_col0 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_4d809_row5_col1 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_4d809_row5_col2, #T_4d809_row9_col0 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_4d809_row5_col3, #T_4d809_row6_col1, #T_4d809_row6_col2, #T_4d809_row6_col3, #T_4d809_row7_col0, #T_4d809_row7_col1, #T_4d809_row7_col2, #T_4d809_row7_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_4d809_row6_col0, #T_4d809_row8_col2, #T_4d809_row11_col1, #T_4d809_row11_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_4d809_row8_col0, #T_4d809_row10_col2, #T_4d809_row12_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_4d809_row8_col3, #T_4d809_row10_col0, #T_4d809_row12_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_4d809_row9_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_4d809_row9_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_4d809_row10_col1 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_4d809_row10_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_4d809_row11_col0, #T_4d809_row11_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_4d809">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mm_dbs3</th>
#       <th id="T_4d809_level0_col0" class="col_heading level0 col0" >-1</th>
#       <th id="T_4d809_level0_col1" class="col_heading level0 col1" >0</th>
#       <th id="T_4d809_level0_col2" class="col_heading level0 col2" >1</th>
#       <th id="T_4d809_level0_col3" class="col_heading level0 col3" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d809_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_4d809_row0_col0" class="data row0 col0" >40.010000</td>
#       <td id="T_4d809_row0_col1" class="data row0 col1" >37.320000</td>
#       <td id="T_4d809_row0_col2" class="data row0 col2" >40.270000</td>
#       <td id="T_4d809_row0_col3" class="data row0 col3" >38.640000</td>
#     </tr>
#     <tr>
#       <th id="T_4d809_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_4d809_row1_col0" class="data row1 col0" >41.840000</td>
#       <td id="T_4d809_row1_col1" class="data row1 col1" >13.690000</td>
#       <td id="T_4d809_row1_col2" class="data row1 col2" >80.120000</td>
#       <td id="T_4d809_row1_col3" class="data row1 col3" >6.780000</td>
#     </tr>
#     <tr>
#       <th id="T_4d809_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_4d809_row2_col0" class="data row2 col0" >16.650000</td>
#       <td id="T_4d809_row2_col1" class="data row2 col1" >14.410000</td>
#       <td id="T_4d809_row2_col2" class="data row2 col2" >16.530000</td>
#       <td id="T_4d809_row2_col3" class="data row2 col3" >12.270000</td>
#     </tr>
#     <tr>
#       <th id="T_4d809_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_4d809_row3_col0" class="data row3 col0" >1.370000</td>
#       <td id="T_4d809_row3_col1" class="data row3 col1" >2.000000</td>
#       <td id="T_4d809_row3_col2" class="data row3 col2" >2.000000</td>
#       <td id="T_4d809_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4d809_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_4d809_row4_col0" class="data row4 col0" >14.780000</td>
#       <td id="T_4d809_row4_col1" class="data row4 col1" >15.440000</td>
#       <td id="T_4d809_row4_col2" class="data row4 col2" >14.820000</td>
#       <td id="T_4d809_row4_col3" class="data row4 col3" >16.180000</td>
#     </tr>
#     <tr>
#       <th id="T_4d809_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_4d809_row5_col0" class="data row5 col0" >23.000000</td>
#       <td id="T_4d809_row5_col1" class="data row5 col1" >10.550000</td>
#       <td id="T_4d809_row5_col2" class="data row5 col2" >10.650000</td>
#       <td id="T_4d809_row5_col3" class="data row5 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4d809_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_4d809_row6_col0" class="data row6 col0" >0.460000</td>
#       <td id="T_4d809_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_4d809_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_4d809_row6_col3" class="data row6 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4d809_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_4d809_row7_col0" class="data row7 col0" >0.090000</td>
#       <td id="T_4d809_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_4d809_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_4d809_row7_col3" class="data row7 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4d809_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_4d809_row8_col0" class="data row8 col0" >0.770000</td>
#       <td id="T_4d809_row8_col1" class="data row8 col1" >0.950000</td>
#       <td id="T_4d809_row8_col2" class="data row8 col2" >0.810000</td>
#       <td id="T_4d809_row8_col3" class="data row8 col3" >0.890000</td>
#     </tr>
#     <tr>
#       <th id="T_4d809_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_4d809_row9_col0" class="data row9 col0" >5.660000</td>
#       <td id="T_4d809_row9_col1" class="data row9 col1" >3.730000</td>
#       <td id="T_4d809_row9_col2" class="data row9 col2" >7.660000</td>
#       <td id="T_4d809_row9_col3" class="data row9 col3" >2.090000</td>
#     </tr>
#     <tr>
#       <th id="T_4d809_level0_row10" class="row_heading level0 row10" >education</th>
#       <td id="T_4d809_row10_col0" class="data row10 col0" >0.950000</td>
#       <td id="T_4d809_row10_col1" class="data row10 col1" >1.180000</td>
#       <td id="T_4d809_row10_col2" class="data row10 col2" >1.010000</td>
#       <td id="T_4d809_row10_col3" class="data row10 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_4d809_level0_row11" class="row_heading level0 row11" >gender</th>
#       <td id="T_4d809_row11_col0" class="data row11 col0" >0.380000</td>
#       <td id="T_4d809_row11_col1" class="data row11 col1" >0.380000</td>
#       <td id="T_4d809_row11_col2" class="data row11 col2" >0.360000</td>
#       <td id="T_4d809_row11_col3" class="data row11 col3" >0.370000</td>
#     </tr>
#     <tr>
#       <th id="T_4d809_level0_row12" class="row_heading level0 row12" >constant</th>
#       <td id="T_4d809_row12_col0" class="data row12 col0" >1.000000</td>
#       <td id="T_4d809_row12_col1" class="data row12 col1" >1.000000</td>
#       <td id="T_4d809_row12_col2" class="data row12 col2" >1.000000</td>
#       <td id="T_4d809_row12_col3" class="data row12 col3" >1.000000</td>

# %% [markdown]
# ##### 4 clusters

# %%
dbscan = DBSCAN(eps=0.23, min_samples=90, n_jobs=4)
dbscan_labels = dbscan.fit_predict(sample_mm_scl)
dbscan_n_clusters = len(np.unique(dbscan_labels))
sample_original['mm_dbs4'] = dbscan_labels

print("Number of estimated clusters  : %d" % dbscan_n_clusters)
print("Counter of cluster labels     :", Counter(dbscan_labels))
print("Percentage of noise rows      :", round(100*Counter(dbscan_labels)[-1]/sample_mm_scl.shape[0],2))
# Out:
# Number of estimated clusters  : 5
# Counter of cluster labels     : Counter({np.int64(0): 16885, np.int64(1): 4851, np.int64(-1): 1986, np.int64(2): 563, np.int64(3): 141})
# Percentage of noise rows      : 8.13

# %%
groupby_mean(sample_original, 'mm_dbs4', True)
# Out:
# # observations per cluster: [1986, 16885, 4851, 563, 141]
# <style type="text/css">
# #T_8d5b4_row0_col0 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_8d5b4_row0_col1, #T_8d5b4_row0_col3, #T_8d5b4_row0_col4, #T_8d5b4_row1_col0, #T_8d5b4_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_8d5b4_row0_col2 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_8d5b4_row1_col1 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_8d5b4_row1_col3 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_8d5b4_row1_col4, #T_8d5b4_row3_col0 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_8d5b4_row2_col0 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_8d5b4_row2_col1 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_8d5b4_row2_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_8d5b4_row2_col3 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_8d5b4_row2_col4 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_8d5b4_row3_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_8d5b4_row3_col2, #T_8d5b4_row3_col3, #T_8d5b4_row8_col1, #T_8d5b4_row12_col1, #T_8d5b4_row12_col3, #T_8d5b4_row12_col4 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_8d5b4_row3_col4, #T_8d5b4_row5_col3, #T_8d5b4_row5_col4, #T_8d5b4_row6_col1, #T_8d5b4_row6_col2, #T_8d5b4_row6_col3, #T_8d5b4_row6_col4, #T_8d5b4_row7_col0, #T_8d5b4_row7_col1, #T_8d5b4_row7_col2, #T_8d5b4_row7_col3, #T_8d5b4_row7_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_8d5b4_row4_col0 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_8d5b4_row4_col1 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_8d5b4_row4_col2 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_8d5b4_row4_col3 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_8d5b4_row4_col4 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_8d5b4_row5_col0 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_8d5b4_row5_col1 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_8d5b4_row5_col2 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_8d5b4_row6_col0, #T_8d5b4_row8_col2, #T_8d5b4_row9_col4, #T_8d5b4_row11_col1, #T_8d5b4_row11_col3, #T_8d5b4_row11_col4 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_8d5b4_row8_col0, #T_8d5b4_row10_col0, #T_8d5b4_row10_col2, #T_8d5b4_row12_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_8d5b4_row8_col3, #T_8d5b4_row12_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_8d5b4_row8_col4, #T_8d5b4_row11_col0, #T_8d5b4_row11_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_8d5b4_row9_col0 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_8d5b4_row9_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_8d5b4_row9_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_8d5b4_row9_col3 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_8d5b4_row10_col1 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_8d5b4_row10_col3, #T_8d5b4_row10_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8d5b4">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mm_dbs4</th>
#       <th id="T_8d5b4_level0_col0" class="col_heading level0 col0" >-1</th>
#       <th id="T_8d5b4_level0_col1" class="col_heading level0 col1" >0</th>
#       <th id="T_8d5b4_level0_col2" class="col_heading level0 col2" >1</th>
#       <th id="T_8d5b4_level0_col3" class="col_heading level0 col3" >2</th>
#       <th id="T_8d5b4_level0_col4" class="col_heading level0 col4" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d5b4_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_8d5b4_row0_col0" class="data row0 col0" >40.100000</td>
#       <td id="T_8d5b4_row0_col1" class="data row0 col1" >37.330000</td>
#       <td id="T_8d5b4_row0_col2" class="data row0 col2" >40.310000</td>
#       <td id="T_8d5b4_row0_col3" class="data row0 col3" >38.110000</td>
#       <td id="T_8d5b4_row0_col4" class="data row0 col4" >39.060000</td>
#     </tr>
#     <tr>
#       <th id="T_8d5b4_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_8d5b4_row1_col0" class="data row1 col0" >45.010000</td>
#       <td id="T_8d5b4_row1_col1" class="data row1 col1" >13.680000</td>
#       <td id="T_8d5b4_row1_col2" class="data row1 col2" >80.130000</td>
#       <td id="T_8d5b4_row1_col3" class="data row1 col3" >10.410000</td>
#       <td id="T_8d5b4_row1_col4" class="data row1 col4" >1.160000</td>
#     </tr>
#     <tr>
#       <th id="T_8d5b4_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_8d5b4_row2_col0" class="data row2 col0" >16.700000</td>
#       <td id="T_8d5b4_row2_col1" class="data row2 col1" >14.420000</td>
#       <td id="T_8d5b4_row2_col2" class="data row2 col2" >16.520000</td>
#       <td id="T_8d5b4_row2_col3" class="data row2 col3" >12.720000</td>
#       <td id="T_8d5b4_row2_col4" class="data row2 col4" >15.990000</td>
#     </tr>
#     <tr>
#       <th id="T_8d5b4_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_8d5b4_row3_col0" class="data row3 col0" >1.470000</td>
#       <td id="T_8d5b4_row3_col1" class="data row3 col1" >2.000000</td>
#       <td id="T_8d5b4_row3_col2" class="data row3 col2" >2.000000</td>
#       <td id="T_8d5b4_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_8d5b4_row3_col4" class="data row3 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8d5b4_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_8d5b4_row4_col0" class="data row4 col0" >14.620000</td>
#       <td id="T_8d5b4_row4_col1" class="data row4 col1" >15.440000</td>
#       <td id="T_8d5b4_row4_col2" class="data row4 col2" >14.820000</td>
#       <td id="T_8d5b4_row4_col3" class="data row4 col3" >16.060000</td>
#       <td id="T_8d5b4_row4_col4" class="data row4 col4" >17.010000</td>
#     </tr>
#     <tr>
#       <th id="T_8d5b4_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_8d5b4_row5_col0" class="data row5 col0" >24.900000</td>
#       <td id="T_8d5b4_row5_col1" class="data row5 col1" >10.610000</td>
#       <td id="T_8d5b4_row5_col2" class="data row5 col2" >10.770000</td>
#       <td id="T_8d5b4_row5_col3" class="data row5 col3" >0.010000</td>
#       <td id="T_8d5b4_row5_col4" class="data row5 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8d5b4_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_8d5b4_row6_col0" class="data row6 col0" >0.520000</td>
#       <td id="T_8d5b4_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_8d5b4_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_8d5b4_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_8d5b4_row6_col4" class="data row6 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8d5b4_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_8d5b4_row7_col0" class="data row7 col0" >0.110000</td>
#       <td id="T_8d5b4_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_8d5b4_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_8d5b4_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_8d5b4_row7_col4" class="data row7 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8d5b4_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_8d5b4_row8_col0" class="data row8 col0" >0.810000</td>
#       <td id="T_8d5b4_row8_col1" class="data row8 col1" >0.950000</td>
#       <td id="T_8d5b4_row8_col2" class="data row8 col2" >0.810000</td>
#       <td id="T_8d5b4_row8_col3" class="data row8 col3" >0.880000</td>
#       <td id="T_8d5b4_row8_col4" class="data row8 col4" >0.280000</td>
#     </tr>
#     <tr>
#       <th id="T_8d5b4_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_8d5b4_row9_col0" class="data row9 col0" >5.970000</td>
#       <td id="T_8d5b4_row9_col1" class="data row9 col1" >3.730000</td>
#       <td id="T_8d5b4_row9_col2" class="data row9 col2" >7.660000</td>
#       <td id="T_8d5b4_row9_col3" class="data row9 col3" >2.810000</td

# %% [markdown]
# ##### 5 clusters

# %%
dbscan = DBSCAN(eps=0.1, min_samples=35, n_jobs=4)
dbscan_labels = dbscan.fit_predict(sample_mm_scl)
sample_original['mm_dbs5'] = dbscan_labels
dbscan_n_clusters = len(np.unique(dbscan_labels))

print("Number of estimated clusters  : %d" % dbscan_n_clusters)
print("Counter of cluster labels     :", Counter(dbscan_labels))
print("Percentage of noise rows      :", round(100*Counter(dbscan_labels)[-1]/sample_mm_scl.shape[0],2))
# Out:
# Number of estimated clusters  : 6
# Counter of cluster labels     : Counter({np.int64(0): 8293, np.int64(-1): 7388, np.int64(2): 5392, np.int64(1): 3267, np.int64(3): 58, np.int64(4): 28})
# Percentage of noise rows      : 30.25

# %%
groupby_mean(sample_original, 'mm_dbs5', True)
# Out:
# # observations per cluster: [7388, 8293, 3267, 5392, 58, 28]
# <style type="text/css">
# #T_500b3_row0_col0, #T_500b3_row0_col1, #T_500b3_row0_col3, #T_500b3_row0_col4, #T_500b3_row0_col5, #T_500b3_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_500b3_row0_col2 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_500b3_row1_col0 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_500b3_row1_col1, #T_500b3_row1_col4, #T_500b3_row9_col5, #T_500b3_row10_col2, #T_500b3_row12_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_500b3_row1_col3 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_500b3_row1_col5, #T_500b3_row3_col2, #T_500b3_row3_col4, #T_500b3_row3_col5, #T_500b3_row8_col1, #T_500b3_row8_col3, #T_500b3_row8_col4, #T_500b3_row8_col5, #T_500b3_row12_col0, #T_500b3_row12_col1, #T_500b3_row12_col4, #T_500b3_row12_col5 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_500b3_row2_col0 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_500b3_row2_col1 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_500b3_row2_col2 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_500b3_row2_col3 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_500b3_row2_col4 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_500b3_row2_col5 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_500b3_row3_col0 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_500b3_row3_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_500b3_row3_col3 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_500b3_row4_col0 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_500b3_row4_col1 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_500b3_row4_col2 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_500b3_row4_col3 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_500b3_row4_col4 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_500b3_row4_col5 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_500b3_row5_col0 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_500b3_row5_col1 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_500b3_row5_col2 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_500b3_row5_col3 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_500b3_row5_col4, #T_500b3_row5_col5, #T_500b3_row6_col0, #T_500b3_row6_col1, #T_500b3_row6_col2, #T_500b3_row6_col3, #T_500b3_row6_col4, #T_500b3_row6_col5, #T_500b3_row7_col0, #T_500b3_row7_col1, #T_500b3_row7_col2, #T_500b3_row7_col3, #T_500b3_row7_col4, #T_500b3_row7_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_500b3_row8_col0, #T_500b3_row10_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_500b3_row8_col2, #T_500b3_row9_col1, #T_500b3_row11_col0, #T_500b3_row11_col1, #T_500b3_row11_col3, #T_500b3_row11_col4 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_500b3_row9_col0 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_500b3_row9_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_500b3_row9_col3 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_500b3_row9_col4, #T_500b3_row11_col2, #T_500b3_row11_col5 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_500b3_row10_col1, #T_500b3_row10_col3 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_500b3_row10_col4, #T_500b3_row10_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_500b3_row12_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# </style>
# <table id="T_500b3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mm_dbs5</th>
#       <th id="T_500b3_level0_col0" class="col_heading level0 col0" >-1</th>
#       <th id="T_500b3_level0_col1" class="col_heading level0 col1" >0</th>
#       <th id="T_500b3_level0_col2" class="col_heading level0 col2" >1</th>
#       <th id="T_500b3_level0_col3" class="col_heading level0 col3" >2</th>
#       <th id="T_500b3_level0_col4" class="col_heading level0 col4" >3</th>
#       <th id="T_500b3_level0_col5" class="col_heading level0 col5" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_500b3_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_500b3_row0_col0" class="data row0 col0" >41.160000</td>
#       <td id="T_500b3_row0_col1" class="data row0 col1" >38.530000</td>
#       <td id="T_500b3_row0_col2" class="data row0 col2" >38.430000</td>
#       <td id="T_500b3_row0_col3" class="data row0 col3" >33.390000</td>
#       <td id="T_500b3_row0_col4" class="data row0 col4" >37.190000</td>
#       <td id="T_500b3_row0_col5" class="data row0 col5" >39.460000</td>
#     </tr>
#     <tr>
#       <th id="T_500b3_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_500b3_row1_col0" class="data row1 col0" >39.220000</td>
#       <td id="T_500b3_row1_col1" class="data row1 col1" >0.510000</td>
#       <td id="T_500b3_row1_col2" class="data row1 col2" >79.580000</td>
#       <td id="T_500b3_row1_col3" class="data row1 col3" >29.890000</td>
#       <td id="T_500b3_row1_col4" class="data row1 col4" >0.600000</td>
#       <td id="T_500b3_row1_col5" class="data row1 col5" >0.970000</td>
#     </tr>
#     <tr>
#       <th id="T_500b3_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_500b3_row2_col0" class="data row2 col0" >17.330000</td>
#       <td id="T_500b3_row2_col1" class="data row2 col1" >12.020000</td>
#       <td id="T_500b3_row2_col2" class="data row2 col2" >16.000000</td>
#       <td id="T_500b3_row2_col3" class="data row2 col3" >15.810000</td>
#       <td id="T_500b3_row2_col4" class="data row2 col4" >10.360000</td>
#       <td id="T_500b3_row2_col5" class="data row2 col5" >13.540000</td>
#     </tr>
#     <tr>
#       <th id="T_500b3_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_500b3_row3_col0" class="data row3 col0" >1.750000</td>
#       <td id="T_500b3_row3_col1" class="data row3 col1" >2.000000</td>
#       <td id="T_500b3_row3_col2" class="data row3 col2" >2.000000</td>
#       <td id="T_500b3_row3_col3" class="data row3 col3" >2.000000</td>
#       <td id="T_500b3_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_500b3_row3_col5" class="data row3 col5" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_500b3_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_500b3_row4_col0" class="data row4 col0" >14.550000</td>
#       <td id="T_500b3_row4_col1" class="data row4 col1" >15.880000</td>
#       <td id="T_500b3_row4_col2" class="data row4 col2" >15.230000</td>
#       <td id="T_500b3_row4_col3" class="data row4 col3" >15.330000</td>
#       <td id="T_500b3_row4_col4" class="data row4 col4" >14.950000</td>
#       <td id="T_500b3_row4_col5" class="data row4 col5" >18.430000</td>
#     </tr>
#     <tr>
#       <th id="T_500b3_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_500b3_row5_col0" class="data row5 col0" >20.760000</td>
#       <td id="T_500b3_row5_col1" class="data row5 col1" >9.530000</td>
#       <td id="T_500b3_row5_col2" class="data row5 col2" >5.790000</td>
#       <td id="T_500b3_row5_col3" class="data row5 col3" >5.470000</td>
#       <td id="T_500b3_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_500b3_row5_col5" class="data row5 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_500b3_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_500b3_row6_col0" class="data row6 col0" >0.140000</td>
#       <td id="T_500b3_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_500b3_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_500b3_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_500b3_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_500b3_row6_col5" class="data row6 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_500b3_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_500b3_row7_col0" class="data row7 col0" >0.030000</td>
#       <td id="T_500b3_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_500b3_row7_col2" class="data row7 col2" >0.000000</td>

# %% [markdown]
# #### Comparison

# %%
clusters_comparison(sample_original, 'mm_dbs4', 'mm_dbs3')
# Out:
#                    mm_dbs3 0 Cluster  mm_dbs3 1 Cluster  mm_dbs3 2 Cluster  \
# mm_dbs4 0 Cluster               1986                  0                  0
# mm_dbs4 1 Cluster                 21              16864                  0
# mm_dbs4 2 Cluster                 16                  0               4835
# mm_dbs4 3 Cluster                 73                  0                  0
# mm_dbs4 4 Cluster                141                  0                  0
#
#                    mm_dbs3 3 Cluster
# mm_dbs4 0 Cluster                  0
# mm_dbs4 1 Cluster                  0
# mm_dbs4 2 Cluster                  0
# mm_dbs4 3 Cluster                490
# mm_dbs4 4 Cluster                  0

# %%
clusters_comparison(sample_original, 'mm_dbs5', 'mm_dbs4')
# Out:
#                    mm_dbs4 0 Cluster  mm_dbs4 1 Cluster  mm_dbs4 2 Cluster  \
# mm_dbs5 0 Cluster               1986               3200               1584
# mm_dbs5 1 Cluster                  0               8293                  0
# mm_dbs5 2 Cluster                  0                  0               3267
# mm_dbs5 3 Cluster                  0               5392                  0
# mm_dbs5 4 Cluster                  0                  0                  0
# mm_dbs5 5 Cluster                  0                  0                  0
#
#                    mm_dbs4 3 Cluster  mm_dbs4 4 Cluster
# mm_dbs5 0 Cluster                477                141
# mm_dbs5 1 Cluster                  0                  0
# mm_dbs5 2 Cluster                  0                  0
# mm_dbs5 3 Cluster                  0                  0
# mm_dbs5 4 Cluster                 58                  0
# mm_dbs5 5 Cluster                 28                  0

# %% [markdown]
# ### Conclusions <a id='conc'></a>

# %% [markdown]
# Based on the results obtained, DBScan was discarded from further study as it recurrently gave clustering result with either one very lage cluster along other very small ones or with a significant amount of outliers.
#
# Having said this, the 2 solutions that were deemed most fit until now were ward hierarchical clustering and kmeans both with 5 clusters. These solutions were chosen as they provided clustering solutions that were consistent with the clusters most frequently found in the testing phase as well as ones that made sense.

# %% [markdown]
# # 5. UMAP <a id='u'></a>

# %% [markdown]
# In this section, the four clustering solutions mentioned in the [conclusion of the previous section](#conc) (minmax kmeans with 4 clusters, minmax kmeans with 5 clusters, minmax ward with 4 clusters, and minmax ward with 5 clusters) were visualized using umap to ensure the custers' consistency. Then, if deemed acceptable, the clustering solutions were implemented to the whole dataset.

# %% [markdown]
# ### Create the embeddings

# %%
umap_object = umap.UMAP(random_state=1)

# %%
# embeddings for samples
umap_embedding_mm = umap_object.fit_transform(sample_mm_scl)

# embeddings for the whole dataset
umap_embedding_mm_all = umap_object.fit_transform(demographic_mm_scl)

# %% [markdown]
# ### UMAP for samples

# %% [markdown]
# ##### MinMax - Kmeans - 5 clusters

# %%
visualize_dimensionality_reduction(umap_embedding_mm, sample_original['mm_kmeans5'])

# %% [markdown]
# ##### Minmax - Ward - 5 clusters

# %%
visualize_dimensionality_reduction(umap_embedding_mm, sample_original['mm_ward5'])

# %% [markdown]
# ##### Conclusion
#
# From these UMAPs, it was possible to conclude that ward hierarchical clustering likely provided a better separation of clusters, however, both solutions were brought to the next phase of joining clustering perspectives.

# %% [markdown]
# # 6. Final solution <a id='f'></a>

# %% [markdown]
# ## Generalization to the whole dataset

# %% [markdown]
# ### Kmeans - MinMax - 5 clusters

# %%
kmeans = KMeans(n_clusters = 5, init='k-means++', n_init=20,  random_state = 1).fit(demographic_mm_scl)
demographic['mm_kmeans5'] = kmeans.predict(demographic_mm_scl)

# %%
groupby_mean(demographic, 'mm_kmeans5', True, 12)
# Out:
# # observations per cluster: [26001, 49331, 5648, 35985, 5164]
# <style type="text/css">
# #T_56fea_row0_col0 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_56fea_row0_col1, #T_56fea_row0_col2, #T_56fea_row0_col3, #T_56fea_row0_col4, #T_56fea_row1_col0, #T_56fea_row1_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_56fea_row1_col1 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_56fea_row1_col2 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_56fea_row1_col3 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_56fea_row2_col0 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_56fea_row2_col1 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_56fea_row2_col2 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_56fea_row2_col3 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_56fea_row2_col4 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_56fea_row3_col0, #T_56fea_row8_col1, #T_56fea_row8_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_56fea_row3_col1, #T_56fea_row3_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_56fea_row3_col2, #T_56fea_row8_col2, #T_56fea_row10_col0, #T_56fea_row10_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_56fea_row3_col4 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_56fea_row4_col0 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_56fea_row4_col1 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_56fea_row4_col2 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_56fea_row4_col3 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_56fea_row4_col4 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_56fea_row5_col0 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_56fea_row5_col1 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_56fea_row5_col2, #T_56fea_row6_col0, #T_56fea_row6_col1, #T_56fea_row6_col2, #T_56fea_row6_col3, #T_56fea_row7_col0, #T_56fea_row7_col1, #T_56fea_row7_col2, #T_56fea_row7_col3, #T_56fea_row7_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_56fea_row5_col3 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_56fea_row5_col4 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_56fea_row6_col4, #T_56fea_row8_col4, #T_56fea_row10_col4 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_56fea_row8_col0, #T_56fea_row11_col1, #T_56fea_row11_col2, #T_56fea_row11_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_56fea_row9_col0, #T_56fea_row9_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_56fea_row9_col1 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_56fea_row9_col3 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_56fea_row9_col4 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_56fea_row10_col1 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_56fea_row10_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_56fea_row11_col0, #T_56fea_row11_col4 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_56fea">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mm_kmeans5</th>
#       <th id="T_56fea_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_56fea_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_56fea_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_56fea_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_56fea_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56fea_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_56fea_row0_col0" class="data row0 col0" >40.800000</td>
#       <td id="T_56fea_row0_col1" class="data row0 col1" >37.470000</td>
#       <td id="T_56fea_row0_col2" class="data row0 col2" >38.550000</td>
#       <td id="T_56fea_row0_col3" class="data row0 col3" >37.150000</td>
#       <td id="T_56fea_row0_col4" class="data row0 col4" >40.150000</td>
#     </tr>
#     <tr>
#       <th id="T_56fea_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_56fea_row1_col0" class="data row1 col0" >80.160000</td>
#       <td id="T_56fea_row1_col1" class="data row1 col1" >8.880000</td>
#       <td id="T_56fea_row1_col2" class="data row1 col2" >17.010000</td>
#       <td id="T_56fea_row1_col3" class="data row1 col3" >20.230000</td>
#       <td id="T_56fea_row1_col4" class="data row1 col4" >40.030000</td>
#     </tr>
#     <tr>
#       <th id="T_56fea_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_56fea_row2_col0" class="data row2 col0" >16.460000</td>
#       <td id="T_56fea_row2_col1" class="data row2 col1" >8.570000</td>
#       <td id="T_56fea_row2_col2" class="data row2 col2" >14.890000</td>
#       <td id="T_56fea_row2_col3" class="data row2 col3" >22.580000</td>
#       <td id="T_56fea_row2_col4" class="data row2 col4" >16.180000</td>
#     </tr>
#     <tr>
#       <th id="T_56fea_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_56fea_row3_col0" class="data row3 col0" >1.950000</td>
#       <td id="T_56fea_row3_col1" class="data row3 col1" >2.000000</td>
#       <td id="T_56fea_row3_col2" class="data row3 col2" >0.640000</td>
#       <td id="T_56fea_row3_col3" class="data row3 col3" >2.000000</td>
#       <td id="T_56fea_row3_col4" class="data row3 col4" >1.880000</td>
#     </tr>
#     <tr>
#       <th id="T_56fea_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_56fea_row4_col0" class="data row4 col0" >14.790000</td>
#       <td id="T_56fea_row4_col1" class="data row4 col1" >15.640000</td>
#       <td id="T_56fea_row4_col2" class="data row4 col2" >15.560000</td>
#       <td id="T_56fea_row4_col3" class="data row4 col3" >15.180000</td>
#       <td id="T_56fea_row4_col4" class="data row4 col4" >14.710000</td>
#     </tr>
#     <tr>
#       <th id="T_56fea_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_56fea_row5_col0" class="data row5 col0" >11.490000</td>
#       <td id="T_56fea_row5_col1" class="data row5 col1" >12.370000</td>
#       <td id="T_56fea_row5_col2" class="data row5 col2" >0.030000</td>
#       <td id="T_56fea_row5_col3" class="data row5 col3" >9.570000</td>
#       <td id="T_56fea_row5_col4" class="data row5 col4" >29.460000</td>
#     </tr>
#     <tr>
#       <th id="T_56fea_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_56fea_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_56fea_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_56fea_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_56fea_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_56fea_row6_col4" class="data row6 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_56fea_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_56fea_row7_col0" class="data row7 col0" >0.010000</td>
#       <td id="T_56fea_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_56fea_row7_col2" class="data row7 col2" >0.050000</td>
#       <td id="T_56fea_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_56fea_row7_col4" class="data row7 col4" >0.070000</td>
#     </tr>
#     <tr>
#       <th id="T_56fea_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_56fea_row8_col0" class="data row8 col0" >0.810000</td>
#       <td id="T_56fea_row8_col1" class="data row8 col1" >0.990000</td>
#       <td id="T_56fea_row8_col2" class="data row8 col2" >0.600000</td>
#       <td id="T_56fea_row8_col3" class="data row8 col3" >0.880000</td>
#       <td id="T_56fea_row8_col4" class="data row8 col4" >0.960000</td>
#     </tr>
#     <tr>
#       <th id="T_56fea_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_56fea_row9_col0" class="data row9 col0" >7.670000</td>
#       <td id="T_56fea_row9_col1" class="data row9 col1" >2.510000</td>
#       <td id="T_56fea_row9_col2" class="data row9 col2" >3.690000</td>
#       <td id="T_56fea_row9_col3" class="data row9 col3" >5.370000</td>
#       <td id="T_56fea_row9_col4" class="data row9 co

# %% [markdown]
# score | lowscore+new | nopromo | antiques | promo+returns

# %% [markdown]
# ---

# %% [markdown]
# ### Ward - MinMax - 5 clusters

# %% [markdown]
# Dividing the dataset in two to run the hierarchical clustering. This is needed as this algorithm is too computationally expensive to run with all the data.

# %%
dem1, dem2 = train_test_split(demographic, test_size=0.5, random_state=1, shuffle=True)
dem1_mm_scl, dem2_mm_scl = train_test_split(demographic_mm_scl, test_size=0.5, random_state=1, shuffle=True)

# %%
# Part 1
dem1['mm_ward5'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 5
    ).fit_predict(dem1_mm_scl)

# %%
# Part 2
dem2['mm_ward5'] = AgglomerativeClustering(
    linkage = 'ward', n_clusters = 5
    ).fit_predict(dem2_mm_scl)

# %%
groupby_mean(dem1, 'mm_ward5', True)
# Out:
# # observations per cluster: [19414, 3650, 12343, 2393, 23264]
# <style type="text/css">
# #T_477fc_row0_col0, #T_477fc_row0_col1, #T_477fc_row0_col3, #T_477fc_row0_col4, #T_477fc_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_477fc_row0_col2 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_477fc_row1_col0 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_477fc_row1_col1 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_477fc_row1_col3 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_477fc_row1_col4 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_477fc_row2_col0 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_477fc_row2_col1, #T_477fc_row4_col1 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_477fc_row2_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_477fc_row2_col3 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_477fc_row2_col4 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_477fc_row3_col0, #T_477fc_row3_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_477fc_row3_col1, #T_477fc_row8_col1, #T_477fc_row10_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_477fc_row3_col2, #T_477fc_row6_col3, #T_477fc_row8_col3, #T_477fc_row8_col4, #T_477fc_row9_col4, #T_477fc_row10_col0, #T_477fc_row10_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_477fc_row3_col3, #T_477fc_row12_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_477fc_row4_col0 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_477fc_row4_col2 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_477fc_row4_col3 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_477fc_row4_col4 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_477fc_row5_col0 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_477fc_row5_col1, #T_477fc_row6_col0, #T_477fc_row6_col1, #T_477fc_row6_col2, #T_477fc_row6_col4, #T_477fc_row7_col0, #T_477fc_row7_col1, #T_477fc_row7_col2, #T_477fc_row7_col3, #T_477fc_row7_col4, #T_477fc_row12_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_477fc_row5_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_477fc_row5_col3 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_477fc_row5_col4 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_477fc_row8_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_477fc_row8_col2, #T_477fc_row11_col0, #T_477fc_row11_col1, #T_477fc_row11_col3, #T_477fc_row11_col4 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_477fc_row9_col0 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_477fc_row9_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_477fc_row9_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_477fc_row9_col3 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_477fc_row10_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_477fc_row10_col4, #T_477fc_row12_col4 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_477fc_row11_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_477fc_row12_col0 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_477fc_row12_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# </style>
# <table id="T_477fc">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mm_ward5</th>
#       <th id="T_477fc_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_477fc_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_477fc_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_477fc_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_477fc_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_477fc_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_477fc_row0_col0" class="data row0 col0" >36.070000</td>
#       <td id="T_477fc_row0_col1" class="data row0 col1" >39.010000</td>
#       <td id="T_477fc_row0_col2" class="data row0 col2" >41.010000</td>
#       <td id="T_477fc_row0_col3" class="data row0 col3" >40.030000</td>
#       <td id="T_477fc_row0_col4" class="data row0 col4" >38.430000</td>
#     </tr>
#     <tr>
#       <th id="T_477fc_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_477fc_row1_col0" class="data row1 col0" >26.780000</td>
#       <td id="T_477fc_row1_col1" class="data row1 col1" >30.280000</td>
#       <td id="T_477fc_row1_col2" class="data row1 col2" >80.130000</td>
#       <td id="T_477fc_row1_col3" class="data row1 col3" >39.060000</td>
#       <td id="T_477fc_row1_col4" class="data row1 col4" >2.840000</td>
#     </tr>
#     <tr>
#       <th id="T_477fc_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_477fc_row2_col0" class="data row2 col0" >18.180000</td>
#       <td id="T_477fc_row2_col1" class="data row2 col1" >15.320000</td>
#       <td id="T_477fc_row2_col2" class="data row2 col2" >16.500000</td>
#       <td id="T_477fc_row2_col3" class="data row2 col3" >16.060000</td>
#       <td id="T_477fc_row2_col4" class="data row2 col4" >11.430000</td>
#     </tr>
#     <tr>
#       <th id="T_477fc_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_477fc_row3_col0" class="data row3 col0" >2.000000</td>
#       <td id="T_477fc_row3_col1" class="data row3 col1" >0.750000</td>
#       <td id="T_477fc_row3_col2" class="data row3 col2" >2.000000</td>
#       <td id="T_477fc_row3_col3" class="data row3 col3" >1.920000</td>
#       <td id="T_477fc_row3_col4" class="data row3 col4" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_477fc_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_477fc_row4_col0" class="data row4 col0" >15.330000</td>
#       <td id="T_477fc_row4_col1" class="data row4 col1" >15.370000</td>
#       <td id="T_477fc_row4_col2" class="data row4 col2" >14.740000</td>
#       <td id="T_477fc_row4_col3" class="data row4 col3" >14.830000</td>
#       <td id="T_477fc_row4_col4" class="data row4 col4" >15.560000</td>
#     </tr>
#     <tr>
#       <th id="T_477fc_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_477fc_row5_col0" class="data row5 col0" >7.940000</td>
#       <td id="T_477fc_row5_col1" class="data row5 col1" >0.060000</td>
#       <td id="T_477fc_row5_col2" class="data row5 col2" >12.040000</td>
#       <td id="T_477fc_row5_col3" class="data row5 col3" >31.430000</td>
#       <td id="T_477fc_row5_col4" class="data row5 col4" >13.910000</td>
#     </tr>
#     <tr>
#       <th id="T_477fc_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_477fc_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_477fc_row6_col1" class="data row6 col1" >0.050000</td>
#       <td id="T_477fc_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_477fc_row6_col3" class="data row6 col3" >1.000000</td>
#       <td id="T_477fc_row6_col4" class="data row6 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_477fc_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_477fc_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_477fc_row7_col1" class="data row7 col1" >0.130000</td>
#       <td id="T_477fc_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_477fc_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_477fc_row7_col4" class="data row7 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_477fc_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_477fc_row8_col0" class="data row8 col0" >0.830000</td>
#       <td id="T_477fc_row8_col1" class="data row8 col1" >0.660000</td>
#       <td id="T_477fc_row8_col2" class="data row8 col2" >0.810000</td>
#       <td id="T_477fc_row8_col3" class="data row8 col3" >0.980000</td>
#       <td id="T_477fc_row8_col4" class="data row8 col4" >1.050000</td>
#     </tr>
#     <tr>
#       <th id="T_477fc_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_477fc_row9_col0" class="data row9 col0" >6.990000</td>
#       <td id="T_477fc_row9_col1" class="data row9 col1" >4.63

# %% [markdown]
# antiques | nopromo | score | promo+returns | lowscore+new

# %%
groupby_mean(dem2, 'mm_ward5', True)
# Out:
# # observations per cluster: [3771, 25425, 12310, 2408, 17151]
# <style type="text/css">
# #T_60ed3_row0_col0, #T_60ed3_row0_col1, #T_60ed3_row0_col3, #T_60ed3_row0_col4, #T_60ed3_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_60ed3_row0_col2 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_60ed3_row1_col0 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_60ed3_row1_col1 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_60ed3_row1_col3 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_60ed3_row1_col4, #T_60ed3_row2_col0 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_60ed3_row2_col1 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_60ed3_row2_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_60ed3_row2_col3 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_60ed3_row2_col4 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_60ed3_row3_col0, #T_60ed3_row8_col0, #T_60ed3_row10_col2, #T_60ed3_row10_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_60ed3_row3_col1, #T_60ed3_row3_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_60ed3_row3_col2, #T_60ed3_row6_col3, #T_60ed3_row8_col1, #T_60ed3_row8_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_60ed3_row3_col3, #T_60ed3_row12_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_60ed3_row4_col0 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_60ed3_row4_col1 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_60ed3_row4_col2 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_60ed3_row4_col3 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_60ed3_row4_col4 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_60ed3_row5_col0, #T_60ed3_row6_col0, #T_60ed3_row6_col1, #T_60ed3_row6_col2, #T_60ed3_row6_col4, #T_60ed3_row7_col0, #T_60ed3_row7_col1, #T_60ed3_row7_col2, #T_60ed3_row7_col3, #T_60ed3_row7_col4, #T_60ed3_row12_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_60ed3_row5_col1 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_60ed3_row5_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_60ed3_row5_col3 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_60ed3_row5_col4 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_60ed3_row8_col2, #T_60ed3_row11_col0, #T_60ed3_row11_col1, #T_60ed3_row11_col3, #T_60ed3_row11_col4 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_60ed3_row8_col4, #T_60ed3_row10_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_60ed3_row9_col0 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_60ed3_row9_col1 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_60ed3_row9_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_60ed3_row9_col3 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_60ed3_row9_col4 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_60ed3_row10_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_60ed3_row10_col1 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_60ed3_row11_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_60ed3_row12_col1 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_60ed3_row12_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_60ed3_row12_col4 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# </style>
# <table id="T_60ed3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mm_ward5</th>
#       <th id="T_60ed3_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_60ed3_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_60ed3_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_60ed3_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_60ed3_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60ed3_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_60ed3_row0_col0" class="data row0 col0" >39.080000</td>
#       <td id="T_60ed3_row0_col1" class="data row0 col1" >36.500000</td>
#       <td id="T_60ed3_row0_col2" class="data row0 col2" >40.680000</td>
#       <td id="T_60ed3_row0_col3" class="data row0 col3" >39.590000</td>
#       <td id="T_60ed3_row0_col4" class="data row0 col4" >38.550000</td>
#     </tr>
#     <tr>
#       <th id="T_60ed3_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_60ed3_row1_col0" class="data row1 col0" >30.530000</td>
#       <td id="T_60ed3_row1_col1" class="data row1 col1" >12.690000</td>
#       <td id="T_60ed3_row1_col2" class="data row1 col2" >80.070000</td>
#       <td id="T_60ed3_row1_col3" class="data row1 col3" >39.030000</td>
#       <td id="T_60ed3_row1_col4" class="data row1 col4" >14.970000</td>
#     </tr>
#     <tr>
#       <th id="T_60ed3_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_60ed3_row2_col0" class="data row2 col0" >15.150000</td>
#       <td id="T_60ed3_row2_col1" class="data row2 col1" >9.110000</td>
#       <td id="T_60ed3_row2_col2" class="data row2 col2" >16.480000</td>
#       <td id="T_60ed3_row2_col3" class="data row2 col3" >16.070000</td>
#       <td id="T_60ed3_row2_col4" class="data row2 col4" >22.380000</td>
#     </tr>
#     <tr>
#       <th id="T_60ed3_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_60ed3_row3_col0" class="data row3 col0" >0.760000</td>
#       <td id="T_60ed3_row3_col1" class="data row3 col1" >2.000000</td>
#       <td id="T_60ed3_row3_col2" class="data row3 col2" >2.000000</td>
#       <td id="T_60ed3_row3_col3" class="data row3 col3" >1.930000</td>
#       <td id="T_60ed3_row3_col4" class="data row3 col4" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_60ed3_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_60ed3_row4_col0" class="data row4 col0" >15.380000</td>
#       <td id="T_60ed3_row4_col1" class="data row4 col1" >15.260000</td>
#       <td id="T_60ed3_row4_col2" class="data row4 col2" >14.800000</td>
#       <td id="T_60ed3_row4_col3" class="data row4 col3" >14.720000</td>
#       <td id="T_60ed3_row4_col4" class="data row4 col4" >15.700000</td>
#     </tr>
#     <tr>
#       <th id="T_60ed3_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_60ed3_row5_col0" class="data row5 col0" >0.070000</td>
#       <td id="T_60ed3_row5_col1" class="data row5 col1" >13.470000</td>
#       <td id="T_60ed3_row5_col2" class="data row5 col2" >12.160000</td>
#       <td id="T_60ed3_row5_col3" class="data row5 col3" >31.950000</td>
#       <td id="T_60ed3_row5_col4" class="data row5 col4" >7.830000</td>
#     </tr>
#     <tr>
#       <th id="T_60ed3_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_60ed3_row6_col0" class="data row6 col0" >0.050000</td>
#       <td id="T_60ed3_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_60ed3_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_60ed3_row6_col3" class="data row6 col3" >1.000000</td>
#       <td id="T_60ed3_row6_col4" class="data row6 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_60ed3_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_60ed3_row7_col0" class="data row7 col0" >0.140000</td>
#       <td id="T_60ed3_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_60ed3_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_60ed3_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_60ed3_row7_col4" class="data row7 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_60ed3_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_60ed3_row8_col0" class="data row8 col0" >0.640000</td>
#       <td id="T_60ed3_row8_col1" class="data row8 col1" >0.980000</td>
#       <td id="T_60ed3_row8_col2" class="data row8 col2" >0.810000</td>
#       <td id="T_60ed3_row8_col3" class="data row8 col3" >0.960000</td>
#       <td id="T_60ed3_row8_col4" class="data row8 col4" >0.890000</td>
#     </tr>
#     <tr>
#       <th id="T_60ed3_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_60ed3_row9_col0"

# %% [markdown]
# nopromo | lowscore+new | score | promo+returns | antiques

# %%
# Define the mapping from values to categories
clusters_mapping = {
    0: 1,
    1: 4,
    2: 2,
    3: 3,
    4: 0
}
# Create a new variable based on the existing variable
dem2['mm_ward5'] = [clusters_mapping[value] for value in dem2['mm_ward5']]

# %%
combined_dem = pd.concat([dem1, dem2], ignore_index=False)
combined_dem.sort_index(inplace=True)
combined_dem.to_csv('Data/New_Data/combined_dem_ward5.csv', index=True)

# %%
groupby_mean(combined_dem, 'mm_ward5', True, 12)
# Out:
# # observations per cluster: [36565, 7421, 24653, 4801, 48689]
# <style type="text/css">
# #T_3efe1_row0_col0, #T_3efe1_row0_col1, #T_3efe1_row0_col3, #T_3efe1_row0_col4, #T_3efe1_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_3efe1_row0_col2 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_3efe1_row1_col0 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_3efe1_row1_col1 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_3efe1_row1_col3 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_3efe1_row1_col4, #T_3efe1_row5_col0 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_3efe1_row2_col0 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_3efe1_row2_col1 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_3efe1_row2_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_3efe1_row2_col3 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_3efe1_row2_col4 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_3efe1_row3_col0, #T_3efe1_row3_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_3efe1_row3_col1, #T_3efe1_row8_col1, #T_3efe1_row10_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_3efe1_row3_col2, #T_3efe1_row6_col3, #T_3efe1_row8_col3, #T_3efe1_row8_col4, #T_3efe1_row10_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_3efe1_row3_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_3efe1_row4_col0 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_3efe1_row4_col1 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_3efe1_row4_col2 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_3efe1_row4_col3 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_3efe1_row4_col4 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_3efe1_row5_col1, #T_3efe1_row6_col0, #T_3efe1_row6_col1, #T_3efe1_row6_col2, #T_3efe1_row6_col4, #T_3efe1_row7_col0, #T_3efe1_row7_col1, #T_3efe1_row7_col2, #T_3efe1_row7_col3, #T_3efe1_row7_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_3efe1_row5_col2, #T_3efe1_row9_col0 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_3efe1_row5_col3 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_3efe1_row5_col4 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_3efe1_row8_col0, #T_3efe1_row10_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_3efe1_row8_col2, #T_3efe1_row11_col0, #T_3efe1_row11_col1, #T_3efe1_row11_col3, #T_3efe1_row11_col4 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_3efe1_row9_col1 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_3efe1_row9_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_3efe1_row9_col3 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_3efe1_row9_col4 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_3efe1_row10_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_3efe1_row10_col4 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_3efe1_row11_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_3efe1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mm_ward5</th>
#       <th id="T_3efe1_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_3efe1_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_3efe1_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_3efe1_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_3efe1_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3efe1_level0_row0" class="row_heading level0 row0" >frequency_items</th>
#       <td id="T_3efe1_row0_col0" class="data row0 col0" >37.240000</td>
#       <td id="T_3efe1_row0_col1" class="data row0 col1" >39.050000</td>
#       <td id="T_3efe1_row0_col2" class="data row0 col2" >40.850000</td>
#       <td id="T_3efe1_row0_col3" class="data row0 col3" >39.810000</td>
#       <td id="T_3efe1_row0_col4" class="data row0 col4" >37.420000</td>
#     </tr>
#     <tr>
#       <th id="T_3efe1_level0_row1" class="row_heading level0 row1" >potencial_score</th>
#       <td id="T_3efe1_row1_col0" class="data row1 col0" >21.240000</td>
#       <td id="T_3efe1_row1_col1" class="data row1 col1" >30.410000</td>
#       <td id="T_3efe1_row1_col2" class="data row1 col2" >80.100000</td>
#       <td id="T_3efe1_row1_col3" class="data row1 col3" >39.040000</td>
#       <td id="T_3efe1_row1_col4" class="data row1 col4" >7.980000</td>
#     </tr>
#     <tr>
#       <th id="T_3efe1_level0_row2" class="row_heading level0 row2" >longevity_months</th>
#       <td id="T_3efe1_row2_col0" class="data row2 col0" >20.150000</td>
#       <td id="T_3efe1_row2_col1" class="data row2 col1" >15.240000</td>
#       <td id="T_3efe1_row2_col2" class="data row2 col2" >16.490000</td>
#       <td id="T_3efe1_row2_col3" class="data row2 col3" >16.060000</td>
#       <td id="T_3efe1_row2_col4" class="data row2 col4" >10.220000</td>
#     </tr>
#     <tr>
#       <th id="T_3efe1_level0_row3" class="row_heading level0 row3" >relevance_criteria</th>
#       <td id="T_3efe1_row3_col0" class="data row3 col0" >2.000000</td>
#       <td id="T_3efe1_row3_col1" class="data row3 col1" >0.760000</td>
#       <td id="T_3efe1_row3_col2" class="data row3 col2" >2.000000</td>
#       <td id="T_3efe1_row3_col3" class="data row3 col3" >1.930000</td>
#       <td id="T_3efe1_row3_col4" class="data row3 col4" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3efe1_level0_row4" class="row_heading level0 row4" >recency_in_weeks</th>
#       <td id="T_3efe1_row4_col0" class="data row4 col0" >15.510000</td>
#       <td id="T_3efe1_row4_col1" class="data row4 col1" >15.370000</td>
#       <td id="T_3efe1_row4_col2" class="data row4 col2" >14.770000</td>
#       <td id="T_3efe1_row4_col3" class="data row4 col3" >14.780000</td>
#       <td id="T_3efe1_row4_col4" class="data row4 col4" >15.400000</td>
#     </tr>
#     <tr>
#       <th id="T_3efe1_level0_row5" class="row_heading level0 row5" >promotional_percentage</th>
#       <td id="T_3efe1_row5_col0" class="data row5 col0" >7.890000</td>
#       <td id="T_3efe1_row5_col1" class="data row5 col1" >0.070000</td>
#       <td id="T_3efe1_row5_col2" class="data row5 col2" >12.100000</td>
#       <td id="T_3efe1_row5_col3" class="data row5 col3" >31.690000</td>
#       <td id="T_3efe1_row5_col4" class="data row5 col4" >13.680000</td>
#     </tr>
#     <tr>
#       <th id="T_3efe1_level0_row6" class="row_heading level0 row6" >returns</th>
#       <td id="T_3efe1_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_3efe1_row6_col1" class="data row6 col1" >0.050000</td>
#       <td id="T_3efe1_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_3efe1_row6_col3" class="data row6 col3" >1.000000</td>
#       <td id="T_3efe1_row6_col4" class="data row6 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3efe1_level0_row7" class="row_heading level0 row7" >flaged</th>
#       <td id="T_3efe1_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_3efe1_row7_col1" class="data row7 col1" >0.130000</td>
#       <td id="T_3efe1_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_3efe1_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_3efe1_row7_col4" class="data row7 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3efe1_level0_row8" class="row_heading level0 row8" >credit_factor</th>
#       <td id="T_3efe1_row8_col0" class="data row8 col0" >0.860000</td>
#       <td id="T_3efe1_row8_col1" class="data row8 col1" >0.650000</td>
#       <td id="T_3efe1_row8_col2" class="data row8 col2" >0.810000</td>
#       <td id="T_3efe1_row8_col3" class="data row8 col3" >0.970000</td>
#       <td id="T_3efe1_row8_col4" class="data row8 col4" >1.010000</td>
#     </tr>
#     <tr>
#       <th id="T_3efe1_level0_row9" class="row_heading level0 row9" >zip_code</th>
#       <td id="T_3efe1_row9_col0" class="data row9 col0" >5.660000</td>
#       <td id="T_3efe1_row9_col1" class="data row9 col1" >4.600000</td>
#       <td id="T_3efe1_row9_col2" class="data row9 col2" >7.670000</td>
#       <td id="T_3efe1_row9_col3" class="data row9 col3" >5.140000</td>
#       <td id="T_3efe1_row9_col4" class="data row9 col

# %% [markdown]
# antiques | nopromo | score | promo+returns | lowscore+new

# %% [markdown]
# ### UMAP for the solutions

# %%
visualize_dimensionality_reduction(umap_embedding_mm_all, demographic['mm_kmeans5'])

# %%
# WARDcombined_dem
visualize_dimensionality_reduction(umap_embedding_mm_all, combined_dem['mm_ward5'])

# %% [markdown]
# ### Final Solution

# %%
demographic['mm_ward5'] = combined_dem['mm_ward5']
demographic
# Out:
#         frequency_items  potencial_score  longevity_months  \
# 0                    38            -0.40                23
# 1                    50            -0.30                24
# 2                    48             1.60                32
# 3                    46            -0.90                12
# 4                    31            31.61                10
# ...                 ...              ...               ...
# 122124               51             0.10                25
# 122125               42            30.99                23
# 122126               24            79.76                29
# 122127               29             0.50                14
# 122128               52            -0.20                11
#
#         relevance_criteria  recency_in_weeks  promotional_percentage  returns  \
# 0                        2                15                      20        0
# 1                        2                10                      36        0
# 2                        2                20                       0        0
# 3                        2                14                      36        0
# 4                        2                12                      10        0
# ...                    ...               ...                     ...      ...
# 122124                   2                 9                       0        1
# 122125                   2                15                       0        0
# 122126                   2                13                      13        0
# 122127                   2                11                       0        0
# 122128                   0                15                       0        0
#
#         flaged  credit_factor  zip_code  education  gender  mm_kmeans5  \
# 0            0            0.7         0        2.0     0.0           3
# 1            0            0.7         0        0.0     NaN           3
# 2            0            0.7         0        0.0     1.0           3
# 3            0            4.5         0        NaN     0.0           1
# 4            0            0.7         8        3.0     NaN           1
# ...        ...            ...       ...        ...     ...         ...
# 122124       0            0.7         0        NaN     NaN           4
# 122125       0            0.7         8        0.0     0.0           3
# 122126       0            0.7         8        0.0     NaN           0
# 122127       0            0.7         0        NaN     NaN           1
# 122128       0            0.7         0        NaN     NaN           2
#
#         mm_ward5
# 0              4
# 1              0
# 2              0
# 3              4
# 4              4
# ...          ...
# 122124         3
# 122125         0
# 122126         2
# 122127         4
# 122128         1
#
# [122129 rows x 14 columns]

# %%
demographic.to_csv('Data/Final_Data/demographic_perspective.csv', index=False)
